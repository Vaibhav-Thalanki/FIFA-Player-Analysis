# %% [markdown]
# # FIFA Players Analysis using NetworkX

# %% [markdown]
# > SIN REVIEW 3
#
# > VAIBHAV THALANKI 20BCE1385,
# > NEERAJ S 20BCE1656

# %%
# %pip install 'scipy==1.8'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scipy==1.8 in /usr/local/lib/python3.8/dist-packages (1.8.0)
# Requirement already satisfied: numpy<1.25.0,>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from scipy==1.8) (1.22.4)

# %%
# %pip install 'networkx==2.7'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: networkx==2.7 in /usr/local/lib/python3.8/dist-packages (2.7)

# %%
import pandas as pd
import numpy as np
import networkx as nx
from networkx.algorithms import bipartite
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data
#
#
# There are **16,961 unique players** out of 17,965 total records. Some of the players appear multiple times as FIFA tracks the notable players throughout their careers.

# %%
# Load Data into Pandas dataframes
fifa = pd.read_csv('CompleteDataset.csv')
fifa.head()
# Out:
#    Unnamed: 0               Name  Age  \
# 0           0  Cristiano Ronaldo   32
# 1           1           L. Messi   30
# 2           2             Neymar   25
# 3           3          L. Suárez   30
# 4           4     R. Lewandowski   28
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1  https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2  https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4  https://cdn.sofifa.org/48/18/players/188545.png      Poland
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/38.png       94         94
# 1  https://cdn.sofifa.org/flags/52.png       93         93
# 2  https://cdn.sofifa.org/flags/54.png       92         94
# 3  https://cdn.sofifa.org/flags/60.png       92         92
# 4  https://cdn.sofifa.org/flags/37.png       91         91
#
#                   Club                                   Club Logo  ...  RB  \
# 0       Real Madrid CF  https://cdn.sofifa.org/24/18/teams/243.png  ...  61
# 1         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...  57
# 2  Paris Saint-Germain   https://cdn.sofifa.org/24/18/teams/73.png  ...  59
# 3         FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...  64
# 4     FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png  ...  58
#
#    RCB  RCM  RDM  RF  RM  RS  RW  RWB  ST
# 0   53   82   62  91  89  92  91   66  92
# 1   45   84   59  92  90  88  91   62  88
# 2   46   79   59  88  87  84  89   64  84
# 3   58   80   65  88  85  88  87   68  88
# 4   57   78   62  87  82  88  84   61  88
#
# [5 rows x 75 columns]

# %%
# Drop any rows that have missing values
fifa = fifa.dropna()

# %% [markdown]
# # Networkx Graph
#
#
# We will use players as one set of nodes and clubs as the other. This should lead us to a bipartite graph.
#
# The edges mark which players play for which clubs. In addition, there is a weight associated with every edge. The weight represents the overall performance of the player for the connected club.
# The weights will be later used to 'raise the water levels' within the network and create multiple islands. This will lead us to one or two islands with the highest performing plaers and their clubs.

# %%
# Networkx graph with two sets of bipartite nodes
B = nx.Graph()
B.add_nodes_from(fifa['Name'], bipartite=0)
B.add_nodes_from(fifa['Nationality'], bipartite=1)

# Extract data from the main dataframe and add as weighted edges
weighted_edges = fifa[['Name', 'Nationality','Overall']].T.apply(tuple)
weighted_edges.T.values.tolist()
# Out:
# [['Cristiano Ronaldo', 'Portugal', 94],
#  ['L. Messi', 'Argentina', 93],
#  ['Neymar', 'Brazil', 92],
#  ['L. Suárez', 'Uruguay', 92],
#  ['R. Lewandowski', 'Poland', 91],
#  ['E. Hazard', 'Belgium', 90],
#  ['T. Kroos', 'Germany', 90],
#  ['G. Higuaín', 'Argentina', 90],
#  ['Sergio Ramos', 'Spain', 90],
#  ['K. De Bruyne', 'Belgium', 89],
#  ['A. Sánchez', 'Chile', 89],
#  ['L. Modrić', 'Croatia', 89],
#  ['G. Bale', 'Wales', 89],
#  ['S. Agüero', 'Argentina', 89],
#  ['G. Chiellini', 'Italy', 89],
#  ['P. Dybala', 'Argentina', 88],
#  ['A. Griezmann', 'France', 88],
#  ['Thiago', 'Spain', 88],
#  ['P. Aubameyang', 'Gabon', 88],
#  ['L. Bonucci', 'Italy', 88],
#  ['J. Boateng', 'Germany', 88],
#  ['D. Godín', 'Uruguay', 88],
#  ['M. Hummels', 'Germany', 88],
#  ['M. Özil', 'Germany', 88],
#  ['Thiago Silva', 'Brazil', 88],
#  ['Z. Ibrahimović', 'Sweden', 88],
#  ['A. Robben', 'Netherlands', 88],
#  ['N. Kanté', 'France', 87],
#  ['M. Verratti', 'Italy', 87],
#  ['P. Pogba', 'France', 87],
#  ['C. Eriksen', 'Denmark', 87],
#  ['A. Vidal', 'Chile', 87],
#  ['E. Cavani', 'Uruguay', 87],
#  ['Marcelo', 'Brazil', 87],
#  ['M. Hamšík', 'Slovakia', 87],
#  ['I. Rakitić', 'Croatia', 87],
#  ['David Silva', 'Spain', 87],
#  ['Piqué', 'Spain', 87],
#  ['Iniesta', 'Spain', 87],
#  ['H. Kane', 'England', 86],
#  ['J. Rodríguez', 'Colombia', 86],
#  ['Isco', 'Spain', 86],
#  ['D. Alaba', 'Austria', 86],
#  ['R. Lukaku', 'Belgium', 86],
#  ['Alex Sandro', 'Brazil', 86],
#  ['T. Müller', 'Germany', 86],
#  ['Sergio Busquets', 'Spain', 86],
#  ['Coutinho', 'Brazil', 86],
#  ['M. Reus', 'Germany', 86],
#  ['T. Alderweireld', 'Belgium', 86],
#  ['David Luiz', 'Brazil', 86],
#  ['Diego Costa', 'Spain', 86],
#  ['R. Nainggolan', 'Belgium', 86],
#  ['Javi Martínez', 'Spain', 86],
#  ['D. Mertens', 'Belgium', 86],
#  ['Sokratis', 'Greece', 86],
#  ['Miranda', 'Brazil', 86],
#  ['K. Benzema', 'France', 86],
#  ['Cesc Fàbregas', 'Spain', 86],
#  ['F. Ribéry', 'France', 86],
#  ['Pepe', 'Portugal', 86],
#  ['Y. Carrasco', 'Belgium', 85],
#  ['R. Varane', 'France', 85],
#  ['Casemiro', 'Brazil', 85],
#  ['L. Insigne', 'Italy', 85],
#  ['A. Lacazette', 'France', 85],
#  ['H. Mkhitaryan', 'Armenia', 85],
#  ['K. Glik', 'Poland', 85],
#  ['Jordi Alba', 'Spain', 85],
#  ['I. Gündoğan', 'Germany', 85],
#  ['Azpilicueta', 'Spain', 85],
#  ['A. Di María', 'Argentina', 85],
#  ['M. Pjanić', 'Bosnia Herzegovina', 85],
#  ['C. Marchisio', 'Italy', 85],
#  ['J. Vertonghen', 'Belgium', 85],
#  ['B. Matuidi', 'France', 85],
#  ['Filipe Luís', 'Brazil', 85],
#  ['V. Kompany', 'Belgium', 85],
#  ['A. Barzagli', 'Italy', 85],
#  ['E. Bailly', 'Ivory Coast', 84],
#  ['Marco Asensio', 'Spain', 84],
#  ['Bernardo Silva', 'Portugal', 84],
#  ['A. Laporte', 'France', 84],
#  ['D. Alli', 'England', 84],
#  ['S. Mané', 'Senegal', 84],
#  ['Carvajal', 'Spain', 84],
#  ['J. Draxler', 'Germany', 84],
#  ['M. Icardi', 'Argentina', 84],
#  ['Morata', 'Spain', 84],
#  ['K. Koulibaly', 'Senegal', 84],
#  ['Koke', 'Spain', 84],
#  ['K. Manolas', 'Greece', 84],
#  ['S. Mustafi', 'Germany', 84],
#  ['Ander Herrera', 'Spain', 84],
#  ['K. Strootman', 'Netherlands', 84],
#  ['Pedro', 'Spain', 84],
#  ['Bruno', 'Spain', 84],
#  ['I. Perišić', 'Croatia', 84],
#  ['E. Džeko', 'Bosnia Herzegovina', 84],
#  ['Willian', 'Brazil', 84],
#  ['S. Khedira', 'Germany', 84],
#  ['Juan Mata', 'Spain', 84],
#  ['M. Benatia', 'Morocco', 84],
#  ['D. Payet', 'France', 84],
#  ['Falcao', 'Colombia', 84],
#  ['L. Koscielny', 'France', 84],
#  ['G. Cahill', 'England', 84],
#  ['Dani Alves', 'Brazil', 84],
#  ['A. Gómez', 'Argentina', 84],
#  ['Aduriz', 'Spain', 84],
#  ['K. Mbappé', 'France', 83],
#  ['O. Dembélé', 'France', 83],
#  ['N. Keïta', 'Guinea', 83],
#  ['J. Giménez', 'Uruguay', 83],
#  ['T. Lemar', 'France', 83],
#  ['João Mário', 'Portugal', 83],
#  ['N. Süle', 'Germany', 83],
#  ['Fabinho', 'Brazil', 83],
#  ['M. Salah', 'Egypt', 83],
#  ['A. Belotti', 'Italy', 83],
#  ['E. Forsberg', 'Sweden', 83],
#  ['Marquinhos', 'Brazil', 83],
#  ['William Carvalho', 'Portugal', 83],
#  ['S. Umtiti', 'France', 83],
#  ['R. Mahrez', 'Algeria', 83],
#  ['V. van Dijk', 'Netherlands', 83],
#  ['Roberto Firmino', 'Brazil', 83],
#  ['Danilo Pereira', 'Portugal', 83],
#  ['Vitolo', 'Spain', 83],
#  ['S. de Vrij', 'Netherlands', 83],
#  ['J. Matip', 'Cameroon', 83],
#  ['I. Gueye', 'Senegal', 83],
#  ['Iago Aspas', 'Spain', 83],
#  ['N. Otamendi', 'Argentina', 83],
#  ['N. Matić', 'Serbia', 83],
#  ['J. Pastore', 'Argentina', 83],
#  ['Parejo', 'Spain', 83],
#  ['S. Kagawa', 'Japan', 83],
#  ['G. Bonaventura', 'Italy', 83],
#  ['B. Dost', 'Netherlands', 83],
#  ['K. Walker', 'England', 83],
#  ["S. N'Zonzi", 'France', 83],
#  ['M. Musacchio', 'Argentina', 83],
#  ['O. Toprak', 'Turkey', 83],
#  ['José Callejón', 'Spain', 83],
#  ['S. Giovinco', 'Italy', 83],
#  ['N. Gaitán', 'Argentina', 83],
#  ['M. Mandžukić', 'Croatia', 83],
#  ['A. Lallana', 'England', 83],
#  ['B. Höwedes', 'Germany', 83],
#  ['E. Banega', 'Argentina', 83],
#  ['M. Schneiderlin', 'France', 83],
#  ['Jonas', 'Brazil', 83],
#  ['K. Gameiro', 'France', 83],
#  ['L. Piszczek', 'Poland', 83],
#  ['E. Garay', 'Argentina', 83],
#  ['A. Valencia', 'Ecuador', 83],
#  ['M. Dembélé', 'Belgium', 83],
#  ['Borja Valero', 'Spain', 83],
#  ['L. Perrin', 'France', 83],
#  ['L. Biglia', 'Argentina', 83],
#  ['Juanfran', 'Spain', 83],
#  ['Santi Cazorla', 'Spain', 83],
#  ['J. Mascherano', 'Argentina', 83],
#  ['W. Sneijder', 'Netherlands', 83],
#  ['Nani', 'Portugal', 83],
#  ['D. De Rossi', 'Italy', 83],
#  ['Quaresma', 'Portugal', 83],
#  ['Y. Touré', 'Ivory Coast', 83],
#  ['L. Sané', 'Germany', 82],
#  ['T. Bakayoko', 'France', 82],
#  ['C. Tolisso', 'France', 82],
#  ['I. Slimani', 'Algeria', 82],
#  ['N. Fekir', 'France', 82],
#  ['J. Seri', 'Ivory Coast', 82],
#  ['K. Baldé Diao', 'Senegal', 82],
#  ['J. Tah', 'Germany', 82],
#  ['F. Bernardeschi', 'Italy', 82],
#  ['T. Werner', 'Germany', 82],
#  ['André Gomes', 'Portugal', 82],
#  ['A. Martial', 'France', 82],
#  ['L. Goretzka', 'Germany', 82],
#  ['Q. Promes', 'Netherlands', 82],
#  ['Lucas Vázquez', 'Spain', 82],
#  ['Saúl', 'Spain', 82],
#  ['Felipe', 'Brazil', 82],
#  ['C. Bacca', 'Colombia', 82],
#  ['F. Vázquez', 'Italy', 82],
#  ['M. Kovačić', 'Croatia', 82],
#  ['Manu Trigueros', 'Spain', 82],
#  ['A. Rüdiger', 'Germany', 82],
#  ['F. Thauvin', 'France', 82],
#  ['S. Savić', 'Montenegro', 82],
#  ['Iñigo Martínez', 'Spain', 82],
#  ['Roque Mesa', 'Spain', 82],
#  ['A. Florenzi', 'Italy', 82],
#  ['D. Klaassen', 'Netherlands', 82],
#  ['K. Bellarabi', 'Germany', 82],
#  ['R. Sterling', 'England', 82],
#  ['Suso', 'Spain', 82],
#  ['Deulofeu', 'Spain', 82],
#  ['E. Dier', 'England', 82],
#  ['M. Rojo', 'Argentina', 82],
#  ['Lucas', 'Brazil', 82],
#  ['H. Son', 'Korea Republic', 82],
#  ['F. Acerbi', 'Italy', 82],
#  ['G. Xhaka', 'Switzerland', 82],
#  ['Jonathan Viera', 'Spain', 82],
#  ['Pizzi', 'Portugal', 82],
#  ['Willian José', 'Brazil', 82],
#  ['G. Medel', 'Chile', 82],
#  ['Víctor Ruíz', 'Spain', 82],
#  ['X. Shaqiri', 'Switzerland', 82],
#  ['J. Cuadrado', 'Colombia', 82],
#  ['C. Immobile', 'Italy', 82],
#  ['Douglas Costa', 'Brazil', 82],
#  ['N. Clyne', 'England', 82],
#  ['Iborra', 'Spain', 82],
#  ['V. Wanyama', 'Kenya', 82],
#  ['Taison', 'Brazil', 82],
#  ['Marlos', 'Brazil', 82],
#  ['L. Stindl', 'Germany', 82],
#  ['M. Balotelli', 'Italy', 82],
#  ['A. Ramsey', 'Wales', 82],
#  ['G. Sigurðsson', 'Iceland', 82],
#  ['Y. Brahimi', 'Algeria', 82],
#  ['M. Arnautović', 'Austria', 82],
#  ['J. Henderson', 'England', 82],
#  ['M. Kruse', 'Germany', 82],
#  ['L. Fejsa', 'Serbia', 82],
#  ['V. Ćorluka', 'Croatia', 82],
#  ['G. Wijnaldum', 'Netherlands', 82],
#  ['F. Fazio', 'Argentina', 82],
#  ['O. Giroud', 'France', 82],
#  ['B. Ivanović', 'Serbia', 82],
#  ['J. Hernández', 'Mexico', 82],
#  ['Beñat', 'Spain', 82],
#  ['L. Bender', 'Germany', 82],
#  ['Naldo', 'Brazil', 82],
#  ['D. Sturridge', 'England', 82],
#  ['D. Rose', 'England', 82],
#  ['C. Vela', 'Mexico', 82],
#  ['G. Castro', 'Germany', 82],
#  ['S. Nasri', 'France', 82],
#  ['A. Williams', 'Wales', 82],
#  ['L. Baines', 'England', 82],
#  ['João Moutinho', 'Portugal', 82],
#  ['Raúl Albiol', 'Spain', 82],
#  ['M. Gómez', 'Germany', 82],
#  ['Raffael', 'Brazil', 82],
#  ['A. Turan', 'Turkey', 82],
#  ['Fernandinho', 'Brazil', 82],
#  ['David Villa', 'Spain', 82],
#  ['S. Lichtsteiner', 'Switzerland', 82],
#  ['Gabriel Jesus', 'Brazil', 81],
#  ['Nélson Semedo', 'Portugal', 81],
#  ['Gelson Martins', 'Portugal', 81],
#  ['Malcom', 'Brazil', 81],
#  ['J. Weigl', 'Germany', 81],
#  ['D. Sánchez', 'Colombia', 81],
#  ['A. Kramarić', 'Croatia', 81],
#  ['M. Brozović', 'Croatia', 81],
#  ['Williams', 'Spain', 81],
#  ['Dani García', 'Spain', 81],
#  ['A. Christensen', 'Denmark', 81],
#  ['J. Kimmich', 'Germany', 81],
#  ['Bruma', 'Portugal', 81],
#  ['D. Berardi', 'Italy', 81],
#  ['M. Sanson', 'France', 81],
#  ['A. Rabiot', 'France', 81],
#  ['R. Guerreiro', 'Portugal', 81],
#  ['J. Vardy', 'England', 81],
#  ['H. Ziyech', 'Morocco', 81],
#  ['M. Keane', 'England', 81],
#  ['Jorginho', 'Italy', 81],
#  ['Héctor Bellerín', 'Spain', 81],
#  ['S. Zaza', 'Italy', 81],
#  ['T. Meunier', 'Belgium', 81],
#  ['Felipe Anderson', 'Brazil', 81],
#  ['Rafinha', 'Brazil', 81],
#  ['Nacho Fernández', 'Spain', 81],
#  ['Sergi Roberto', 'Spain', 81],
#  ['W. Ben Yedder', 'France', 81],
#  ['Lucas Pérez', 'Spain', 81],
#  ['R. Barkley', 'England', 81],
#  ['C. Bakambu', 'DR Congo', 81],
#  ['W. Zaha', 'Ivory Coast', 81],
#  ['Bartra', 'Spain', 81],
#  ['S. Aurier', 'Ivory Coast', 81],
#  ['S. Coates', 'Uruguay', 81],
#  ['G. Krychowiak', 'Poland', 81],
#  ['K. Kampl', 'Slovenia', 81],
#  ['D. Lovren', 'Croatia', 81],
#  ['A. Yarmolenko', 'Ukraine', 81],
#  ['Y. Belhanda', 'Morocco', 81],
#  ['Mário Fernandes', 'Russia', 81],
#  ['R. Rodríguez', 'Switzerland', 81],
#  ['J. Corona', 'Mexico', 81],
#  ['Mario Gaspar', 'Spain', 81],
#  ['Marcos Alonso', 'Spain', 81],
#  ['M. Götze', 'Germany', 81],
#  ['Illarramendi', 'Spain', 81],
#  ['De Marcos', 'Spain', 81],
#  ['C. Smalling', 'England', 81],
#  ['Iturraspe', 'Spain', 81],
#  ['J. Wilshere', 'England', 81],
#  ['S. Rudy', 'Germany', 81],
#  ['M. Lanzini', 'Argentina', 81],
#  ['R. Boudebouz', 'Algeria', 81],
#  ['Camacho', 'Spain', 81],
#  ['Paulinho', 'Brazil', 81],
#  ['N. Kalinić', 'Croatia', 81],
#  ['Giuliano', 'Brazil', 81],
#  ['C. Benteke', 'Belgium', 81],
#  ['D. Perotti', 'Argentina', 81],
#  ['M. Parolo', 'Italy', 81],
#  ['K. Mitroglou', 'Greece', 81],
#  ['M. Sakho', 'France', 81],
#  ['A. Rami', 'France', 81],
#  ['S. Jovetić', 'Montenegro', 81],
#  ['S. Coleman', 'Republic of Ireland', 81],
#  ['S. Kjær', 'Denmark', 81],
#  ['M. Valbuena', 'France', 81],
#  ['D. Astori', 'Italy', 81],
#  ['K. Mirallas', 'Belgium', 81],
#  ['Raúl García', 'Spain', 81],
#  ['M. Škrtel', 'Slovakia', 81],
#  ['H. Ben Arfa', 'France', 81],
#  ['Dante', 'Brazil', 81],
#  ['A. Gignac', 'France', 81],
#  ['Gabi', 'Spain', 81],
#  ['G. Rodríguez', 'Argentina', 81],
#  ['D. Srna', 'Croatia', 81],
#  ['B. Schweinsteiger', 'Germany', 81],
#  ['W. Rooney', 'England', 81],
#  ['P. Mertesacker', 'Germany', 81],
#  ['T. Motta', 'Italy', 81],
#  ['Fernando Torres', 'Spain', 81],
#  ["S. Eto'o", 'Cameroon', 81],
#  ['M. Rashford', 'England', 80],
#  ['S. Milinković-Savić', 'Serbia', 80],
#  ['Y. Tielemans', 'Belgium', 80],
#  ['Jemerson', 'Brazil', 80],
#  ['N. Bentaleb', 'Algeria', 80],
#  ['Alex Telles', 'Brazil', 80],
#  ['J. Brandt', 'Germany', 80],
#  ['K. Demirbay', 'Germany', 80],
#  ['D. Rugani', 'Italy', 80],
#  ['Samu Castillejo', 'Spain', 80],
#  ['P. Zieliński', 'Poland', 80],
#  ['Ricardo Pereira', 'Portugal', 80],
#  ['Grimaldo', 'Spain', 80],
#  ['Fred', 'Brazil', 80],
#  ['J. Hector', 'Germany', 80],
#  ['E. Can', 'Germany', 80],
#  ['S. Kolašinac', 'Bosnia Herzegovina', 80],
#  ['A. Pléa', 'France', 80],
#  ['T. Stepanenko', 'Ukraine', 80],
#  ['O. Shatov', 'Russia', 80],
#  ['Leo Baptistao', 'Brazil', 80],
#  ['M. Nastasić', 'Serbia', 80],
#  ['Denis Suárez', 'Spain', 80],
#  ['M. Batshuayi', 'Belgium', 80],
#  ['J. Brooks', 'United States', 80],
#  ['Eric Botteghin', 'Brazil', 80],
#  ['T. Hazard', 'Belgium', 80],
#  ['V. Germain', 'France', 80],
#  ['L. Kurzawa', 'France', 80],
#  ['J. Iličić', 'Slovenia', 80],
#  ['K. Volland', 'Germany', 80],
#  ['Allan', 'Brazil', 80],
#  ['P. Hernández', 'Chile', 80],
#  ['D. Tadić', 'Serbia', 80],
#  ['L. Muriel', 'Colombia', 80],
#  ['Pablo Sarabia', 'Spain', 80],
#  ['A. Oxlade-Chamberlain', 'England', 80],
#  ['J. Guilavogui', 'France', 80],
#  ['O. Özyakup', 'Turkey', 80],
#  ['Y. Rakitskyi', 'Ukraine', 80],
#  ['Sergi Enrich', 'Spain', 80],
#  ['Hugo Mallo', 'Spain', 80],
#  ['D. Didavi', 'Germany', 80],
#  ['R. Soriano', 'Italy', 80],
#  ['A. Schürrle', 'Germany', 80],
#  ['M. Gonalons', 'France', 80],
#  ['R. Pereyra', 'Argentina', 80],
#  ['K. Vogt', 'Germany', 80],
#  ['F. Orellana', 'Chile', 80],
#  ['Maicon', 'Brazil', 80],
#  ['E. Salvio', 'Argentina', 80],
#  ['D. Blind', 'Netherlands', 80],
#  ['S. El Shaarawy', 'Italy', 80],
#  ['M. Antonio', 'England', 80],
#  ['Iago Falqué', 'Spain', 80],
#  ['S. Rondón', 'Venezuela', 80],
#  ['Daniel Carriço', 'Portugal', 80],
#  ['M. Schmelzer', 'Germany', 80],
#  ['J. McCarthy', 'Republic of Ireland', 80],
#  ['A. Dzagoev', 'Russia', 80],
#  ['Ganso', 'Brazil', 80],
#  ['F. Smolov', 'Russia', 80],
#  ['D. Welbeck', 'England', 80],
#  ['Luiz Gustavo', 'Brazil', 80],
#  ['Mikel San José', 'Spain', 80],
#  ['M. Darmian', 'Italy', 80],
#  ['R. Thomas', 'France', 80],
#  ['I. Traoré', 'Guinea', 80],
#  ['Sidnei', 'Brazil', 80],
#  ['J. Lens', 'Netherlands', 80],
#  ['Eder', 'Italy', 80],
#  ['Nacho Monreal', 'Spain', 80],
#  ['S. Bender', 'Germany', 80],
#  ['M. Díaz', 'Chile', 80],
#  ['A. Fernández', 'Argentina', 80],
#  ['I. Piatti', 'Argentina', 80],
#  ['V. Birsa', 'Slovenia', 80],
#  ['Pedro León', 'Spain', 80],
#  ['K. Boateng', 'Ghana', 80],
#  ['Marcano', 'Spain', 80],
#  ['H. Moreno', 'Mexico', 80],
#  ['A. Candreva', 'Italy', 80],
#  ['D. Criscito', 'Italy', 80],
#  ['D. Wass', 'Denmark', 80],
#  ['Coke', 'Spain', 80],
#  ['A. Guardado', 'Mexico', 80],
#  ['J. dos Santos', 'Mexico', 80],
#  ['E. Lamela', 'Argentina', 80],
#  ['R. Bertrand', 'England', 80],
#  ['Jardel', 'Brazil', 80],
#  ['V. Denisov', 'Uzbekistan', 80],
#  ['D. Basta', 'Serbia', 80],
#  ['G. Cabral', 'Argentina', 80],
#  ['G. Paletta', 'Italy', 80],
#  ['T. Walcott', 'England', 80],
#  ['V. Ibišević', 'Bosnia Herzegovina', 80],
#  ['K. El Ahmadi', 'Morocco', 80],
#  ['S. Kalou', 'Ivory Coast', 80],
#  ['Manuel Fernandes', 'Portugal', 80],
#  ['A. Granqvist', 'Sweden', 80],
#  ['L. Podolski', 'Germany', 80],
#  ['Javi Fuego', 'Spain', 80],
#  ['F. Belluschi', 'Argentina', 80],
#  ['Kaká', 'Brazil', 80],
#  ['J. Milner', 'England', 80],
#  ['A. Hutchinson', 'Canada', 80],
#  ['M. Topal', 'Turkey', 80],
#  ['J. Mathieu', 'France', 80],
#  ['P. Jagielka', 'England', 80],
#  ['P. Evra', 'France', 80],
#  ['J. Defoe', 'England', 80],
#  ['M. Carrick', 'England', 80],
#  ['M. Almirón', 'Paraguay', 79],
#  ['Oyarzabal', 'Spain', 79],
#  ['Soares', 'Brazil', 79],
#  ['F. Andone', 'Romania', 79],
#  ['M. Acuña', 'Argentina', 79],
#  ['V. Lindelöf', 'Sweden', 79],
#  ['C. Lenglet', 'France', 79],
#  ['M. Dahoud', 'Germany', 79],
#  ['D. Zappacosta', 'Italy', 79],
#  ['N. Maksimović', 'Serbia', 79],
#  ['E. Rigoni', 'Argentina', 79],
#  ['I. Marcone', 'Argentina', 79],
#  ['L. López', 'Argentina', 79],
#  ['A. Correa', 'Argentina', 79],
#  ['K. Coman', 'France', 79],
#  ['W. Cyprien', 'France', 79],
#  ['Diego Llorente', 'Spain', 79],
#  ['Anderson Talisca', 'Brazil', 79],
#  ['L. Dendoncker', 'Belgium', 79],
#  ['M. Meyer', 'Germany', 79],
#  ['Gayà', 'Spain', 79],
#  ['S. Boufal', 'Morocco', 79],
#  ['M. Benassi', 'Italy', 79],
#  ['N. Tagliafico', 'Argentina', 79],
#  ['E. Hysaj', 'Albania', 79],
#  ['João Cancelo', 'Portugal', 79],
#  ['A. Romagnoli', 'Italy', 79],
#  ['Óliver Torres', 'Spain', 79],
#  ['H. Çalhanoğlu', 'Turkey', 79],
#  ['Gerard Moreno', 'Spain', 79],
#  ['B. Traoré', 'Burkina Faso', 79],
#  ['L. Vietto', 'Argentina', 79],
#  ['L. Paredes', 'Argentina', 79],
#  ['M. Arnold', 'Germany', 79],
#  ['S. Gnabry', 'Germany', 79],
#  ['L. Shaw', 'England', 79],
#  ['E. Višća', 'Bosnia Herzegovina', 79],
#  ['Bernard', 'Brazil', 79],
#  ['D. Baselli', 'Italy', 79],
#  ['A. Milik', 'Poland', 79],
#  ['Bernat', 'Spain', 79],
#  ['W. Orban', 'Germany', 79],
#  ['Rubén Pardo', 'Spain', 79],
#  ['K. Zouma', 'France', 79],
#  ['C. Kramer', 'Germany', 79],
#  ['S. Vrsaljko', 'Croatia', 79],
#  ['Zé Luís', 'Cape Verde', 79],
#  ['J. Stones', 'England', 79],
#  ['J. Vestergaard', 'Denmark', 79],
#  ['Fernando', 'Brazil', 79],
#  ['M. Depay', 'Netherlands', 79],
#  ['F. Fernández', 'Argentina', 79],
#  ['S. Sané', 'Senegal', 79],
#  ['N. Sansone', 'Italy', 79],
#  ['P. Ntep', 'France', 79],
#  ['F. Ghoulam', 'Algeria', 79],
#  ['J. Murillo', 'Colombia', 79],
#  ['Gabriel Paulista', 'Brazil', 79],
#  ['V. Darida', 'Czech Republic', 79],
#  ['Cédric', 'Portugal', 79],
#  ['L. Tonelli', 'Italy', 79],
#  ['R. Saponara', 'Italy', 79],
#  ['D. Sidibé', 'France', 79],
#  ['Y. Konoplyanka', 'Ukraine', 79],
#  ['L. Digne', 'France', 79],
#  ['Paco Alcácer', 'Spain', 79],
#  ['Vicente Gómez', 'Spain', 79],
#  ['E. Çolak', 'Turkey', 79],
#  ['N. Jørgensen', 'Denmark', 79],
#  ['Oriol Romeu', 'Spain', 79],
#  ['Nolito', 'Spain', 79],
#  ['B. Martins Indi', 'Netherlands', 79],
#  ['M. Gabbiadini', 'Italy', 79],
#  ['P. Herrmann', 'Germany', 79],
#  ['F. Lejeune', 'France', 79],
#  ['J. Bruma', 'Netherlands', 79],
#  ['P. Jones', 'England', 79],
#  ['Keko', 'Spain', 79],
#  ['H. Pérez', 'Paraguay', 79],
#  ['Jaume Costa', 'Spain', 79],
#  ['Escudero', 'Spain', 79],
#  ['Y. Mallı', 'Turkey', 79],
#  ['A. Kokorin', 'Russia', 79],
#  ['S. Corchia', 'France', 79],
#  ['J. Kucka', 'Slovakia', 79],
#  ['A. Ljajić', 'Serbia', 79],
#  ['Canales', 'Spain', 79],
#  ['Balenziaga', 'Spain', 79],
#  ['W. Bony', 'Ivory Coast', 79],
#  ['B. Hübner', 'Germany', 79],
#  ['F. Coquelin', 'France', 79],
#  ['Jonathas', 'Brazil', 79],
#  ['G. Bou', 'Argentina', 79],
#  ['S. Doumbia', 'Ivory Coast', 79],
#  ['C. Noboa', 'Ecuador', 79],
#  ['I. Smolnikov', 'Russia', 79],
#  ['Maurício', 'Brazil', 79],
#  ['M. Fabián', 'Mexico', 79],
#  ['D. Drinkwater', 'England', 79],
#  ['A. Kolarov', 'Serbia', 79],
#  ['Mariano', 'Brazil', 79],
#  ['S. Feghouli', 'Algeria', 79],
#  ['K. Papadopoulos', 'Greece', 79],
#  ['S. Wagner', 'Germany', 79],
#  ['P. Piatti', 'Argentina', 79],
#  ['C. Yacob', 'Argentina', 79],
#  ['A. Ogbonna', 'Italy', 79],
#  ['N. Amrabat', 'Morocco', 79],
#  ['W. Vainqueur', 'France', 79],
#  ['Marcelo', 'Brazil', 79],
#  ['Antunes', 'Portugal', 79],
#  ['S. Prödl', 'Austria', 79],
#  ['S. Tasci', 'Germany', 79],
#  ['F. Johnson', 'United States', 79],
#  ['Bojan', 'Spain', 79],
#  ['M. Fellaini', 'Belgium', 79],
#  ['P. Wernbloom', 'Sweden', 79],
#  ['A. Ayew', 'Ghana', 79],
#  ['W. Reid', 'New Zealand', 79],
#  ['Lucas Leiva', 'Brazil', 79],
#  ['Z. Junuzović', 'Austria', 79],
#  ['C. Ansaldi', 'Argentina', 79],
#  ['V. Moses', 'Nigeria', 79],
#  ['D. Zurutuza', 'France', 79],
#  ['D. Valeri', 'Argentina', 79],
#  ['José Fonte', 'Portugal', 79],
#  ['N. Şahin', 'Turkey', 79],
#  ['G. dos Santos', 'Mexico', 79],
#  ['R. Shawcross', 'England', 79],
#  ['J. Evans', 'Northern Ireland', 79],
#  ['A. Gyan', 'Ghana', 79],
#  ['Y. Cabaye', 'France', 79],
#  ['Danilo', 'Brazil', 79],
#  ['N. Pareja', 'Argentina', 79],
#  ['S. Radu', 'Romania', 79],
#  ['D. Abraham', 'Argentina', 79],
#  ['M. Krohn-Dehli', 'Denmark', 79],
#  ['Jurado', 'Spain', 79],
#  ['B. Gomis', 'France', 79],
#  ['H. Herrera', 'Mexico', 79],
#  ['Luisão', 'Brazil', 79],
#  ['V. Berezutskiy', 'Russia', 79],
#  ['I. Denisov', 'Russia', 79],
#  ['A. Samedov', 'Russia', 79],
#  ['Xabi Prieto', 'Spain', 79],
#  ['Negredo', 'Spain', 79],
#  ['P. Zabaleta', 'Argentina', 79],
#  ['Vágner Love', 'Brazil', 79],
#  ['D. Baier', 'Germany', 79],
#  ['T. Rosický', 'Czech Republic', 79],
#  ['A. Pirlo', 'Italy', 79],
#  ['G. Barry', 'England', 79],
#  ['E. Belözoğlu', 'Turkey', 79],
#  ['André Silva', 'Portugal', 78],
#  ['K. Dolberg', 'Denmark', 78],
#  ['Yeray', 'Spain', 78],
#  ['C. Pulisic', 'United States', 78],
#  ['L. Tousart', 'France', 78],
#  ['V. Koziello', 'France', 78],
#  ['N. Radoja', 'Serbia', 78],
#  ['V. Rongier', 'France', 78],
#  ['O. Al Soma', 'Syria', 78],
#  ['F. Cervi', 'Argentina', 78],
#  ['Jorge Meré', 'Spain', 78],
#  ['Jony', 'Spain', 78],
#  ['R. Karsdorp', 'Netherlands', 78],
#  ['Dani Ceballos', 'Spain', 78],
#  ['H. Lozano', 'Mexico', 78],
#  ['Raúl', 'Brazil', 78],
#  ['M. Vecino', 'Uruguay', 78],
#  ['A. Sanabria', 'Paraguay', 78],
#  ['R. Battaglia', 'Argentina', 78],
#  ['J. Izquierdo', 'Colombia', 78],
#  ['T. Bongonda', 'Belgium', 78],
#  ['Rúben Semedo', 'Portugal', 78],
#  ['Rafa', 'Portugal', 78],
#  ['Morales', 'Spain', 78],
#  ['Capa', 'Spain', 78],
#  ['D. Zapata', 'Colombia', 78],
#  ['D. Benedetto', 'Argentina', 78],
#  ['A. Ruiz', 'Argentina', 78],
#  ['D. Laxalt', 'Uruguay', 78],
#  ['D. Origi', 'Belgium', 78],
#  ['N. Stark', 'Germany', 78],
#  ['Hernâni', 'Portugal', 78],
#  ['Iuri Medeiros', 'Portugal', 78],
#  ['Bruno Fernandes', 'Portugal', 78],
#  ['R. Gagliardini', 'Italy', 78],
#  ['Pedro Santos', 'Portugal', 78],
#  ['Carles Gil', 'Spain', 78],
#  ['Paulo Oliveira', 'Portugal', 78],
#  ['A. Szymanowski', 'Argentina', 78],
#  ['Bruno Peres', 'Brazil', 78],
#  ['K. Wimmer', 'Austria', 78],
#  ['F. Kostić', 'Serbia', 78],
#  ['A. Samaris', 'Greece', 78],
#  ['A. Doucouré', 'France', 78],
#  ['G. Pizarro', 'Argentina', 78],
#  ['J. Martínez', 'Venezuela', 78],
#  ['M. Ginter', 'Germany', 78],
#  ['J. Lingard', 'England', 78],
#  ['M. Weiser', 'Germany', 78],
#  ['D. Cheryshev', 'Russia', 78],
#  ['Bigas', 'Spain', 78],
#  ['D. Heintz', 'Germany', 78],
#  ['B. Davies', 'Wales', 78],
#  ['L. Castro', 'Argentina', 78],
#  ['J. Ward-Prowse', 'England', 78],
#  ['T. Inui', 'Japan', 78],
#  ['M. Sabitzer', 'Austria', 78],
#  ['B. Mendy', 'France', 78],
#  ['R. Jiménez', 'Mexico', 78],
#  ['E. Sala', 'Argentina', 78],
#  ['M. Niang', 'France', 78],
#  ['K. Fortounis', 'Greece', 78],
#  ['Pozuelo', 'Spain', 78],
#  ['Joãozinho', 'Brazil', 78],
#  ['P. Kadeřábek', 'Czech Republic', 78],
#  ['T. Vilhena', 'Netherlands', 78],
#  ['M. Elyounoussi', 'Norway', 78],
#  ['L. Bittencourt', 'Germany', 78],
#  ['Sergi Darder', 'Spain', 78],
#  ['D. Demme', 'Germany', 78],
#  ['V. Eysseric', 'France', 78],
#  ['G. Ramírez', 'Uruguay', 78],
#  ['David López', 'Spain', 78],
#  ['M. Badelj', 'Croatia', 78],
#  ['A. Mandi', 'Algeria', 78],
#  ['Ismaily', 'Brazil', 78],
#  ['L. Teodorczyk', 'Poland', 78],
#  ['N. Chadli', 'Belgium', 78],
#  ['S. Rode', 'Germany', 78],
#  ['M. van Ginkel', 'Netherlands', 78],
#  ['André André', 'Portugal', 78],
#  ['J. Guidetti', 'Sweden', 78],
#  ['Danilo', 'Brazil', 78],
#  ['V. Aboubakar', 'Cameroon', 78],
#  ['C. Aránguiz', 'Chile', 78],
#  ['Raúl Navas', 'Spain', 78],
#  ['K. Mbodj', 'Senegal', 78],
#  ['Rodrigo', 'Spain', 78],
#  ['R. Funes Mori', 'Argentina', 78],
#  ['M. Höger', 'Germany', 78],
#  ['N. Lodeiro', 'Uruguay', 78],
#  ['D. Caligiuri', 'Italy', 78],
#  ['S. Verdi', 'Italy', 78],
#  ['E. Pérez', 'Argentina', 78],
#  ['T. Gutiérrez', 'Colombia', 78],
#  ['C. Austin', 'England', 78],
#  ['G. Gillet', 'Belgium', 78],
#  ['L. López', 'Argentina', 78],
#  ['A. Townsend', 'England', 78],
#  ['D. Heintz', 'Germany', 78],
#  ['Pozuelo', 'Spain', 78],
#  ['T. Vermaelen', 'Belgium', 78],
#  ['I. Abate', 'Italy', 78],
#  ['J. Briand', 'France', 78],
#  ['M. Sabitzer', 'Austria', 78],
#  ['Capa', 'Spain', 78],
#  ['J. Toulalan', 'France', 78],
#  ['Bruno Alves', 'Portugal', 78],
#  ['C. Aránguiz', 'Chile', 78],
#  ['V. Rongier', 'France', 78],
#  ['Joaquín', 'Spain', 78],
#  ['J. Lingard', 'England', 78],
#  ['S. Bocchetti', 'Italy', 78],
#  ['Muniain', 'Spain', 78],
#  ['Danilo', 'Brazil', 78],
#  ['C. Gentner', 'Germany', 78],
#  ['O. Al Soma', 'Syria', 78],
#  ['F. Gago', 'Argentina', 78],
#  ['Bigas', 'Spain', 78],
#  ['D. Origi', 'Belgium', 78],
#  ['D. Cheryshev', 'Russia', 78],
#  ['R. van Persie', 'Netherlands', 78],
#  ['M. Layún', 'Mexico', 78],
#  ['V. Eysseric', 'France', 78],
#  ['Sergi Darder', 'Spain', 78],
#  ['D. Laxalt', 'Uruguay', 78],
#  ['Morales', 'Spain', 78],
#  ['V. Aboubakar', 'Cameroon', 78],
#  ['A. Szymanowski', 'Argentina', 78],
#  ['N. Nkoulou', 'Cameroon', 78],
#  ['S. Ignashevich', 'Russia', 78],
#  ['Ismaily', 'Brazil', 78],
#  ['Rafinha', 'Brazil', 78],
#  ['L. Tousart', 'France', 78],
#  ['J. Terry', 'England', 78],
#  ['P. Skjelbred', 'Norway', 78],
#  ['I. Afellay', 'Netherlands', 78],
#  ['N. Lombaerts', 'Belgium', 78],
#  ['Granero', 'Spain', 78],
#  ['J. Baumgartlinger', 'Austria', 78],
#  ['R. Palacio', 'Argentina', 78],
#  ['Miguel Lopes', 'Portugal', 78],
#  ['Susaeta', 'Spain', 78],
#  ['Hilton', 'Brazil', 78],
#  ["Y. M'Vila", 'France', 78],
#  ['Pedro Santos', 'Portugal', 78],
#  ['Hernâni', 'Portugal', 78],
#  ['V. Koziello', 'France', 78],
#  ['J. Guidetti', 'Sweden', 78],
#  ['Borja Bastón', 'Spain', 78],
#  ['J. Farfán', 'Peru', 78],
#  ['J. Montero', 'Ecuador', 78],
#  ['A. Mandi', 'Algeria', 78],
#  ['K. Mbodj', 'Senegal', 78],
#  ['M. Badelj', 'Croatia', 78],
#  ['R. Battaglia', 'Argentina', 78],
#  ['M. Ruben', 'Argentina', 78],
#  ['M. Borriello', 'Italy', 78],
#  ['Rodrigo', 'Spain', 78],
#  ['R. Gagliardini', 'Italy', 78],
#  ['Eliseu', 'Portugal', 78],
#  ['F. Kostić', 'Serbia', 78],
#  ['Mosquera', 'Spain', 78],
#  ['Rochina', 'Spain', 78],
#  ['André André', 'Portugal', 78],
#  ['Rúben Semedo', 'Portugal', 78],
#  ['B. Džemaili', 'Switzerland', 78],
#  ['K. Fortounis', 'Greece', 78],
#  ["A. N'Diaye", 'Senegal', 78],
#  ['Y. Gourcuff', 'France', 78],
#  ['K. Asamoah', 'Ghana', 78],
#  ['R. Bobadilla', 'Paraguay', 78],
#  ['R. Hamouma', 'France', 78],
#  ['C. Pulisic', 'United States', 78],
#  ['M. Fernández', 'Chile', 78],
#  ['K. Honda', 'Japan', 78],
#  ['Raúl Navas', 'Spain', 78],
#  ['A. Dzyuba', 'Russia', 78],
#  ['B. Yılmaz', 'Turkey', 78],
#  ['J. Holebas', 'Greece', 78],
#  ['Javi García', 'Spain', 78],
#  ['D. Caligiuri', 'Italy', 78],
#  ['Fontàs', 'Spain', 78],
#  ['Jony', 'Spain', 78],
#  ['C. Tosun', 'Turkey', 78],
#  ['M. Höger', 'Germany', 78],
#  ['S. Dann', 'England', 78],
#  ['Rafa', 'Portugal', 78],
#  ['Y. Bolasie', 'DR Congo', 78],
#  ['Bruno Fernandes', 'Portugal', 78],
#  ['D. Glushakov', 'Russia', 78],
#  ['Juanfran', 'Spain', 78],
#  ['K. Trippier', 'England', 78],
#  ['J. Cork', 'England', 78],
#  ['A. Ramos', 'Colombia', 78],
#  ['M. Bradley', 'United States', 78],
#  ['Souza', 'Brazil', 78],
#  ['T. Mangani', 'France', 78],
#  ['N. Stark', 'Germany', 78],
#  ['Rafael', 'Brazil', 78],
#  ['Carles Gil', 'Spain', 78],
#  ['Adriano', 'Brazil', 78],
#  ['B. Mee', 'England', 78],
#  ['M. Ginter', 'Germany', 78],
#  ['Paulo Oliveira', 'Portugal', 78],
#  ['C. Dempsey', 'United States', 78],
#  ['R. Funes Mori', 'Argentina', 78],
#  ['M. Weiser', 'Germany', 78],
#  ['H. Briceldo', 'Chile', 77],
#  ['Juanmi', 'Spain', 77],
#  ['N. Subotić', 'Serbia', 77],
#  ['N. Blandi', 'Argentina', 77],
#  ['P. De Blasis', 'Argentina', 77],
#  ['M. Phillips', 'Scotland', 77],
#  ['M. Braithwaite', 'Denmark', 77],
#  ['D. Reyes', 'Mexico', 77],
#  ['Iván Ramis', 'Spain', 77],
#  ['V. Behrami', 'Switzerland', 77],
#  ['G. Hoarau', 'France', 77],
#  ['T. Barnetta', 'Switzerland', 77],
#  ['E. Choupo-Moting', 'Cameroon', 77],
#  ['Jesé', 'Spain', 77],
#  ['J. Pinola', 'Argentina', 77],
#  ['Luís Hernández', 'Spain', 77],
#  ['Jonny', 'Spain', 77],
#  ['M. Carcela-González', 'Morocco', 77],
#  ['L. Pavoletti', 'Italy', 77],
#  ['D. Bonera', 'Italy', 77],
#  ['Marcelo', 'Brazil', 77],
#  ['Dalbert', 'Brazil', 77],
#  ['G. McAuley', 'Northern Ireland', 77],
#  ['A. Halilović', 'Croatia', 77],
#  ['N. Amiri', 'Germany', 77],
#  ['I. Popov', 'Bulgaria', 77],
#  ['N. Burdisso', 'Argentina', 77],
#  ['W. Hoolahan', 'Republic of Ireland', 77],
#  ['Sidney Pessinho', 'Brazil', 77],
#  ['A. Potuk', 'Turkey', 77],
#  ['F. Pogba', 'Guinea', 77],
#  ['A. Carrillo', 'Peru', 77],
#  ['M. Andreolli', 'Italy', 77],
#  ['Bruno', 'Spain', 77],
#  ['O. Duarte', 'Costa Rica', 77],
#  ['Rúben Neves', 'Portugal', 77],
#  ['Jozabed', 'Spain', 77],
#  ['P. Pérez', 'Argentina', 77],
#  ['Gazzolisco', 'Brazil', 77],
#  ['M. Gamonales', 'Chile', 77],
#  ['Ronaldo Esler', 'Brazil', 77],
#  ['Vitor Hugo', 'Brazil', 77],
#  ['T. Arslan', 'Turkey', 77],
#  ['J. Veretout', 'France', 77],
#  ['D. Pabón', 'Colombia', 77],
#  ['Juan Jesus', 'Brazil', 77],
#  ['E. Durm', 'Germany', 77],
#  ['G. Imbula', 'France', 77],
#  ['Luis Alberto', 'Spain', 77],
#  ['M. Risse', 'Germany', 77],
#  ['Luís Neto', 'Portugal', 77],
#  ['B. Ruíz', 'Costa Rica', 77],
#  ['Jordi Amat', 'Spain', 77],
#  ['J. Ďurica', 'Slovakia', 77],
#  ['B. Stambouli', 'France', 77],
#  ['C. Kaboré', 'Burkina Faso', 77],
#  ['A. Rukavina', 'Serbia', 77],
#  ['P. Kimpembe', 'France', 77],
#  ['Sergio León', 'Spain', 77],
#  ['M. Elneny', 'Egypt', 77],
#  ['D. Torres', 'Colombia', 77],
#  ['S. Okazaki', 'Japan', 77],
#  ['C. Jallet', 'France', 77],
#  ['Y. Salibur', 'France', 77],
#  ['N. Redmond', 'England', 77],
#  ['A. Song', 'Cameroon', 77],
#  ['Andreas Pereira', 'Brazil', 77],
#  ['Castán', 'Brazil', 77],
#  ['K. Huntelaar', 'Netherlands', 77],
#  ['T. Partey', 'Ghana', 77],
#  ['Mário Rui', 'Portugal', 77],
#  ['André Pinto', 'Portugal', 77],
#  ['L. Rémy', 'France', 77],
#  ['Badou Ndiaye', 'Senegal', 77],
#  ['A. Bertolacci', 'Italy', 77],
#  ['A. Živković', 'Serbia', 77],
#  ['M. Lemina', 'Gabon', 77],
#  ['D. Da Silva', 'France', 77],
#  ['T. Rincón', 'Venezuela', 77],
#  ['Y. Ōsako', 'Japan', 77],
#  ['L. Sané', 'Senegal', 77],
#  ['J. King', 'Norway', 77],
#  ['Bastos', 'Angola', 77],
#  ['J. Quintero', 'Colombia', 77],
#  ['A. Meier', 'Germany', 77],
#  ['G. Nkoudou', 'France', 77],
#  ['Montoya', 'Spain', 77],
#  ['L. Dalsaro', 'Chile', 77],
#  ['K. Källström', 'Sweden', 77],
#  ['M. Politano', 'Italy', 77],
#  ['M. Zárate', 'Argentina', 77],
#  ['G. İnler', 'Switzerland', 77],
#  ['M. Albrighton', 'England', 77],
#  ['A. Gray', 'England', 77],
#  ['Marçal', 'Brazil', 77],
#  ['A. Gamberini', 'Italy', 77],
#  ['S. Widmer', 'Switzerland', 77],
#  ['J. Aquino', 'Mexico', 77],
#  ['S. Gentiletti', 'Argentina', 77],
#  ['C. Sánchez', 'Colombia', 77],
#  ['M. Sissoko', 'France', 77],
#  ['G. Defrel', 'France', 77],
#  ['R. Martínez', 'Argentina', 77],
#  ['J. Geis', 'Germany', 77],
#  ['P. Verhaegh', 'Netherlands', 77],
#  ['H. Nordtveit', 'Norway', 77],
#  ['R. Steffen', 'Switzerland', 77],
#  ['M. Hasebe', 'Japan', 77],
#  ['J. Córdoba', 'Colombia', 77],
#  ['L. Schøne', 'Denmark', 77],
#  ['R. Rosales', 'Venezuela', 77],
#  ['N. De Préville', 'France', 77],
#  ['Marcos Llorente', 'Spain', 77],
#  ['Y. Chará', 'Colombia', 77],
#  ['Wallace', 'Brazil', 77],
#  ['J. Toornstra', 'Netherlands', 77],
#  ['Pedro Obiang', 'Spain', 77],
#  ['V. Chiricheş', 'Romania', 77],
#  ['S. Hanni', 'Algeria', 77],
#  ['C. Théréau', 'France', 77],
#  ['D. Rolán', 'Uruguay', 77],
#  ['Pedro Henrique', 'Brazil', 77],
#  ['Bruno Gaspar', 'Portugal', 77],
#  ['Cristian Tello', 'Spain', 77],
#  ['Formosandrinho', 'Brazil', 77],
#  ['S. Haller', 'France', 77],
#  ['Claudio Coíntra', 'Brazil', 77],
#  ['M. Uth', 'Germany', 77],
#  ['F. Sørensen', 'Denmark', 77],
#  ['J. Van Damme', 'Belgium', 77],
#  ['L. Britton', 'England', 77],
#  ['V. Grifo', 'Italy', 77],
#  ['T. Cairney', 'Scotland', 77],
#  ['Sandro', 'Spain', 77],
#  ['F. Delph', 'England', 77],
#  ['J. Veltman', 'Netherlands', 77],
#  ['A. Dragović', 'Austria', 77],
#  ['D. Pröpper', 'Netherlands', 77],
#  ['L. Cattermole', 'England', 77],
#  ['Luisinho', 'Portugal', 77],
#  ['Vitinho', 'Brazil', 77],
#  ['Z. Feddal', 'Morocco', 77],
#  ['Vallejo', 'Spain', 77],
#  ['Rafael Carioca', 'Brazil', 77],
#  ['David García', 'Spain', 77],
#  ['J. Allen', 'Wales', 77],
#  ['A. Younes', 'Germany', 77],
#  ['L. Hernández', 'France', 77],
#  ['A. Mooy', 'Australia', 77],
#  ['Campaña', 'Spain', 77],
#  ['Vieirinha', 'Portugal', 77],
#  ['Wendell', 'Brazil', 77],
#  ['Y. Sabaly', 'France', 77],
#  ['J. Hofmann', 'Germany', 77],
#  ['Timor', 'Spain', 77],
#  ['H. Arter', 'Republic of Ireland', 77],
#  ['M. Lemos', 'Uruguay', 77],
#  ['Louri Beretta', 'Brazil', 77],
#  ['F. Caicedo', 'Ecuador', 77],
#  ['S. Sturaro', 'Italy', 77],
#  ['Pablo Fornals', 'Spain', 77],
#  ['Sergi Gómez', 'Spain', 77],
#  ['P. Jansson', 'Sweden', 77],
#  ['A. Berezutskiy', 'Russia', 77],
#  ['L. Pellegrini', 'Italy', 77],
#  ['A. Masiello', 'Italy', 77],
#  ['M. Ekici', 'Turkey', 77],
#  ['A. Nyom', 'Cameroon', 77],
#  ['F. Roncaglia', 'Argentina', 77],
#  ['P. Hidalgado', 'Chile', 77],
#  ['J. De Guzmán', 'Netherlands', 77],
#  ['M. Gradel', 'Ivory Coast', 77],
#  ['M. Debuchy', 'France', 77],
#  ['S. Terodde', 'Germany', 77],
#  ['Recio', 'Spain', 77],
#  ['R. Zobnin', 'Russia', 77],
#  ['Fábio Coentrão', 'Portugal', 77],
#  ['J. Campbell', 'Costa Rica', 77],
#  ['C. Stuani', 'Uruguay', 77],
#  ['A. Veznera', 'Chile', 77],
#  ['J. Willems', 'Netherlands', 77],
#  ['A. Lennon', 'England', 77],
#  ['T. Lagardo', 'Chile', 77],
#  ['S. Okaka', 'Italy', 77],
#  ['Aritz Elustondo', 'Spain', 77],
#  ['Ricardo Ferreira', 'Portugal', 77],
#  ['W. Morgan', 'Jamaica', 77],
#  ['J. Lukaku', 'Belgium', 77],
#  ...]

# %%
weighted_edges.T
# Out:
#                     Name Nationality Overall
# 0      Cristiano Ronaldo    Portugal      94
# 1               L. Messi   Argentina      93
# 2                 Neymar      Brazil      92
# 3              L. Suárez     Uruguay      92
# 4         R. Lewandowski      Poland      91
# ...                  ...         ...     ...
# 15741          J. Keeble     England      46
# 15742       T. Käßemodel     Germany      46
# 15743           J. Young    Scotland      46
# 15744       J. Lundstram     England      46
# 15745          L. Sackey       Ghana      46
#
# [15746 rows x 3 columns]

# %%
B.add_weighted_edges_from(weighted_edges.T.values.tolist())

# %%
list(B.edges(data=True))
# Out:
# [('Cristiano Ronaldo', 'Portugal', {'weight': 94}),
#  ('L. Messi', 'Argentina', {'weight': 93}),
#  ('Neymar', 'Brazil', {'weight': 92}),
#  ('L. Suárez', 'Uruguay', {'weight': 92}),
#  ('L. Suárez', 'Argentina', {'weight': 64}),
#  ('R. Lewandowski', 'Poland', {'weight': 91}),
#  ('E. Hazard', 'Belgium', {'weight': 90}),
#  ('T. Kroos', 'Germany', {'weight': 90}),
#  ('G. Higuaín', 'Argentina', {'weight': 90}),
#  ('Sergio Ramos', 'Spain', {'weight': 90}),
#  ('K. De Bruyne', 'Belgium', {'weight': 89}),
#  ('A. Sánchez', 'Chile', {'weight': 89}),
#  ('L. Modrić', 'Croatia', {'weight': 89}),
#  ('G. Bale', 'Wales', {'weight': 89}),
#  ('S. Agüero', 'Argentina', {'weight': 89}),
#  ('G. Chiellini', 'Italy', {'weight': 89}),
#  ('P. Dybala', 'Argentina', {'weight': 88}),
#  ('A. Griezmann', 'France', {'weight': 88}),
#  ('Thiago', 'Spain', {'weight': 88}),
#  ('P. Aubameyang', 'Gabon', {'weight': 88}),
#  ('L. Bonucci', 'Italy', {'weight': 88}),
#  ('J. Boateng', 'Germany', {'weight': 88}),
#  ('D. Godín', 'Uruguay', {'weight': 88}),
#  ('M. Hummels', 'Germany', {'weight': 88}),
#  ('M. Özil', 'Germany', {'weight': 88}),
#  ('Thiago Silva', 'Brazil', {'weight': 88}),
#  ('Z. Ibrahimović', 'Sweden', {'weight': 88}),
#  ('A. Robben', 'Netherlands', {'weight': 88}),
#  ('N. Kanté', 'France', {'weight': 87}),
#  ('M. Verratti', 'Italy', {'weight': 87}),
#  ('P. Pogba', 'France', {'weight': 87}),
#  ('C. Eriksen', 'Denmark', {'weight': 87}),
#  ('A. Vidal', 'Chile', {'weight': 87}),
#  ('E. Cavani', 'Uruguay', {'weight': 87}),
#  ('Marcelo', 'Brazil', {'weight': 77}),
#  ('M. Hamšík', 'Slovakia', {'weight': 87}),
#  ('I. Rakitić', 'Croatia', {'weight': 87}),
#  ('David Silva', 'Spain', {'weight': 87}),
#  ('Piqué', 'Spain', {'weight': 87}),
#  ('Iniesta', 'Spain', {'weight': 87}),
#  ('H. Kane', 'England', {'weight': 86}),
#  ('J. Rodríguez', 'Colombia', {'weight': 61}),
#  ('J. Rodríguez', 'Uruguay', {'weight': 72}),
#  ('J. Rodríguez', 'Mexico', {'weight': 57}),
#  ('J. Rodríguez', 'Argentina', {'weight': 70}),
#  ('Isco', 'Spain', {'weight': 86}),
#  ('D. Alaba', 'Austria', {'weight': 86}),
#  ('R. Lukaku', 'Belgium', {'weight': 86}),
#  ('Alex Sandro', 'Brazil', {'weight': 86}),
#  ('T. Müller', 'Germany', {'weight': 59}),
#  ('Sergio Busquets', 'Spain', {'weight': 86}),
#  ('Coutinho', 'Brazil', {'weight': 86}),
#  ('M. Reus', 'Germany', {'weight': 86}),
#  ('T. Alderweireld', 'Belgium', {'weight': 86}),
#  ('David Luiz', 'Brazil', {'weight': 86}),
#  ('Diego Costa', 'Spain', {'weight': 86}),
#  ('R. Nainggolan', 'Belgium', {'weight': 86}),
#  ('Javi Martínez', 'Spain', {'weight': 86}),
#  ('D. Mertens', 'Belgium', {'weight': 86}),
#  ('Sokratis', 'Greece', {'weight': 86}),
#  ('Miranda', 'Brazil', {'weight': 86}),
#  ('Miranda', 'Spain', {'weight': 64}),
#  ('K. Benzema', 'France', {'weight': 86}),
#  ('Cesc Fàbregas', 'Spain', {'weight': 86}),
#  ('F. Ribéry', 'France', {'weight': 86}),
#  ('Pepe', 'Portugal', {'weight': 86}),
#  ('Y. Carrasco', 'Belgium', {'weight': 85}),
#  ('R. Varane', 'France', {'weight': 85}),
#  ('Casemiro', 'Brazil', {'weight': 85}),
#  ('L. Insigne', 'Italy', {'weight': 85}),
#  ('A. Lacazette', 'France', {'weight': 85}),
#  ('H. Mkhitaryan', 'Armenia', {'weight': 85}),
#  ('K. Glik', 'Poland', {'weight': 85}),
#  ('Jordi Alba', 'Spain', {'weight': 85}),
#  ('I. Gündoğan', 'Germany', {'weight': 85}),
#  ('Azpilicueta', 'Spain', {'weight': 85}),
#  ('A. Di María', 'Argentina', {'weight': 85}),
#  ('M. Pjanić', 'Bosnia Herzegovina', {'weight': 85}),
#  ('C. Marchisio', 'Italy', {'weight': 85}),
#  ('J. Vertonghen', 'Belgium', {'weight': 85}),
#  ('B. Matuidi', 'France', {'weight': 85}),
#  ('Filipe Luís', 'Brazil', {'weight': 85}),
#  ('V. Kompany', 'Belgium', {'weight': 85}),
#  ('A. Barzagli', 'Italy', {'weight': 85}),
#  ('E. Bailly', 'Ivory Coast', {'weight': 84}),
#  ('Marco Asensio', 'Spain', {'weight': 84}),
#  ('Bernardo Silva', 'Portugal', {'weight': 84}),
#  ('A. Laporte', 'France', {'weight': 84}),
#  ('D. Alli', 'England', {'weight': 84}),
#  ('S. Mané', 'Senegal', {'weight': 84}),
#  ('Carvajal', 'Spain', {'weight': 84}),
#  ('J. Draxler', 'Germany', {'weight': 84}),
#  ('M. Icardi', 'Argentina', {'weight': 84}),
#  ('Morata', 'Spain', {'weight': 84}),
#  ('K. Koulibaly', 'Senegal', {'weight': 84}),
#  ('Koke', 'Spain', {'weight': 84}),
#  ('K. Manolas', 'Greece', {'weight': 84}),
#  ('S. Mustafi', 'Germany', {'weight': 84}),
#  ('Ander Herrera', 'Spain', {'weight': 84}),
#  ('K. Strootman', 'Netherlands', {'weight': 84}),
#  ('Pedro', 'Spain', {'weight': 84}),
#  ('Bruno', 'Spain', {'weight': 77}),
#  ('Bruno', 'Brazil', {'weight': 62}),
#  ('I. Perišić', 'Croatia', {'weight': 84}),
#  ('E. Džeko', 'Bosnia Herzegovina', {'weight': 84}),
#  ('Willian', 'Brazil', {'weight': 84}),
#  ('S. Khedira', 'Germany', {'weight': 84}),
#  ('Juan Mata', 'Spain', {'weight': 84}),
#  ('M. Benatia', 'Morocco', {'weight': 84}),
#  ('D. Payet', 'France', {'weight': 84}),
#  ('Falcao', 'Colombia', {'weight': 84}),
#  ('L. Koscielny', 'France', {'weight': 84}),
#  ('G. Cahill', 'England', {'weight': 84}),
#  ('Dani Alves', 'Brazil', {'weight': 84}),
#  ('A. Gómez', 'Argentina', {'weight': 57}),
#  ('Aduriz', 'Spain', {'weight': 84}),
#  ('K. Mbappé', 'France', {'weight': 83}),
#  ('O. Dembélé', 'France', {'weight': 83}),
#  ('N. Keïta', 'Guinea', {'weight': 83}),
#  ('J. Giménez', 'Uruguay', {'weight': 83}),
#  ('T. Lemar', 'France', {'weight': 83}),
#  ('João Mário', 'Portugal', {'weight': 83}),
#  ('N. Süle', 'Germany', {'weight': 83}),
#  ('Fabinho', 'Brazil', {'weight': 83}),
#  ('M. Salah', 'Egypt', {'weight': 83}),
#  ('A. Belotti', 'Italy', {'weight': 83}),
#  ('E. Forsberg', 'Sweden', {'weight': 83}),
#  ('Marquinhos', 'Brazil', {'weight': 83}),
#  ('William Carvalho', 'Portugal', {'weight': 83}),
#  ('S. Umtiti', 'France', {'weight': 83}),
#  ('R. Mahrez', 'Algeria', {'weight': 83}),
#  ('V. van Dijk', 'Netherlands', {'weight': 83}),
#  ('Roberto Firmino', 'Brazil', {'weight': 83}),
#  ('Danilo Pereira', 'Portugal', {'weight': 83}),
#  ('Vitolo', 'Spain', {'weight': 72}),
#  ('S. de Vrij', 'Netherlands', {'weight': 83}),
#  ('J. Matip', 'Cameroon', {'weight': 83}),
#  ('I. Gueye', 'Senegal', {'weight': 83}),
#  ('Iago Aspas', 'Spain', {'weight': 83}),
#  ('N. Otamendi', 'Argentina', {'weight': 83}),
#  ('N. Matić', 'Serbia', {'weight': 83}),
#  ('J. Pastore', 'Argentina', {'weight': 83}),
#  ('Parejo', 'Spain', {'weight': 83}),
#  ('S. Kagawa', 'Japan', {'weight': 83}),
#  ('G. Bonaventura', 'Italy', {'weight': 83}),
#  ('B. Dost', 'Netherlands', {'weight': 83}),
#  ('K. Walker', 'England', {'weight': 83}),
#  ('K. Walker', 'Sweden', {'weight': 68}),
#  ("S. N'Zonzi", 'France', {'weight': 83}),
#  ('M. Musacchio', 'Argentina', {'weight': 83}),
#  ('O. Toprak', 'Turkey', {'weight': 83}),
#  ('José Callejón', 'Spain', {'weight': 83}),
#  ('S. Giovinco', 'Italy', {'weight': 83}),
#  ('N. Gaitán', 'Argentina', {'weight': 83}),
#  ('M. Mandžukić', 'Croatia', {'weight': 83}),
#  ('A. Lallana', 'England', {'weight': 83}),
#  ('B. Höwedes', 'Germany', {'weight': 83}),
#  ('E. Banega', 'Argentina', {'weight': 83}),
#  ('M. Schneiderlin', 'France', {'weight': 83}),
#  ('Jonas', 'Brazil', {'weight': 83}),
#  ('K. Gameiro', 'France', {'weight': 83}),
#  ('L. Piszczek', 'Poland', {'weight': 83}),
#  ('E. Garay', 'Argentina', {'weight': 83}),
#  ('A. Valencia', 'Ecuador', {'weight': 83}),
#  ('M. Dembélé', 'Belgium', {'weight': 83}),
#  ('M. Dembélé', 'France', {'weight': 62}),
#  ('M. Dembélé', 'Mali', {'weight': 62}),
#  ('Borja Valero', 'Spain', {'weight': 83}),
#  ('L. Perrin', 'France', {'weight': 83}),
#  ('L. Biglia', 'Argentina', {'weight': 83}),
#  ('Juanfran', 'Spain', {'weight': 78}),
#  ('Santi Cazorla', 'Spain', {'weight': 83}),
#  ('J. Mascherano', 'Argentina', {'weight': 83}),
#  ('W. Sneijder', 'Netherlands', {'weight': 83}),
#  ('Nani', 'Portugal', {'weight': 83}),
#  ('D. De Rossi', 'Italy', {'weight': 83}),
#  ('Quaresma', 'Portugal', {'weight': 83}),
#  ('Y. Touré', 'Ivory Coast', {'weight': 83}),
#  ('L. Sané', 'Germany', {'weight': 82}),
#  ('L. Sané', 'Senegal', {'weight': 77}),
#  ('T. Bakayoko', 'France', {'weight': 82}),
#  ('C. Tolisso', 'France', {'weight': 82}),
#  ('I. Slimani', 'Algeria', {'weight': 82}),
#  ('N. Fekir', 'France', {'weight': 82}),
#  ('J. Seri', 'Ivory Coast', {'weight': 82}),
#  ('K. Baldé Diao', 'Senegal', {'weight': 82}),
#  ('J. Tah', 'Germany', {'weight': 82}),
#  ('F. Bernardeschi', 'Italy', {'weight': 82}),
#  ('T. Werner', 'Germany', {'weight': 70}),
#  ('André Gomes', 'Portugal', {'weight': 82}),
#  ('A. Martial', 'France', {'weight': 82}),
#  ('L. Goretzka', 'Germany', {'weight': 82}),
#  ('Q. Promes', 'Netherlands', {'weight': 82}),
#  ('Lucas Vázquez', 'Spain', {'weight': 82}),
#  ('Saúl', 'Spain', {'weight': 68}),
#  ('Felipe', 'Brazil', {'weight': 70}),
#  ('Felipe', 'Spain', {'weight': 60}),
#  ('C. Bacca', 'Colombia', {'weight': 82}),
#  ('F. Vázquez', 'Italy', {'weight': 82}),
#  ('M. Kovačić', 'Croatia', {'weight': 82}),
#  ('Manu Trigueros', 'Spain', {'weight': 82}),
#  ('A. Rüdiger', 'Germany', {'weight': 82}),
#  ('F. Thauvin', 'France', {'weight': 82}),
#  ('S. Savić', 'Montenegro', {'weight': 82}),
#  ('Iñigo Martínez', 'Spain', {'weight': 82}),
#  ('Roque Mesa', 'Spain', {'weight': 82}),
#  ('A. Florenzi', 'Italy', {'weight': 82}),
#  ('D. Klaassen', 'Netherlands', {'weight': 82}),
#  ('K. Bellarabi', 'Germany', {'weight': 82}),
#  ('R. Sterling', 'England', {'weight': 82}),
#  ('Suso', 'Spain', {'weight': 82}),
#  ('Deulofeu', 'Spain', {'weight': 82}),
#  ('E. Dier', 'England', {'weight': 82}),
#  ('M. Rojo', 'Argentina', {'weight': 82}),
#  ('Lucas', 'Brazil', {'weight': 60}),
#  ('H. Son', 'Korea Republic', {'weight': 82}),
#  ('F. Acerbi', 'Italy', {'weight': 82}),
#  ('G. Xhaka', 'Switzerland', {'weight': 82}),
#  ('Jonathan Viera', 'Spain', {'weight': 82}),
#  ('Pizzi', 'Portugal', {'weight': 82}),
#  ('Willian José', 'Brazil', {'weight': 82}),
#  ('G. Medel', 'Chile', {'weight': 82}),
#  ('Víctor Ruíz', 'Spain', {'weight': 82}),
#  ('X. Shaqiri', 'Switzerland', {'weight': 82}),
#  ('J. Cuadrado', 'Colombia', {'weight': 82}),
#  ('C. Immobile', 'Italy', {'weight': 82}),
#  ('Douglas Costa', 'Brazil', {'weight': 82}),
#  ('N. Clyne', 'England', {'weight': 82}),
#  ('Iborra', 'Spain', {'weight': 82}),
#  ('V. Wanyama', 'Kenya', {'weight': 82}),
#  ('Taison', 'Brazil', {'weight': 82}),
#  ('Marlos', 'Brazil', {'weight': 82}),
#  ('L. Stindl', 'Germany', {'weight': 82}),
#  ('M. Balotelli', 'Italy', {'weight': 82}),
#  ('A. Ramsey', 'Wales', {'weight': 82}),
#  ('G. Sigurðsson', 'Iceland', {'weight': 82}),
#  ('Y. Brahimi', 'Algeria', {'weight': 82}),
#  ('M. Arnautović', 'Austria', {'weight': 82}),
#  ('J. Henderson', 'England', {'weight': 82}),
#  ('M. Kruse', 'Germany', {'weight': 82}),
#  ('L. Fejsa', 'Serbia', {'weight': 82}),
#  ('V. Ćorluka', 'Croatia', {'weight': 82}),
#  ('G. Wijnaldum', 'Netherlands', {'weight': 66}),
#  ('F. Fazio', 'Argentina', {'weight': 82}),
#  ('O. Giroud', 'France', {'weight': 82}),
#  ('B. Ivanović', 'Serbia', {'weight': 82}),
#  ('J. Hernández', 'Mexico', {'weight': 75}),
#  ('J. Hernández', 'Venezuela', {'weight': 67}),
#  ('J. Hernández', 'Colombia', {'weight': 64}),
#  ('Beñat', 'Spain', {'weight': 82}),
#  ('L. Bender', 'Germany', {'weight': 61}),
#  ('Naldo', 'Brazil', {'weight': 75}),
#  ('D. Sturridge', 'England', {'weight': 82}),
#  ('D. Rose', 'England', {'weight': 65}),
#  ('C. Vela', 'Mexico', {'weight': 82}),
#  ('G. Castro', 'Germany', {'weight': 82}),
#  ('G. Castro', 'Uruguay', {'weight': 75}),
#  ('S. Nasri', 'France', {'weight': 82}),
#  ('A. Williams', 'Wales', {'weight': 82}),
#  ('A. Williams', 'England', {'weight': 59}),
#  ('L. Baines', 'England', {'weight': 82}),
#  ('João Moutinho', 'Portugal', {'weight': 82}),
#  ('Raúl Albiol', 'Spain', {'weight': 82}),
#  ('M. Gómez', 'Germany', {'weight': 82}),
#  ('M. Gómez', 'Uruguay', {'weight': 73}),
#  ('M. Gómez', 'Colombia', {'weight': 62}),
#  ('Raffael', 'Brazil', {'weight': 82}),
#  ('A. Turan', 'Turkey', {'weight': 67}),
#  ('Fernandinho', 'Brazil', {'weight': 82}),
#  ('David Villa', 'Spain', {'weight': 82}),
#  ('S. Lichtsteiner', 'Switzerland', {'weight': 82}),
#  ('Gabriel Jesus', 'Brazil', {'weight': 81}),
#  ('Nélson Semedo', 'Portugal', {'weight': 81}),
#  ('Gelson Martins', 'Portugal', {'weight': 81}),
#  ('Malcom', 'Brazil', {'weight': 81}),
#  ('J. Weigl', 'Germany', {'weight': 81}),
#  ('D. Sánchez', 'Colombia', {'weight': 81}),
#  ('A. Kramarić', 'Croatia', {'weight': 81}),
#  ('M. Brozović', 'Croatia', {'weight': 81}),
#  ('Williams', 'Spain', {'weight': 81}),
#  ('Dani García', 'Spain', {'weight': 81}),
#  ('A. Christensen', 'Denmark', {'weight': 81}),
#  ('J. Kimmich', 'Germany', {'weight': 81}),
#  ('Bruma', 'Portugal', {'weight': 81}),
#  ('D. Berardi', 'Italy', {'weight': 81}),
#  ('M. Sanson', 'France', {'weight': 81}),
#  ('A. Rabiot', 'France', {'weight': 81}),
#  ('R. Guerreiro', 'Portugal', {'weight': 81}),
#  ('J. Vardy', 'England', {'weight': 81}),
#  ('H. Ziyech', 'Morocco', {'weight': 81}),
#  ('M. Keane', 'England', {'weight': 81}),
#  ('Jorginho', 'Italy', {'weight': 81}),
#  ('Jorginho', 'Portugal', {'weight': 70}),
#  ('Héctor Bellerín', 'Spain', {'weight': 81}),
#  ('S. Zaza', 'Italy', {'weight': 81}),
#  ('T. Meunier', 'Belgium', {'weight': 81}),
#  ('Felipe Anderson', 'Brazil', {'weight': 81}),
#  ('Rafinha', 'Brazil', {'weight': 68}),
#  ('Rafinha', 'Portugal', {'weight': 64}),
#  ('Nacho Fernández', 'Spain', {'weight': 81}),
#  ('Sergi Roberto', 'Spain', {'weight': 81}),
#  ('W. Ben Yedder', 'France', {'weight': 81}),
#  ('Lucas Pérez', 'Spain', {'weight': 81}),
#  ('R. Barkley', 'England', {'weight': 81}),
#  ('C. Bakambu', 'DR Congo', {'weight': 81}),
#  ('W. Zaha', 'Ivory Coast', {'weight': 81}),
#  ('Bartra', 'Spain', {'weight': 81}),
#  ('S. Aurier', 'Ivory Coast', {'weight': 81}),
#  ('S. Coates', 'Uruguay', {'weight': 81}),
#  ('G. Krychowiak', 'Poland', {'weight': 81}),
#  ('K. Kampl', 'Slovenia', {'weight': 81}),
#  ('D. Lovren', 'Croatia', {'weight': 58}),
#  ('A. Yarmolenko', 'Ukraine', {'weight': 81}),
#  ('Y. Belhanda', 'Morocco', {'weight': 81}),
#  ('Mário Fernandes', 'Russia', {'weight': 81}),
#  ('R. Rodríguez', 'Switzerland', {'weight': 81}),
#  ('J. Corona', 'Mexico', {'weight': 81}),
#  ('J. Corona', 'United States', {'weight': 69}),
#  ('Mario Gaspar', 'Spain', {'weight': 81}),
#  ('Marcos Alonso', 'Spain', {'weight': 81}),
#  ('M. Götze', 'Germany', {'weight': 81}),
#  ('Illarramendi', 'Spain', {'weight': 81}),
#  ('De Marcos', 'Spain', {'weight': 81}),
#  ('C. Smalling', 'England', {'weight': 81}),
#  ('Iturraspe', 'Spain', {'weight': 81}),
#  ('J. Wilshere', 'England', {'weight': 81}),
#  ('S. Rudy', 'Germany', {'weight': 81}),
#  ('M. Lanzini', 'Argentina', {'weight': 81}),
#  ('R. Boudebouz', 'Algeria', {'weight': 81}),
#  ('Camacho', 'Spain', {'weight': 69}),
#  ('Paulinho', 'Brazil', {'weight': 70}),
#  ('Paulinho', 'Portugal', {'weight': 71}),
#  ('N. Kalinić', 'Croatia', {'weight': 81}),
#  ('Giuliano', 'Brazil', {'weight': 81}),
#  ('C. Benteke', 'Belgium', {'weight': 81}),
#  ('D. Perotti', 'Argentina', {'weight': 81}),
#  ('M. Parolo', 'Italy', {'weight': 81}),
#  ('K. Mitroglou', 'Greece', {'weight': 81}),
#  ('M. Sakho', 'France', {'weight': 81}),
#  ('A. Rami', 'France', {'weight': 81}),
#  ('S. Jovetić', 'Montenegro', {'weight': 81}),
#  ('S. Coleman', 'Republic of Ireland', {'weight': 81}),
#  ('S. Kjær', 'Denmark', {'weight': 81}),
#  ('M. Valbuena', 'France', {'weight': 81}),
#  ('D. Astori', 'Italy', {'weight': 81}),
#  ('K. Mirallas', 'Belgium', {'weight': 81}),
#  ('Raúl García', 'Spain', {'weight': 81}),
#  ('M. Škrtel', 'Slovakia', {'weight': 81}),
#  ('H. Ben Arfa', 'France', {'weight': 81}),
#  ('Dante', 'Brazil', {'weight': 81}),
#  ('A. Gignac', 'France', {'weight': 81}),
#  ('Gabi', 'Spain', {'weight': 58}),
#  ('G. Rodríguez', 'Argentina', {'weight': 73}),
#  ('G. Rodríguez', 'Mexico', {'weight': 69}),
#  ('D. Srna', 'Croatia', {'weight': 81}),
#  ('B. Schweinsteiger', 'Germany', {'weight': 81}),
#  ('W. Rooney', 'England', {'weight': 81}),
#  ('P. Mertesacker', 'Germany', {'weight': 81}),
#  ('T. Motta', 'Italy', {'weight': 81}),
#  ('Fernando Torres', 'Spain', {'weight': 81}),
#  ("S. Eto'o", 'Cameroon', {'weight': 81}),
#  ('M. Rashford', 'England', {'weight': 80}),
#  ('S. Milinković-Savić', 'Serbia', {'weight': 80}),
#  ('Y. Tielemans', 'Belgium', {'weight': 80}),
#  ('Jemerson', 'Brazil', {'weight': 80}),
#  ('N. Bentaleb', 'Algeria', {'weight': 80}),
#  ('Alex Telles', 'Brazil', {'weight': 80}),
#  ('J. Brandt', 'Germany', {'weight': 80}),
#  ('K. Demirbay', 'Germany', {'weight': 80}),
#  ('D. Rugani', 'Italy', {'weight': 80}),
#  ('Samu Castillejo', 'Spain', {'weight': 80}),
#  ('P. Zieliński', 'Poland', {'weight': 80}),
#  ('Ricardo Pereira', 'Portugal', {'weight': 80}),
#  ('Grimaldo', 'Spain', {'weight': 80}),
#  ('Fred', 'Brazil', {'weight': 80}),
#  ('J. Hector', 'Germany', {'weight': 80}),
#  ('E. Can', 'Germany', {'weight': 80}),
#  ('S. Kolašinac', 'Bosnia Herzegovina', {'weight': 80}),
#  ('A. Pléa', 'France', {'weight': 80}),
#  ('T. Stepanenko', 'Ukraine', {'weight': 80}),
#  ('O. Shatov', 'Russia', {'weight': 80}),
#  ('Leo Baptistao', 'Brazil', {'weight': 80}),
#  ('M. Nastasić', 'Serbia', {'weight': 80}),
#  ('Denis Suárez', 'Spain', {'weight': 80}),
#  ('M. Batshuayi', 'Belgium', {'weight': 80}),
#  ('J. Brooks', 'United States', {'weight': 80}),
#  ('Eric Botteghin', 'Brazil', {'weight': 80}),
#  ('T. Hazard', 'Belgium', {'weight': 80}),
#  ('V. Germain', 'France', {'weight': 80}),
#  ('L. Kurzawa', 'France', {'weight': 80}),
#  ('J. Iličić', 'Slovenia', {'weight': 80}),
#  ('K. Volland', 'Germany', {'weight': 80}),
#  ('Allan', 'Brazil', {'weight': 80}),
#  ('P. Hernández', 'Chile', {'weight': 80}),
#  ('D. Tadić', 'Serbia', {'weight': 80}),
#  ('L. Muriel', 'Colombia', {'weight': 80}),
#  ('Pablo Sarabia', 'Spain', {'weight': 80}),
#  ('A. Oxlade-Chamberlain', 'England', {'weight': 80}),
#  ('J. Guilavogui', 'France', {'weight': 80}),
#  ('O. Özyakup', 'Turkey', {'weight': 80}),
#  ('Y. Rakitskyi', 'Ukraine', {'weight': 80}),
#  ('Sergi Enrich', 'Spain', {'weight': 80}),
#  ('Hugo Mallo', 'Spain', {'weight': 80}),
#  ('D. Didavi', 'Germany', {'weight': 80}),
#  ('R. Soriano', 'Italy', {'weight': 80}),
#  ('A. Schürrle', 'Germany', {'weight': 80}),
#  ('M. Gonalons', 'France', {'weight': 80}),
#  ('R. Pereyra', 'Argentina', {'weight': 80}),
#  ('K. Vogt', 'Germany', {'weight': 80}),
#  ('F. Orellana', 'Chile', {'weight': 80}),
#  ('Maicon', 'Brazil', {'weight': 80}),
#  ('E. Salvio', 'Argentina', {'weight': 80}),
#  ('D. Blind', 'Netherlands', {'weight': 80}),
#  ('S. El Shaarawy', 'Italy', {'weight': 80}),
#  ('M. Antonio', 'England', {'weight': 80}),
#  ('Iago Falqué', 'Spain', {'weight': 80}),
#  ('S. Rondón', 'Venezuela', {'weight': 80}),
#  ('Daniel Carriço', 'Portugal', {'weight': 80}),
#  ('M. Schmelzer', 'Germany', {'weight': 80}),
#  ('J. McCarthy', 'Republic of Ireland', {'weight': 80}),
#  ('J. McCarthy', 'England', {'weight': 66}),
#  ('A. Dzagoev', 'Russia', {'weight': 80}),
#  ('Ganso', 'Brazil', {'weight': 80}),
#  ('F. Smolov', 'Russia', {'weight': 80}),
#  ('D. Welbeck', 'England', {'weight': 80}),
#  ('Luiz Gustavo', 'Brazil', {'weight': 80}),
#  ('Mikel San José', 'Spain', {'weight': 80}),
#  ('M. Darmian', 'Italy', {'weight': 80}),
#  ('R. Thomas', 'France', {'weight': 80}),
#  ('R. Thomas', 'New Zealand', {'weight': 71}),
#  ('I. Traoré', 'Guinea', {'weight': 80}),
#  ('I. Traoré', 'Ivory Coast', {'weight': 76}),
#  ('Sidnei', 'Brazil', {'weight': 80}),
#  ('J. Lens', 'Netherlands', {'weight': 80}),
#  ('Eder', 'Italy', {'weight': 80}),
#  ('Nacho Monreal', 'Spain', {'weight': 80}),
#  ('S. Bender', 'Germany', {'weight': 80}),
#  ('M. Díaz', 'Chile', {'weight': 80}),
#  ('M. Díaz', 'Argentina', {'weight': 74}),
#  ('A. Fernández', 'Argentina', {'weight': 80}),
#  ('A. Fernández', 'Uruguay', {'weight': 65}),
#  ('I. Piatti', 'Argentina', {'weight': 80}),
#  ('V. Birsa', 'Slovenia', {'weight': 80}),
#  ('Pedro León', 'Spain', {'weight': 80}),
#  ('K. Boateng', 'Ghana', {'weight': 80}),
#  ('Marcano', 'Spain', {'weight': 80}),
#  ('H. Moreno', 'Mexico', {'weight': 80}),
#  ('A. Candreva', 'Italy', {'weight': 80}),
#  ('D. Criscito', 'Italy', {'weight': 80}),
#  ('D. Wass', 'Denmark', {'weight': 80}),
#  ('Coke', 'Spain', {'weight': 80}),
#  ('A. Guardado', 'Mexico', {'weight': 80}),
#  ('J. dos Santos', 'Mexico', {'weight': 80}),
#  ('E. Lamela', 'Argentina', {'weight': 80}),
#  ('R. Bertrand', 'England', {'weight': 80}),
#  ('Jardel', 'Brazil', {'weight': 80}),
#  ('Jardel', 'Portugal', {'weight': 63}),
#  ('V. Denisov', 'Uzbekistan', {'weight': 80}),
#  ('D. Basta', 'Serbia', {'weight': 80}),
#  ('G. Cabral', 'Argentina', {'weight': 80}),
#  ('G. Paletta', 'Italy', {'weight': 80}),
#  ('T. Walcott', 'England', {'weight': 80}),
#  ('V. Ibišević', 'Bosnia Herzegovina', {'weight': 80}),
#  ('K. El Ahmadi', 'Morocco', {'weight': 80}),
#  ('S. Kalou', 'Ivory Coast', {'weight': 80}),
#  ('Manuel Fernandes', 'Portugal', {'weight': 80}),
#  ('A. Granqvist', 'Sweden', {'weight': 80}),
#  ('L. Podolski', 'Germany', {'weight': 80}),
#  ('Javi Fuego', 'Spain', {'weight': 80}),
#  ('F. Belluschi', 'Argentina', {'weight': 80}),
#  ('Kaká', 'Brazil', {'weight': 80}),
#  ('J. Milner', 'England', {'weight': 80}),
#  ('A. Hutchinson', 'Canada', {'weight': 80}),
#  ('M. Topal', 'Turkey', {'weight': 80}),
#  ('J. Mathieu', 'France', {'weight': 80}),
#  ('P. Jagielka', 'England', {'weight': 80}),
#  ('P. Evra', 'France', {'weight': 80}),
#  ('J. Defoe', 'England', {'weight': 80}),
#  ('M. Carrick', 'England', {'weight': 80}),
#  ('M. Almirón', 'Paraguay', {'weight': 79}),
#  ('Oyarzabal', 'Spain', {'weight': 79}),
#  ('Soares', 'Brazil', {'weight': 79}),
#  ('F. Andone', 'Romania', {'weight': 79}),
#  ('M. Acuña', 'Argentina', {'weight': 79}),
#  ('V. Lindelöf', 'Sweden', {'weight': 79}),
#  ('C. Lenglet', 'France', {'weight': 79}),
#  ('M. Dahoud', 'Germany', {'weight': 79}),
#  ('D. Zappacosta', 'Italy', {'weight': 79}),
#  ('N. Maksimović', 'Serbia', {'weight': 72}),
#  ('E. Rigoni', 'Argentina', {'weight': 79}),
#  ('I. Marcone', 'Argentina', {'weight': 79}),
#  ('L. López', 'Argentina', {'weight': 78}),
#  ('L. López', 'Mexico', {'weight': 65}),
#  ('A. Correa', 'Argentina', {'weight': 79}),
#  ('A. Correa', 'Colombia', {'weight': 65}),
#  ('K. Coman', 'France', {'weight': 79}),
#  ('W. Cyprien', 'France', {'weight': 79}),
#  ('Diego Llorente', 'Spain', {'weight': 79}),
#  ('Anderson Talisca', 'Brazil', {'weight': 79}),
#  ('L. Dendoncker', 'Belgium', {'weight': 79}),
#  ('M. Meyer', 'Germany', {'weight': 79}),
#  ('Gayà', 'Spain', {'weight': 79}),
#  ('S. Boufal', 'Morocco', {'weight': 79}),
#  ('M. Benassi', 'Italy', {'weight': 79}),
#  ('N. Tagliafico', 'Argentina', {'weight': 79}),
#  ('E. Hysaj', 'Albania', {'weight': 79}),
#  ('João Cancelo', 'Portugal', {'weight': 79}),
#  ('A. Romagnoli', 'Italy', {'weight': 79}),
#  ('Óliver Torres', 'Spain', {'weight': 79}),
#  ('H. Çalhanoğlu', 'Turkey', {'weight': 79}),
#  ('Gerard Moreno', 'Spain', {'weight': 79}),
#  ('B. Traoré', 'Burkina Faso', {'weight': 79}),
#  ('B. Traoré', 'France', {'weight': 66}),
#  ('L. Vietto', 'Argentina', {'weight': 79}),
#  ('L. Paredes', 'Argentina', {'weight': 79}),
#  ('M. Arnold', 'Germany', {'weight': 79}),
#  ('S. Gnabry', 'Germany', {'weight': 79}),
#  ('L. Shaw', 'England', {'weight': 79}),
#  ('E. Višća', 'Bosnia Herzegovina', {'weight': 79}),
#  ('Bernard', 'Brazil', {'weight': 79}),
#  ('D. Baselli', 'Italy', {'weight': 79}),
#  ('A. Milik', 'Poland', {'weight': 79}),
#  ('Bernat', 'Spain', {'weight': 79}),
#  ('W. Orban', 'Germany', {'weight': 79}),
#  ('Rubén Pardo', 'Spain', {'weight': 79}),
#  ('K. Zouma', 'France', {'weight': 79}),
#  ('C. Kramer', 'Germany', {'weight': 79}),
#  ('S. Vrsaljko', 'Croatia', {'weight': 79}),
#  ('Zé Luís', 'Cape Verde', {'weight': 79}),
#  ('J. Stones', 'England', {'weight': 79}),
#  ('J. Vestergaard', 'Denmark', {'weight': 79}),
#  ('Fernando', 'Brazil', {'weight': 79}),
#  ('M. Depay', 'Netherlands', {'weight': 79}),
#  ('F. Fernández', 'Argentina', {'weight': 79}),
#  ('F. Fernández', 'Paraguay', {'weight': 71}),
#  ('S. Sané', 'Senegal', {'weight': 79}),
#  ('S. Sané', 'Germany', {'weight': 65}),
#  ('N. Sansone', 'Italy', {'weight': 79}),
#  ('P. Ntep', 'France', {'weight': 79}),
#  ('F. Ghoulam', 'Algeria', {'weight': 79}),
#  ('J. Murillo', 'Colombia', {'weight': 60}),
#  ('J. Murillo', 'Venezuela', {'weight': 72}),
#  ('Gabriel Paulista', 'Brazil', {'weight': 79}),
#  ('V. Darida', 'Czech Republic', {'weight': 79}),
#  ('Cédric', 'Portugal', {'weight': 79}),
#  ('L. Tonelli', 'Italy', {'weight': 79}),
#  ('R. Saponara', 'Italy', {'weight': 79}),
#  ('D. Sidibé', 'France', {'weight': 79}),
#  ('Y. Konoplyanka', 'Ukraine', {'weight': 79}),
#  ('L. Digne', 'France', {'weight': 79}),
#  ('Paco Alcácer', 'Spain', {'weight': 79}),
#  ('Vicente Gómez', 'Spain', {'weight': 79}),
#  ('E. Çolak', 'Turkey', {'weight': 79}),
#  ('N. Jørgensen', 'Denmark', {'weight': 79}),
#  ('Oriol Romeu', 'Spain', {'weight': 79}),
#  ('Nolito', 'Spain', {'weight': 79}),
#  ('B. Martins Indi', 'Netherlands', {'weight': 79}),
#  ('M. Gabbiadini', 'Italy', {'weight': 79}),
#  ('P. Herrmann', 'Germany', {'weight': 66}),
#  ('F. Lejeune', 'France', {'weight': 79}),
#  ('J. Bruma', 'Netherlands', {'weight': 79}),
#  ('P. Jones', 'England', {'weight': 79}),
#  ('Keko', 'Spain', {'weight': 79}),
#  ('H. Pérez', 'Paraguay', {'weight': 79}),
#  ('Jaume Costa', 'Spain', {'weight': 79}),
#  ('Escudero', 'Spain', {'weight': 79}),
#  ('Y. Mallı', 'Turkey', {'weight': 79}),
#  ('A. Kokorin', 'Russia', {'weight': 79}),
#  ('S. Corchia', 'France', {'weight': 79}),
#  ('J. Kucka', 'Slovakia', {'weight': 79}),
#  ('A. Ljajić', 'Serbia', {'weight': 79}),
#  ('Canales', 'Spain', {'weight': 79}),
#  ('Balenziaga', 'Spain', {'weight': 79}),
#  ('W. Bony', 'Ivory Coast', {'weight': 79}),
#  ('B. Hübner', 'Germany', {'weight': 79}),
#  ('F. Coquelin', 'France', {'weight': 79}),
#  ('Jonathas', 'Brazil', {'weight': 79}),
#  ('G. Bou', 'Argentina', {'weight': 79}),
#  ('S. Doumbia', 'Ivory Coast', {'weight': 59}),
#  ('C. Noboa', 'Ecuador', {'weight': 79}),
#  ('I. Smolnikov', 'Russia', {'weight': 79}),
#  ('Maurício', 'Brazil', {'weight': 76}),
#  ('M. Fabián', 'Mexico', {'weight': 79}),
#  ('D. Drinkwater', 'England', {'weight': 79}),
#  ('A. Kolarov', 'Serbia', {'weight': 79}),
#  ('Mariano', 'Brazil', {'weight': 79}),
#  ('Mariano', 'Dominican Republic', {'weight': 76}),
#  ('S. Feghouli', 'Algeria', {'weight': 79}),
#  ('K. Papadopoulos', 'Greece', {'weight': 79}),
#  ('S. Wagner', 'Germany', {'weight': 79}),
#  ('P. Piatti', 'Argentina', {'weight': 79}),
#  ('C. Yacob', 'Argentina', {'weight': 79}),
#  ('A. Ogbonna', 'Italy', {'weight': 79}),
#  ('N. Amrabat', 'Morocco', {'weight': 79}),
#  ('W. Vainqueur', 'France', {'weight': 79}),
#  ('Antunes', 'Portugal', {'weight': 79}),
#  ('S. Prödl', 'Austria', {'weight': 79}),
#  ('S. Tasci', 'Germany', {'weight': 79}),
#  ('F. Johnson', 'United States', {'weight': 79}),
#  ('Bojan', 'Spain', {'weight': 79}),
#  ('M. Fellaini', 'Belgium', {'weight': 79}),
#  ('P. Wernbloom', 'Sweden', {'weight': 79}),
#  ('A. Ayew', 'Ghana', {'weight': 79}),
#  ('W. Reid', 'New Zealand', {'weight': 79}),
#  ('Lucas Leiva', 'Brazil', {'weight': 79}),
#  ('Z. Junuzović', 'Austria', {'weight': 79}),
#  ('C. Ansaldi', 'Argentina', {'weight': 79}),
#  ('V. Moses', 'Nigeria', {'weight': 79}),
#  ('D. Zurutuza', 'France', {'weight': 79}),
#  ('D. Valeri', 'Argentina', {'weight': 79}),
#  ('José Fonte', 'Portugal', {'weight': 79}),
#  ('N. Şahin', 'Turkey', {'weight': 79}),
#  ('G. dos Santos', 'Mexico', {'weight': 79}),
#  ('R. Shawcross', 'England', {'weight': 79}),
#  ('J. Evans', 'Northern Ireland', {'weight': 79}),
#  ('A. Gyan', 'Ghana', {'weight': 79}),
#  ('Y. Cabaye', 'France', {'weight': 79}),
#  ('Danilo', 'Brazil', {'weight': 71}),
#  ('Danilo', 'Belgium', {'weight': 71}),
#  ('N. Pareja', 'Argentina', {'weight': 79}),
#  ('S. Radu', 'Romania', {'weight': 79}),
#  ('D. Abraham', 'Argentina', {'weight': 79}),
#  ('M. Krohn-Dehli', 'Denmark', {'weight': 79}),
#  ('Jurado', 'Spain', {'weight': 79}),
#  ('B. Gomis', 'France', {'weight': 79}),
#  ('H. Herrera', 'Mexico', {'weight': 79}),
#  ('Luisão', 'Brazil', {'weight': 79}),
#  ('V. Berezutskiy', 'Russia', {'weight': 79}),
#  ('I. Denisov', 'Russia', {'weight': 79}),
#  ('A. Samedov', 'Russia', {'weight': 79}),
#  ('Xabi Prieto', 'Spain', {'weight': 79}),
#  ('Negredo', 'Spain', {'weight': 79}),
#  ('P. Zabaleta', 'Argentina', {'weight': 79}),
#  ('Vágner Love', 'Brazil', {'weight': 79}),
#  ('D. Baier', 'Germany', {'weight': 79}),
#  ('T. Rosický', 'Czech Republic', {'weight': 79}),
#  ('A. Pirlo', 'Italy', {'weight': 79}),
#  ('G. Barry', 'England', {'weight': 79}),
#  ('E. Belözoğlu', 'Turkey', {'weight': 79}),
#  ('André Silva', 'Portugal', {'weight': 78}),
#  ('K. Dolberg', 'Denmark', {'weight': 78}),
#  ('Yeray', 'Spain', {'weight': 65}),
#  ('C. Pulisic', 'United States', {'weight': 78}),
#  ('L. Tousart', 'France', {'weight': 78}),
#  ('V. Koziello', 'France', {'weight': 78}),
#  ('N. Radoja', 'Serbia', {'weight': 78}),
#  ('V. Rongier', 'France', {'weight': 78}),
#  ('O. Al Soma', 'Syria', {'weight': 78}),
#  ('F. Cervi', 'Argentina', {'weight': 78}),
#  ('Jorge Meré', 'Spain', {'weight': 78}),
#  ('Jony', 'Spain', {'weight': 78}),
#  ('R. Karsdorp', 'Netherlands', {'weight': 78}),
#  ('Dani Ceballos', 'Spain', {'weight': 78}),
#  ('H. Lozano', 'Mexico', {'weight': 78}),
#  ('Raúl', 'Brazil', {'weight': 78}),
#  ('M. Vecino', 'Uruguay', {'weight': 78}),
#  ('A. Sanabria', 'Paraguay', {'weight': 78}),
#  ('R. Battaglia', 'Argentina', {'weight': 78}),
#  ('J. Izquierdo', 'Colombia', {'weight': 78}),
#  ('T. Bongonda', 'Belgium', {'weight': 78}),
#  ('Rúben Semedo', 'Portugal', {'weight': 78}),
#  ('Rafa', 'Portugal', {'weight': 78}),
#  ('Morales', 'Spain', {'weight': 78}),
#  ('Capa', 'Spain', {'weight': 78}),
#  ('D. Zapata', 'Colombia', {'weight': 78}),
#  ('D. Benedetto', 'Argentina', {'weight': 78}),
#  ('A. Ruiz', 'Argentina', {'weight': 78}),
#  ('D. Laxalt', 'Uruguay', {'weight': 78}),
#  ('D. Origi', 'Belgium', {'weight': 78}),
#  ('N. Stark', 'Germany', {'weight': 78}),
#  ('Hernâni', 'Portugal', {'weight': 78}),
#  ('Iuri Medeiros', 'Portugal', {'weight': 78}),
#  ('Bruno Fernandes', 'Portugal', {'weight': 78}),
#  ('R. Gagliardini', 'Italy', {'weight': 78}),
#  ('Pedro Santos', 'Portugal', {'weight': 78}),
#  ('Carles Gil', 'Spain', {'weight': 78}),
#  ('Paulo Oliveira', 'Portugal', {'weight': 78}),
#  ('A. Szymanowski', 'Argentina', {'weight': 78}),
#  ('Bruno Peres', 'Brazil', {'weight': 78}),
#  ('K. Wimmer', 'Austria', {'weight': 78}),
#  ('F. Kostić', 'Serbia', {'weight': 78}),
#  ('A. Samaris', 'Greece', {'weight': 78}),
#  ('A. Doucouré', 'France', {'weight': 78}),
#  ('G. Pizarro', 'Argentina', {'weight': 78}),
#  ('J. Martínez', 'Venezuela', {'weight': 78}),
#  ('J. Martínez', 'Argentina', {'weight': 74}),
#  ('J. Martínez', 'Mexico', {'weight': 66}),
#  ('J. Martínez', 'Colombia', {'weight': 63}),
#  ('M. Ginter', 'Germany', {'weight': 78}),
#  ('J. Lingard', 'England', {'weight': 78}),
#  ('M. Weiser', 'Germany', {'weight': 78}),
#  ('D. Cheryshev', 'Russia', {'weight': 78}),
#  ('Bigas', 'Spain', {'weight': 78}),
#  ('D. Heintz', 'Germany', {'weight': 78}),
#  ('B. Davies', 'Wales', {'weight': 78}),
#  ('B. Davies', 'England', {'weight': 63}),
#  ('L. Castro', 'Argentina', {'weight': 78}),
#  ('L. Castro', 'Colombia', {'weight': 70}),
#  ('J. Ward-Prowse', 'England', {'weight': 78}),
#  ('T. Inui', 'Japan', {'weight': 78}),
#  ('M. Sabitzer', 'Austria', {'weight': 78}),
#  ('B. Mendy', 'France', {'weight': 78}),
#  ('R. Jiménez', 'Mexico', {'weight': 78}),
#  ('E. Sala', 'Argentina', {'weight': 78}),
#  ('M. Niang', 'France', {'weight': 78}),
#  ('K. Fortounis', 'Greece', {'weight': 78}),
#  ('Pozuelo', 'Spain', {'weight': 78}),
#  ('Joãozinho', 'Brazil', {'weight': 78}),
#  ('Joãozinho', 'Portugal', {'weight': 70}),
#  ('P. Kadeřábek', 'Czech Republic', {'weight': 78}),
#  ('T. Vilhena', 'Netherlands', {'weight': 78}),
#  ('M. Elyounoussi', 'Norway', {'weight': 78}),
#  ('L. Bittencourt', 'Germany', {'weight': 78}),
#  ('Sergi Darder', 'Spain', {'weight': 78}),
#  ('D. Demme', 'Germany', {'weight': 78}),
#  ('V. Eysseric', 'France', {'weight': 78}),
#  ('G. Ramírez', 'Uruguay', {'weight': 78}),
#  ('G. Ramírez', 'Argentina', {'weight': 66}),
#  ('David López', 'Spain', {'weight': 78}),
#  ('M. Badelj', 'Croatia', {'weight': 78}),
#  ('A. Mandi', 'Algeria', {'weight': 78}),
#  ('Ismaily', 'Brazil', {'weight': 78}),
#  ('L. Teodorczyk', 'Poland', {'weight': 78}),
#  ('N. Chadli', 'Belgium', {'weight': 78}),
#  ('S. Rode', 'Germany', {'weight': 78}),
#  ('M. van Ginkel', 'Netherlands', {'weight': 78}),
#  ('André André', 'Portugal', {'weight': 78}),
#  ('J. Guidetti', 'Sweden', {'weight': 78}),
#  ('V. Aboubakar', 'Cameroon', {'weight': 78}),
#  ('C. Aránguiz', 'Chile', {'weight': 78}),
#  ('Raúl Navas', 'Spain', {'weight': 78}),
#  ('K. Mbodj', 'Senegal', {'weight': 78}),
#  ('Rodrigo', 'Spain', {'weight': 70}),
#  ('Rodrigo', 'Brazil', {'weight': 59}),
#  ('R. Funes Mori', 'Argentina', {'weight': 77}),
#  ('M. Höger', 'Germany', {'weight': 78}),
#  ('N. Lodeiro', 'Uruguay', {'weight': 78}),
#  ('D. Caligiuri', 'Italy', {'weight': 78}),
#  ('S. Verdi', 'Italy', {'weight': 78}),
#  ('E. Pérez', 'Argentina', {'weight': 78}),
#  ('E. Pérez', 'Mexico', {'weight': 70}),
#  ('T. Gutiérrez', 'Colombia', {'weight': 78}),
#  ('C. Austin', 'England', {'weight': 78}),
#  ('G. Gillet', 'Belgium', {'weight': 78}),
#  ('A. Townsend', 'England', {'weight': 78}),
#  ('T. Vermaelen', 'Belgium', {'weight': 78}),
#  ('I. Abate', 'Italy', {'weight': 78}),
#  ('J. Briand', 'France', {'weight': 78}),
#  ('J. Toulalan', 'France', {'weight': 78}),
#  ('Bruno Alves', 'Portugal', {'weight': 78}),
#  ('Joaquín', 'Spain', {'weight': 67}),
#  ('S. Bocchetti', 'Italy', {'weight': 78}),
#  ('Muniain', 'Spain', {'weight': 78}),
#  ('C. Gentner', 'Germany', {'weight': 78}),
#  ('F. Gago', 'Argentina', {'weight': 78}),
#  ('R. van Persie', 'Netherlands', {'weight': 78}),
#  ('M. Layún', 'Mexico', {'weight': 78}),
#  ('N. Nkoulou', 'Cameroon', {'weight': 78}),
#  ('S. Ignashevich', 'Russia', {'weight': 78}),
#  ('J. Terry', 'England', {'weight': 78}),
#  ('P. Skjelbred', 'Norway', {'weight': 78}),
#  ('I. Afellay', 'Netherlands', {'weight': 78}),
#  ('N. Lombaerts', 'Belgium', {'weight': 78}),
#  ('Granero', 'Spain', {'weight': 78}),
#  ('J. Baumgartlinger', 'Austria', {'weight': 78}),
#  ('R. Palacio', 'Argentina', {'weight': 78}),
#  ('Miguel Lopes', 'Portugal', {'weight': 78}),
#  ('Susaeta', 'Spain', {'weight': 73}),
#  ('Hilton', 'Brazil', {'weight': 78}),
#  ("Y. M'Vila", 'France', {'weight': 78}),
#  ('Borja Bastón', 'Spain', {'weight': 78}),
#  ('J. Farfán', 'Peru', {'weight': 78}),
#  ('J. Montero', 'Ecuador', {'weight': 78}),
#  ('M. Ruben', 'Argentina', {'weight': 78}),
#  ('M. Borriello', 'Italy', {'weight': 78}),
#  ('Eliseu', 'Portugal', {'weight': 78}),
#  ('Mosquera', 'Spain', {'weight': 78}),
#  ('Rochina', 'Spain', {'weight': 78}),
#  ('B. Džemaili', 'Switzerland', {'weight': 78}),
#  ("A. N'Diaye", 'Senegal', {'weight': 78}),
#  ("A. N'Diaye", 'France', {'weight': 63}),
#  ('Y. Gourcuff', 'France', {'weight': 78}),
#  ('K. Asamoah', 'Ghana', {'weight': 78}),
#  ('R. Bobadilla', 'Paraguay', {'weight': 78}),
#  ('R. Hamouma', 'France', {'weight': 78}),
#  ('M. Fernández', 'Chile', {'weight': 78}),
#  ('K. Honda', 'Japan', {'weight': 78}),
#  ('A. Dzyuba', 'Russia', {'weight': 78}),
#  ('B. Yılmaz', 'Turkey', {'weight': 78}),
#  ('J. Holebas', 'Greece', {'weight': 78}),
#  ('Javi García', 'Spain', {'weight': 78}),
#  ('Fontàs', 'Spain', {'weight': 78}),
#  ('C. Tosun', 'Turkey', {'weight': 63}),
#  ('S. Dann', 'England', {'weight': 78}),
#  ('Y. Bolasie', 'DR Congo', {'weight': 78}),
#  ('D. Glushakov', 'Russia', {'weight': 78}),
#  ('K. Trippier', 'England', {'weight': 78}),
#  ('J. Cork', 'England', {'weight': 78}),
#  ('A. Ramos', 'Colombia', {'weight': 78}),
#  ('A. Ramos', 'Chile', {'weight': 69}),
#  ('M. Bradley', 'United States', {'weight': 78}),
#  ('Souza', 'Brazil', {'weight': 70}),
#  ('T. Mangani', 'France', {'weight': 78}),
#  ('Rafael', 'Brazil', {'weight': 78}),
#  ('Adriano', 'Brazil', {'weight': 78}),
#  ('B. Mee', 'England', {'weight': 78}),
#  ('C. Dempsey', 'United States', {'weight': 78}),
#  ('H. Briceldo', 'Chile', {'weight': 77}),
#  ('Juanmi', 'Spain', {'weight': 77}),
#  ('N. Subotić', 'Serbia', {'weight': 77}),
#  ('N. Blandi', 'Argentina', {'weight': 77}),
#  ('P. De Blasis', 'Argentina', {'weight': 77}),
#  ('M. Phillips', 'Scotland', {'weight': 77}),
#  ('M. Phillips', 'England', {'weight': 55}),
#  ('M. Braithwaite', 'Denmark', {'weight': 77}),
#  ('D. Reyes', 'Mexico', {'weight': 77}),
#  ('Iván Ramis', 'Spain', {'weight': 77}),
#  ('V. Behrami', 'Switzerland', {'weight': 77}),
#  ('G. Hoarau', 'France', {'weight': 77}),
#  ('T. Barnetta', 'Switzerland', {'weight': 77}),
#  ('E. Choupo-Moting', 'Cameroon', {'weight': 77}),
#  ('Jesé', 'Spain', {'weight': 77}),
#  ('J. Pinola', 'Argentina', {'weight': 77}),
#  ('Luís Hernández', 'Spain', {'weight': 77}),
#  ('Jonny', 'Spain', {'weight': 77}),
#  ('M. Carcela-González', 'Morocco', {'weight': 77}),
#  ('L. Pavoletti', 'Italy', {'weight': 77}),
#  ('D. Bonera', 'Italy', {'weight': 77}),
#  ('Dalbert', 'Brazil', {'weight': 77}),
#  ('G. McAuley', 'Northern Ireland', {'weight': 77}),
#  ('A. Halilović', 'Croatia', {'weight': 77}),
#  ('N. Amiri', 'Germany', {'weight': 77}),
#  ('I. Popov', 'Bulgaria', {'weight': 77}),
#  ('N. Burdisso', 'Argentina', {'weight': 77}),
#  ('W. Hoolahan', 'Republic of Ireland', {'weight': 77}),
#  ('Sidney Pessinho', 'Brazil', {'weight': 77}),
#  ('A. Potuk', 'Turkey', {'weight': 77}),
#  ('F. Pogba', 'Guinea', {'weight': 77}),
#  ('A. Carrillo', 'Peru', {'weight': 77}),
#  ('M. Andreolli', 'Italy', {'weight': 77}),
#  ('O. Duarte', 'Costa Rica', {'weight': 77}),
#  ('O. Duarte', 'Colombia', {'weight': 63}),
#  ('Rúben Neves', 'Portugal', {'weight': 77}),
#  ('Jozabed', 'Spain', {'weight': 77}),
#  ('P. Pérez', 'Argentina', {'weight': 77}),
#  ('Gazzolisco', 'Brazil', {'weight': 77}),
#  ('M. Gamonales', 'Chile', {'weight': 77}),
#  ('Ronaldo Esler', 'Brazil', {'weight': 77}),
#  ('Vitor Hugo', 'Brazil', {'weight': 77}),
#  ('T. Arslan', 'Turkey', {'weight': 77}),
#  ('J. Veretout', 'France', {'weight': 77}),
#  ('D. Pabón', 'Colombia', {'weight': 77}),
#  ('Juan Jesus', 'Brazil', {'weight': 77}),
#  ('E. Durm', 'Germany', {'weight': 77}),
#  ('G. Imbula', 'France', {'weight': 77}),
#  ('Luis Alberto', 'Spain', {'weight': 77}),
#  ('M. Risse', 'Germany', {'weight': 77}),
#  ('Luís Neto', 'Portugal', {'weight': 77}),
#  ('B. Ruíz', 'Costa Rica', {'weight': 77}),
#  ('Jordi Amat', 'Spain', {'weight': 77}),
#  ('J. Ďurica', 'Slovakia', {'weight': 77}),
#  ('B. Stambouli', 'France', {'weight': 77}),
#  ('C. Kaboré', 'Burkina Faso', {'weight': 77}),
#  ('A. Rukavina', 'Serbia', {'weight': 77}),
#  ('P. Kimpembe', 'France', {'weight': 77}),
#  ('Sergio León', 'Spain', {'weight': 77}),
#  ('M. Elneny', 'Egypt', {'weight': 77}),
#  ('D. Torres', 'Colombia', {'weight': 77}),
#  ('S. Okazaki', 'Japan', {'weight': 77}),
#  ('C. Jallet', 'France', {'weight': 77}),
#  ('Y. Salibur', 'France', {'weight': 77}),
#  ('N. Redmond', 'England', {'weight': 77}),
#  ('A. Song', 'Cameroon', {'weight': 77}),
#  ('Andreas Pereira', 'Brazil', {'weight': 77}),
#  ('Castán', 'Brazil', {'weight': 77}),
#  ('K. Huntelaar', 'Netherlands', {'weight': 77}),
#  ('T. Partey', 'Ghana', {'weight': 77}),
#  ('Mário Rui', 'Portugal', {'weight': 77}),
#  ('André Pinto', 'Portugal', {'weight': 77}),
#  ('L. Rémy', 'France', {'weight': 77}),
#  ('Badou Ndiaye', 'Senegal', {'weight': 77}),
#  ('A. Bertolacci', 'Italy', {'weight': 77}),
#  ('A. Živković', 'Serbia', {'weight': 77}),
#  ('M. Lemina', 'Gabon', {'weight': 77}),
#  ('D. Da Silva', 'France', {'weight': 77}),
#  ('T. Rincón', 'Venezuela', {'weight': 77}),
#  ('Y. Ōsako', 'Japan', {'weight': 77}),
#  ('J. King', 'Norway', {'weight': 77}),
#  ('J. King', 'England', {'weight': 63}),
#  ('Bastos', 'Angola', {'weight': 77}),
#  ('Bastos', 'Spain', {'weight': 62}),
#  ('J. Quintero', 'Colombia', {'weight': 68}),
#  ('J. Quintero', 'Ecuador', {'weight': 61}),
#  ('A. Meier', 'Germany', {'weight': 77}),
#  ('G. Nkoudou', 'France', {'weight': 77}),
#  ('Montoya', 'Spain', {'weight': 77}),
#  ('L. Dalsaro', 'Chile', {'weight': 77}),
#  ('K. Källström', 'Sweden', {'weight': 77}),
#  ('M. Politano', 'Italy', {'weight': 77}),
#  ('M. Zárate', 'Argentina', {'weight': 77}),
#  ('G. İnler', 'Switzerland', {'weight': 77}),
#  ('M. Albrighton', 'England', {'weight': 77}),
#  ('A. Gray', 'England', {'weight': 77}),
#  ('Marçal', 'Brazil', {'weight': 77}),
#  ('A. Gamberini', 'Italy', {'weight': 77}),
#  ('S. Widmer', 'Switzerland', {'weight': 77}),
#  ('J. Aquino', 'Mexico', {'weight': 77}),
#  ('S. Gentiletti', 'Argentina', {'weight': 77}),
#  ('C. Sánchez', 'Colombia', {'weight': 77}),
#  ('C. Sánchez', 'Uruguay', {'weight': 77}),
#  ('C. Sánchez', 'Argentina', {'weight': 60}),
#  ('M. Sissoko', 'France', {'weight': 77}),
#  ('G. Defrel', 'France', {'weight': 77}),
#  ('R. Martínez', 'Argentina', {'weight': 77}),
#  ('J. Geis', 'Germany', {'weight': 77}),
#  ('P. Verhaegh', 'Netherlands', {'weight': 77}),
#  ('H. Nordtveit', 'Norway', {'weight': 77}),
#  ('R. Steffen', 'Switzerland', {'weight': 77}),
#  ('M. Hasebe', 'Japan', {'weight': 77}),
#  ('J. Córdoba', 'Colombia', {'weight': 77}),
#  ('L. Schøne', 'Denmark', {'weight': 77}),
#  ('R. Rosales', 'Venezuela', {'weight': 77}),
#  ('N. De Préville', 'France', {'weight': 77}),
#  ('Marcos Llorente', 'Spain', {'weight': 77}),
#  ('Y. Chará', 'Colombia', {'weight': 77}),
#  ('Wallace', 'Brazil', {'weight': 77}),
#  ('J. Toornstra', 'Netherlands', {'weight': 77}),
#  ('Pedro Obiang', 'Spain', {'weight': 77}),
#  ('V. Chiricheş', 'Romania', {'weight': 77}),
#  ('S. Hanni', 'Algeria', {'weight': 77}),
#  ('C. Théréau', 'France', {'weight': 77}),
#  ('D. Rolán', 'Uruguay', {'weight': 77}),
#  ('Pedro Henrique', 'Brazil', {'weight': 64}),
#  ('Bruno Gaspar', 'Portugal', {'weight': 77}),
#  ('Cristian Tello', 'Spain', {'weight': 77}),
#  ('Formosandrinho', 'Brazil', {'weight': 77}),
#  ('S. Haller', 'France', {'weight': 77}),
#  ('Claudio Coíntra', 'Brazil', {'weight': 77}),
#  ('M. Uth', 'Germany', {'weight': 77}),
#  ('F. Sørensen', 'Denmark', {'weight': 77}),
#  ('J. Van Damme', 'Belgium', {'weight': 77}),
#  ('L. Britton', 'England', {'weight': 77}),
#  ('V. Grifo', 'Italy', {'weight': 77}),
#  ('T. Cairney', 'Scotland', {'weight': 77}),
#  ('Sandro', 'Spain', {'weight': 77}),
#  ('Sandro', 'Brazil', {'weight': 75}),
#  ('F. Delph', 'England', {'weight': 77}),
#  ('J. Veltman', 'Netherlands', {'weight': 77}),
#  ('A. Dragović', 'Austria', {'weight': 77}),
#  ('D. Pröpper', 'Netherlands', {'weight': 77}),
#  ('L. Cattermole', 'England', {'weight': 77}),
#  ('Luisinho', 'Portugal', {'weight': 77}),
#  ('Luisinho', 'Brazil', {'weight': 66}),
#  ('Vitinho', 'Brazil', {'weight': 71}),
#  ('Z. Feddal', 'Morocco', {'weight': 77}),
#  ('Vallejo', 'Spain', {'weight': 77}),
#  ('Rafael Carioca', 'Brazil', {'weight': 77}),
#  ('David García', 'Spain', {'weight': 75}),
#  ('J. Allen', 'Wales', {'weight': 77}),
#  ('J. Allen', 'England', {'weight': 65}),
#  ('J. Allen', 'United States', {'weight': 61}),
#  ('A. Younes', 'Germany', {'weight': 77}),
#  ('L. Hernández', 'France', {'weight': 77}),
#  ('L. Hernández', 'Mexico', {'weight': 69}),
#  ('A. Mooy', 'Australia', {'weight': 77}),
#  ('Campaña', 'Spain', {'weight': 77}),
#  ('Vieirinha', 'Portugal', {'weight': 77}),
#  ('Wendell', 'Brazil', {'weight': 77}),
#  ('Y. Sabaly', 'France', {'weight': 77}),
#  ('J. Hofmann', 'Germany', {'weight': 77}),
#  ('Timor', 'Spain', {'weight': 77}),
#  ('H. Arter', 'Republic of Ireland', {'weight': 77}),
#  ('M. Lemos', 'Uruguay', {'weight': 77}),
#  ('Louri Beretta', 'Brazil', {'weight': 77}),
#  ('F. Caicedo', 'Ecuador', {'weight': 77}),
#  ('S. Sturaro', 'Italy', {'weight': 77}),
#  ('Pablo Fornals', 'Spain', {'weight': 77}),
#  ('Sergi Gómez', 'Spain', {'weight': 77}),
#  ('P. Jansson', 'Sweden', {'weight': 77}),
#  ('A. Berezutskiy', 'Russia', {'weight': 77}),
#  ('L. Pellegrini', 'Italy', {'weight': 77}),
#  ('A. Masiello', 'Italy', {'weight': 77}),
#  ('M. Ekici', 'Turkey', {'weight': 77}),
#  ('A. Nyom', 'Cameroon', {'weight': 77}),
#  ('F. Roncaglia', 'Argentina', {'weight': 77}),
#  ('P. Hidalgado', 'Chile', {'weight': 77}),
#  ('J. De Guzmán', 'Netherlands', {'weight': 77}),
#  ('M. Gradel', 'Ivory Coast', {'weight': 77}),
#  ('M. Debuchy', 'France', {'weight': 77}),
#  ('S. Terodde', 'Germany', {'weight': 77}),
#  ('Recio', 'Spain', {'weight': 77}),
#  ('R. Zobnin', 'Russia', {'weight': 77}),
#  ('Fábio Coentrão', 'Portugal', {'weight': 77}),
#  ('J. Campbell', 'Costa Rica', {'weight': 77}),
#  ('J. Campbell', 'United States', {'weight': 66}),
#  ('C. Stuani', 'Uruguay', {'weight': 77}),
#  ('A. Veznera', 'Chile', {'weight': 77}),
#  ('J. Willems', 'Netherlands', {'weight': 77}),
#  ('A. Lennon', 'England', {'weight': 77}),
#  ('T. Lagardo', 'Chile', {'weight': 77}),
#  ...]

# %% [markdown]
# Since there are so many players and clubs, the graph does not fully connect. The cell below captures the largest connected component that we will continue to study.

# %%
# Capture Biggest connected graph and test
B = max((B.subgraph(c) for c in nx.connected_components(B)), key=len)
nx.is_connected(B)
# Out:
# True

# %% [markdown]
# Capture all player and nodes from the graph.
#
# This will be used to color code players and clubs for improved visuals.

# %%
player_nodes = set(n for n,d in B.nodes(data=True) if d['bipartite']==0)
club_nodes = set(B) - player_nodes

# %% [markdown]
# # Island method

# %%
def trim_edges(g, weight=1):
    g2 = nx.Graph()
    
    for f, to, edata in g.edges(data=True):
        if edata['weight'] > weight:
            g2.add_edge(f,to,weight=edata['weight'])
            
    return g2

# %%
def island_method(g, iterations=6):
    weights= [edata['weight'] for f,to,edata in g.edges(data=True)]
    mn=int(min(weights))
    mx=int(max(weights))
    
    #compute the size of the step, so we get a reasonable step in iterations
    step=int((mx-mn)/iterations)
    
    return [[threshold, trim_edges(g, threshold)] for threshold in range(mn,mx,step)]

# %%
cc = sorted((B.subgraph(c) for c in nx.connected_components(B)), key = len, reverse=True)[0]
#    sorted(nx.connected_component_subgraphs(team_win), key = len, reverse=True)[0]
islands = island_method(cc)
 
for i in islands:
    # print the threshold level, size of the graph, and number of connected components
    print (i[0], len(i[1]), len(sorted((i[1].subgraph(c) for c in nx.connected_components(i[1])), key = len, reverse=True)))
# Out:
# 46 12687 1
# 54 12065 5
# 62 9246 13
# 70 3648 39
# 78 558 40
# 86 50 15

# %% [markdown]
# We performed 6 iterations on the biggest connected graph from the entire dataset.
# This lead us to 6 _islands_ each containing smaller number of players but of higher overall performance.
#
# ** Edge Weight = Player Performance Score (_Overall_)**
#
#
# We will visualize only on the last two, and conduct an in-depth analysis on **the smallest island with 59 nodes total, 45 players and 14 clubs.**

# %% [markdown]
# # Graph Visualization
#
#
# First attempt in visualizing the 2nd-to-smallest island with 716 total nodes. The picture may render hard to read. This should improve with moving onto the smallest island.
#
# - **Blue = Player**
# - **Green = Nationality**
# - **Node Size = Degree**

# %% [markdown]
# ## 2nd Smallest Island Visualization

# %%
# Create a list of colors based on the node name (players vs countries)

node_colors = []
for n in islands[4][1].nodes(data=True):
    if n[0] in player_nodes:
        node_colors.append('#3366ff')
    else:
        node_colors.append('#40bf80')

# %%
plt.rcParams['figure.figsize'] = [16, 12]

pos = nx.spring_layout(islands[4][1], k=2) # k=2 values helps spread the nodes

# Degree calculations to denote the size of nodes
degree = dict(nx.degree(islands[4][1]))


degree_graph = nx.draw_networkx(islands[4][1], 
                                pos=pos,
                                node_color=node_colors,
                                node_size=np.multiply(list(degree.values()), 400), # multiply degree by 400 for better resolution
                                with_labels=True, 
                                width=0.2)

# Remove axis
limits=plt.axis('off')

# %% [markdown]
# ## Smallest Island Visualization

# %%
node_colors = []

for n in islands[5][1].nodes(data=True):
    if n[0] in player_nodes:
        node_colors.append('#3366ff')
    else:
        node_colors.append('#40bf80')

# %%
plt.rcParams['figure.figsize'] = [16, 12]

pos = nx.spring_layout(islands[5][1], k=2)

degree = dict(nx.degree(islands[5][1]))

degree_graph = nx.draw_networkx(islands[5][1], 
                                pos=pos,
                                node_color=node_colors,
                                #edge_color='#b3b3b3',   
                                node_size=np.multiply(list(degree.values()), 400), 
                                with_labels=True, 
                                width=0.2)

# remove axis
limits=plt.axis('off')

# %% [markdown]
# In the graph above we can see some of the most renowned clubs and players.
# Very few of the players in the graph played for more than one of the listed clubs.

# %% [markdown]
# ## FOR CLUBS

# %%
B1 = nx.Graph()
B1.add_nodes_from(fifa['Name'], bipartite=0)
B1.add_nodes_from(fifa['Club'], bipartite=1)

weighted_edges1 = fifa[['Name', 'Club','Overall']].T
weighted_edges1.T.values.tolist()
# Out:
# [['Cristiano Ronaldo', 'Real Madrid CF', 94],
#  ['L. Messi', 'FC Barcelona', 93],
#  ['Neymar', 'Paris Saint-Germain', 92],
#  ['L. Suárez', 'FC Barcelona', 92],
#  ['R. Lewandowski', 'FC Bayern Munich', 91],
#  ['E. Hazard', 'Chelsea', 90],
#  ['T. Kroos', 'Real Madrid CF', 90],
#  ['G. Higuaín', 'Juventus', 90],
#  ['Sergio Ramos', 'Real Madrid CF', 90],
#  ['K. De Bruyne', 'Manchester City', 89],
#  ['A. Sánchez', 'Arsenal', 89],
#  ['L. Modrić', 'Real Madrid CF', 89],
#  ['G. Bale', 'Real Madrid CF', 89],
#  ['S. Agüero', 'Manchester City', 89],
#  ['G. Chiellini', 'Juventus', 89],
#  ['P. Dybala', 'Juventus', 88],
#  ['A. Griezmann', 'Atlético Madrid', 88],
#  ['Thiago', 'FC Bayern Munich', 88],
#  ['P. Aubameyang', 'Borussia Dortmund', 88],
#  ['L. Bonucci', 'Milan', 88],
#  ['J. Boateng', 'FC Bayern Munich', 88],
#  ['D. Godín', 'Atlético Madrid', 88],
#  ['M. Hummels', 'FC Bayern Munich', 88],
#  ['M. Özil', 'Arsenal', 88],
#  ['Thiago Silva', 'Paris Saint-Germain', 88],
#  ['Z. Ibrahimović', 'Manchester United', 88],
#  ['A. Robben', 'FC Bayern Munich', 88],
#  ['N. Kanté', 'Chelsea', 87],
#  ['M. Verratti', 'Paris Saint-Germain', 87],
#  ['P. Pogba', 'Manchester United', 87],
#  ['C. Eriksen', 'Tottenham Hotspur', 87],
#  ['A. Vidal', 'FC Bayern Munich', 87],
#  ['E. Cavani', 'Paris Saint-Germain', 87],
#  ['Marcelo', 'Real Madrid CF', 87],
#  ['M. Hamšík', 'Napoli', 87],
#  ['I. Rakitić', 'FC Barcelona', 87],
#  ['David Silva', 'Manchester City', 87],
#  ['Piqué', 'FC Barcelona', 87],
#  ['Iniesta', 'FC Barcelona', 87],
#  ['H. Kane', 'Tottenham Hotspur', 86],
#  ['J. Rodríguez', 'FC Bayern Munich', 86],
#  ['Isco', 'Real Madrid CF', 86],
#  ['D. Alaba', 'FC Bayern Munich', 86],
#  ['R. Lukaku', 'Manchester United', 86],
#  ['Alex Sandro', 'Juventus', 86],
#  ['T. Müller', 'FC Bayern Munich', 86],
#  ['Sergio Busquets', 'FC Barcelona', 86],
#  ['Coutinho', 'Liverpool', 86],
#  ['M. Reus', 'Borussia Dortmund', 86],
#  ['T. Alderweireld', 'Tottenham Hotspur', 86],
#  ['David Luiz', 'Chelsea', 86],
#  ['Diego Costa', 'Chelsea', 86],
#  ['R. Nainggolan', 'Roma', 86],
#  ['Javi Martínez', 'FC Bayern Munich', 86],
#  ['D. Mertens', 'Napoli', 86],
#  ['Sokratis', 'Borussia Dortmund', 86],
#  ['Miranda', 'Inter', 86],
#  ['K. Benzema', 'Real Madrid CF', 86],
#  ['Cesc Fàbregas', 'Chelsea', 86],
#  ['F. Ribéry', 'FC Bayern Munich', 86],
#  ['Pepe', 'Beşiktaş JK', 86],
#  ['Y. Carrasco', 'Atlético Madrid', 85],
#  ['R. Varane', 'Real Madrid CF', 85],
#  ['Casemiro', 'Real Madrid CF', 85],
#  ['L. Insigne', 'Napoli', 85],
#  ['A. Lacazette', 'Arsenal', 85],
#  ['H. Mkhitaryan', 'Manchester United', 85],
#  ['K. Glik', 'AS Monaco', 85],
#  ['Jordi Alba', 'FC Barcelona', 85],
#  ['I. Gündoğan', 'Manchester City', 85],
#  ['Azpilicueta', 'Chelsea', 85],
#  ['A. Di María', 'Paris Saint-Germain', 85],
#  ['M. Pjanić', 'Juventus', 85],
#  ['C. Marchisio', 'Juventus', 85],
#  ['J. Vertonghen', 'Tottenham Hotspur', 85],
#  ['B. Matuidi', 'Juventus', 85],
#  ['Filipe Luís', 'Atlético Madrid', 85],
#  ['V. Kompany', 'Manchester City', 85],
#  ['A. Barzagli', 'Juventus', 85],
#  ['E. Bailly', 'Manchester United', 84],
#  ['Marco Asensio', 'Real Madrid CF', 84],
#  ['Bernardo Silva', 'Manchester City', 84],
#  ['A. Laporte', 'Athletic Club de Bilbao', 84],
#  ['D. Alli', 'Tottenham Hotspur', 84],
#  ['S. Mané', 'Liverpool', 84],
#  ['Carvajal', 'Real Madrid CF', 84],
#  ['J. Draxler', 'Paris Saint-Germain', 84],
#  ['M. Icardi', 'Inter', 84],
#  ['Morata', 'Chelsea', 84],
#  ['K. Koulibaly', 'Napoli', 84],
#  ['Koke', 'Atlético Madrid', 84],
#  ['K. Manolas', 'Roma', 84],
#  ['S. Mustafi', 'Arsenal', 84],
#  ['Ander Herrera', 'Manchester United', 84],
#  ['K. Strootman', 'Roma', 84],
#  ['Pedro', 'Chelsea', 84],
#  ['Bruno', 'Villarreal CF', 84],
#  ['I. Perišić', 'Inter', 84],
#  ['E. Džeko', 'Roma', 84],
#  ['Willian', 'Chelsea', 84],
#  ['S. Khedira', 'Juventus', 84],
#  ['Juan Mata', 'Manchester United', 84],
#  ['M. Benatia', 'Juventus', 84],
#  ['D. Payet', 'Olympique de Marseille', 84],
#  ['Falcao', 'AS Monaco', 84],
#  ['L. Koscielny', 'Arsenal', 84],
#  ['G. Cahill', 'Chelsea', 84],
#  ['Dani Alves', 'Paris Saint-Germain', 84],
#  ['A. Gómez', 'Atalanta', 84],
#  ['Aduriz', 'Athletic Club de Bilbao', 84],
#  ['K. Mbappé', 'Paris Saint-Germain', 83],
#  ['O. Dembélé', 'FC Barcelona', 83],
#  ['N. Keïta', 'RB Leipzig', 83],
#  ['J. Giménez', 'Atlético Madrid', 83],
#  ['T. Lemar', 'AS Monaco', 83],
#  ['João Mário', 'Inter', 83],
#  ['N. Süle', 'FC Bayern Munich', 83],
#  ['Fabinho', 'AS Monaco', 83],
#  ['M. Salah', 'Liverpool', 83],
#  ['A. Belotti', 'Torino', 83],
#  ['E. Forsberg', 'RB Leipzig', 83],
#  ['Marquinhos', 'Paris Saint-Germain', 83],
#  ['William Carvalho', 'Sporting CP', 83],
#  ['S. Umtiti', 'FC Barcelona', 83],
#  ['R. Mahrez', 'Leicester City', 83],
#  ['V. van Dijk', 'Southampton', 83],
#  ['Roberto Firmino', 'Liverpool', 83],
#  ['Danilo Pereira', 'FC Porto', 83],
#  ['Vitolo', 'UD Las Palmas', 83],
#  ['S. de Vrij', 'Lazio', 83],
#  ['J. Matip', 'Liverpool', 83],
#  ['I. Gueye', 'Everton', 83],
#  ['Iago Aspas', 'RC Celta de Vigo', 83],
#  ['N. Otamendi', 'Manchester City', 83],
#  ['N. Matić', 'Manchester United', 83],
#  ['J. Pastore', 'Paris Saint-Germain', 83],
#  ['Parejo', 'Valencia CF', 83],
#  ['S. Kagawa', 'Borussia Dortmund', 83],
#  ['G. Bonaventura', 'Milan', 83],
#  ['B. Dost', 'Sporting CP', 83],
#  ['K. Walker', 'Manchester City', 83],
#  ["S. N'Zonzi", 'Sevilla FC', 83],
#  ['M. Musacchio', 'Milan', 83],
#  ['O. Toprak', 'Borussia Dortmund', 83],
#  ['José Callejón', 'Napoli', 83],
#  ['S. Giovinco', 'Toronto FC', 83],
#  ['N. Gaitán', 'Atlético Madrid', 83],
#  ['M. Mandžukić', 'Juventus', 83],
#  ['A. Lallana', 'Liverpool', 83],
#  ['B. Höwedes', 'Juventus', 83],
#  ['E. Banega', 'Sevilla FC', 83],
#  ['M. Schneiderlin', 'Everton', 83],
#  ['Jonas', 'SL Benfica', 83],
#  ['K. Gameiro', 'Atlético Madrid', 83],
#  ['L. Piszczek', 'Borussia Dortmund', 83],
#  ['E. Garay', 'Valencia CF', 83],
#  ['A. Valencia', 'Manchester United', 83],
#  ['M. Dembélé', 'Tottenham Hotspur', 83],
#  ['Borja Valero', 'Inter', 83],
#  ['L. Perrin', 'AS Saint-Étienne', 83],
#  ['L. Biglia', 'Milan', 83],
#  ['Juanfran', 'Atlético Madrid', 83],
#  ['Santi Cazorla', 'Arsenal', 83],
#  ['J. Mascherano', 'FC Barcelona', 83],
#  ['W. Sneijder', 'OGC Nice', 83],
#  ['Nani', 'Lazio', 83],
#  ['D. De Rossi', 'Roma', 83],
#  ['Quaresma', 'Beşiktaş JK', 83],
#  ['Y. Touré', 'Manchester City', 83],
#  ['L. Sané', 'Manchester City', 82],
#  ['T. Bakayoko', 'Chelsea', 82],
#  ['C. Tolisso', 'FC Bayern Munich', 82],
#  ['I. Slimani', 'Leicester City', 82],
#  ['N. Fekir', 'Olympique Lyonnais', 82],
#  ['J. Seri', 'OGC Nice', 82],
#  ['K. Baldé Diao', 'AS Monaco', 82],
#  ['J. Tah', 'Bayer 04 Leverkusen', 82],
#  ['F. Bernardeschi', 'Juventus', 82],
#  ['T. Werner', 'RB Leipzig', 82],
#  ['André Gomes', 'FC Barcelona', 82],
#  ['A. Martial', 'Manchester United', 82],
#  ['L. Goretzka', 'FC Schalke 04', 82],
#  ['Q. Promes', 'Spartak Moscow', 82],
#  ['Lucas Vázquez', 'Real Madrid CF', 82],
#  ['Saúl', 'Atlético Madrid', 82],
#  ['Felipe', 'FC Porto', 82],
#  ['C. Bacca', 'Villarreal CF', 82],
#  ['F. Vázquez', 'Sevilla FC', 82],
#  ['M. Kovačić', 'Real Madrid CF', 82],
#  ['Manu Trigueros', 'Villarreal CF', 82],
#  ['A. Rüdiger', 'Chelsea', 82],
#  ['F. Thauvin', 'Olympique de Marseille', 82],
#  ['S. Savić', 'Atlético Madrid', 82],
#  ['Iñigo Martínez', 'Real Sociedad', 82],
#  ['Roque Mesa', 'Swansea City', 82],
#  ['A. Florenzi', 'Roma', 82],
#  ['D. Klaassen', 'Everton', 82],
#  ['K. Bellarabi', 'Bayer 04 Leverkusen', 82],
#  ['R. Sterling', 'Manchester City', 82],
#  ['Suso', 'Milan', 82],
#  ['Deulofeu', 'FC Barcelona', 82],
#  ['E. Dier', 'Tottenham Hotspur', 82],
#  ['M. Rojo', 'Manchester United', 82],
#  ['Lucas', 'Paris Saint-Germain', 82],
#  ['H. Son', 'Tottenham Hotspur', 82],
#  ['F. Acerbi', 'Sassuolo', 82],
#  ['G. Xhaka', 'Arsenal', 82],
#  ['Jonathan Viera', 'UD Las Palmas', 82],
#  ['Pizzi', 'SL Benfica', 82],
#  ['Willian José', 'Real Sociedad', 82],
#  ['G. Medel', 'Beşiktaş JK', 82],
#  ['Víctor Ruíz', 'Villarreal CF', 82],
#  ['X. Shaqiri', 'Stoke City', 82],
#  ['J. Cuadrado', 'Juventus', 82],
#  ['C. Immobile', 'Lazio', 82],
#  ['Douglas Costa', 'Juventus', 82],
#  ['N. Clyne', 'Liverpool', 82],
#  ['Iborra', 'Leicester City', 82],
#  ['V. Wanyama', 'Tottenham Hotspur', 82],
#  ['Taison', 'Shakhtar Donetsk', 82],
#  ['Marlos', 'Shakhtar Donetsk', 82],
#  ['L. Stindl', 'Borussia Mönchengladbach', 82],
#  ['M. Balotelli', 'OGC Nice', 82],
#  ['A. Ramsey', 'Arsenal', 82],
#  ['G. Sigurðsson', 'Everton', 82],
#  ['Y. Brahimi', 'FC Porto', 82],
#  ['M. Arnautović', 'West Ham United', 82],
#  ['J. Henderson', 'Liverpool', 82],
#  ['M. Kruse', 'SV Werder Bremen', 82],
#  ['L. Fejsa', 'SL Benfica', 82],
#  ['V. Ćorluka', 'Lokomotiv Moscow', 82],
#  ['G. Wijnaldum', 'Liverpool', 82],
#  ['F. Fazio', 'Roma', 82],
#  ['O. Giroud', 'Arsenal', 82],
#  ['B. Ivanović', 'Zenit St. Petersburg', 82],
#  ['J. Hernández', 'West Ham United', 82],
#  ['Beñat', 'Athletic Club de Bilbao', 82],
#  ['L. Bender', 'Bayer 04 Leverkusen', 82],
#  ['Naldo', 'FC Schalke 04', 82],
#  ['D. Sturridge', 'Liverpool', 82],
#  ['D. Rose', 'Tottenham Hotspur', 82],
#  ['C. Vela', 'Real Sociedad', 82],
#  ['G. Castro', 'Borussia Dortmund', 82],
#  ['S. Nasri', 'Antalyaspor', 82],
#  ['A. Williams', 'Everton', 82],
#  ['L. Baines', 'Everton', 82],
#  ['João Moutinho', 'AS Monaco', 82],
#  ['Raúl Albiol', 'Napoli', 82],
#  ['M. Gómez', 'VfL Wolfsburg', 82],
#  ['Raffael', 'Borussia Mönchengladbach', 82],
#  ['A. Turan', 'FC Barcelona', 82],
#  ['Fernandinho', 'Manchester City', 82],
#  ['David Villa', 'New York City Football Club', 82],
#  ['S. Lichtsteiner', 'Juventus', 82],
#  ['Gabriel Jesus', 'Manchester City', 81],
#  ['Nélson Semedo', 'FC Barcelona', 81],
#  ['Gelson Martins', 'Sporting CP', 81],
#  ['Malcom', 'Girondins de Bordeaux', 81],
#  ['J. Weigl', 'Borussia Dortmund', 81],
#  ['D. Sánchez', 'Tottenham Hotspur', 81],
#  ['A. Kramarić', 'TSG 1899 Hoffenheim', 81],
#  ['M. Brozović', 'Inter', 81],
#  ['Williams', 'Athletic Club de Bilbao', 81],
#  ['Dani García', 'SD Eibar', 81],
#  ['A. Christensen', 'Chelsea', 81],
#  ['J. Kimmich', 'FC Bayern Munich', 81],
#  ['Bruma', 'RB Leipzig', 81],
#  ['D. Berardi', 'Sassuolo', 81],
#  ['M. Sanson', 'Olympique de Marseille', 81],
#  ['A. Rabiot', 'Paris Saint-Germain', 81],
#  ['R. Guerreiro', 'Borussia Dortmund', 81],
#  ['J. Vardy', 'Leicester City', 81],
#  ['H. Ziyech', 'Ajax', 81],
#  ['M. Keane', 'Everton', 81],
#  ['Jorginho', 'Napoli', 81],
#  ['Héctor Bellerín', 'Arsenal', 81],
#  ['S. Zaza', 'Valencia CF', 81],
#  ['T. Meunier', 'Paris Saint-Germain', 81],
#  ['Felipe Anderson', 'Lazio', 81],
#  ['Rafinha', 'FC Barcelona', 81],
#  ['Nacho Fernández', 'Real Madrid CF', 81],
#  ['Sergi Roberto', 'FC Barcelona', 81],
#  ['W. Ben Yedder', 'Sevilla FC', 81],
#  ['Lucas Pérez', 'RC Deportivo de La Coruña', 81],
#  ['R. Barkley', 'Everton', 81],
#  ['C. Bakambu', 'Villarreal CF', 81],
#  ['W. Zaha', 'Crystal Palace', 81],
#  ['Bartra', 'Borussia Dortmund', 81],
#  ['S. Aurier', 'Tottenham Hotspur', 81],
#  ['S. Coates', 'Sporting CP', 81],
#  ['G. Krychowiak', 'West Bromwich Albion', 81],
#  ['K. Kampl', 'RB Leipzig', 81],
#  ['D. Lovren', 'Liverpool', 81],
#  ['A. Yarmolenko', 'Borussia Dortmund', 81],
#  ['Y. Belhanda', 'Galatasaray SK', 81],
#  ['Mário Fernandes', 'CSKA Moscow', 81],
#  ['R. Rodríguez', 'Milan', 81],
#  ['J. Corona', 'FC Porto', 81],
#  ['Mario Gaspar', 'Villarreal CF', 81],
#  ['Marcos Alonso', 'Chelsea', 81],
#  ['M. Götze', 'Borussia Dortmund', 81],
#  ['Illarramendi', 'Real Sociedad', 81],
#  ['De Marcos', 'Athletic Club de Bilbao', 81],
#  ['C. Smalling', 'Manchester United', 81],
#  ['Iturraspe', 'Athletic Club de Bilbao', 81],
#  ['J. Wilshere', 'Arsenal', 81],
#  ['S. Rudy', 'FC Bayern Munich', 81],
#  ['M. Lanzini', 'West Ham United', 81],
#  ['R. Boudebouz', 'Real Betis Balompié', 81],
#  ['Camacho', 'VfL Wolfsburg', 81],
#  ['Paulinho', 'FC Barcelona', 81],
#  ['N. Kalinić', 'Milan', 81],
#  ['Giuliano', 'Fenerbahçe SK', 81],
#  ['C. Benteke', 'Crystal Palace', 81],
#  ['D. Perotti', 'Roma', 81],
#  ['M. Parolo', 'Lazio', 81],
#  ['K. Mitroglou', 'Olympique de Marseille', 81],
#  ['M. Sakho', 'Crystal Palace', 81],
#  ['A. Rami', 'Olympique de Marseille', 81],
#  ['S. Jovetić', 'AS Monaco', 81],
#  ['S. Coleman', 'Everton', 81],
#  ['S. Kjær', 'Sevilla FC', 81],
#  ['M. Valbuena', 'Fenerbahçe SK', 81],
#  ['D. Astori', 'Fiorentina', 81],
#  ['K. Mirallas', 'Everton', 81],
#  ['Raúl García', 'Athletic Club de Bilbao', 81],
#  ['M. Škrtel', 'Fenerbahçe SK', 81],
#  ['H. Ben Arfa', 'Paris Saint-Germain', 81],
#  ['Dante', 'OGC Nice', 81],
#  ['A. Gignac', 'Tigres U.A.N.L.', 81],
#  ['Gabi', 'Atlético Madrid', 81],
#  ['G. Rodríguez', 'San Lorenzo de Almagro', 81],
#  ['D. Srna', 'Shakhtar Donetsk', 81],
#  ['B. Schweinsteiger', 'Chicago Fire Soccer Club', 81],
#  ['W. Rooney', 'Everton', 81],
#  ['P. Mertesacker', 'Arsenal', 81],
#  ['T. Motta', 'Paris Saint-Germain', 81],
#  ['Fernando Torres', 'Atlético Madrid', 81],
#  ["S. Eto'o", 'Antalyaspor', 81],
#  ['M. Rashford', 'Manchester United', 80],
#  ['S. Milinković-Savić', 'Lazio', 80],
#  ['Y. Tielemans', 'AS Monaco', 80],
#  ['Jemerson', 'AS Monaco', 80],
#  ['N. Bentaleb', 'FC Schalke 04', 80],
#  ['Alex Telles', 'FC Porto', 80],
#  ['J. Brandt', 'Bayer 04 Leverkusen', 80],
#  ['K. Demirbay', 'TSG 1899 Hoffenheim', 80],
#  ['D. Rugani', 'Juventus', 80],
#  ['Samu Castillejo', 'Villarreal CF', 80],
#  ['P. Zieliński', 'Napoli', 80],
#  ['Ricardo Pereira', 'FC Porto', 80],
#  ['Grimaldo', 'SL Benfica', 80],
#  ['Fred', 'Shakhtar Donetsk', 80],
#  ['J. Hector', '1. FC Köln', 80],
#  ['E. Can', 'Liverpool', 80],
#  ['S. Kolašinac', 'Arsenal', 80],
#  ['A. Pléa', 'OGC Nice', 80],
#  ['T. Stepanenko', 'Shakhtar Donetsk', 80],
#  ['O. Shatov', 'Zenit St. Petersburg', 80],
#  ['Leo Baptistao', 'RCD Espanyol', 80],
#  ['M. Nastasić', 'FC Schalke 04', 80],
#  ['Denis Suárez', 'FC Barcelona', 80],
#  ['M. Batshuayi', 'Chelsea', 80],
#  ['J. Brooks', 'VfL Wolfsburg', 80],
#  ['Eric Botteghin', 'Feyenoord', 80],
#  ['T. Hazard', 'Borussia Mönchengladbach', 80],
#  ['V. Germain', 'Olympique de Marseille', 80],
#  ['L. Kurzawa', 'Paris Saint-Germain', 80],
#  ['J. Iličić', 'Atalanta', 80],
#  ['K. Volland', 'Bayer 04 Leverkusen', 80],
#  ['Allan', 'Napoli', 80],
#  ['P. Hernández', 'RC Celta de Vigo', 80],
#  ['D. Tadić', 'Southampton', 80],
#  ['L. Muriel', 'Sevilla FC', 80],
#  ['Pablo Sarabia', 'Sevilla FC', 80],
#  ['A. Oxlade-Chamberlain', 'Liverpool', 80],
#  ['J. Guilavogui', 'VfL Wolfsburg', 80],
#  ['O. Özyakup', 'Beşiktaş JK', 80],
#  ['Y. Rakitskyi', 'Shakhtar Donetsk', 80],
#  ['Sergi Enrich', 'SD Eibar', 80],
#  ['Hugo Mallo', 'RC Celta de Vigo', 80],
#  ['D. Didavi', 'VfL Wolfsburg', 80],
#  ['R. Soriano', 'Villarreal CF', 80],
#  ['A. Schürrle', 'Borussia Dortmund', 80],
#  ['M. Gonalons', 'Roma', 80],
#  ['R. Pereyra', 'Watford', 80],
#  ['K. Vogt', 'TSG 1899 Hoffenheim', 80],
#  ['F. Orellana', 'Valencia CF', 80],
#  ['Maicon', 'Galatasaray SK', 80],
#  ['E. Salvio', 'SL Benfica', 80],
#  ['D. Blind', 'Manchester United', 80],
#  ['S. El Shaarawy', 'Roma', 80],
#  ['M. Antonio', 'West Ham United', 80],
#  ['Iago Falqué', 'Torino', 80],
#  ['S. Rondón', 'West Bromwich Albion', 80],
#  ['Daniel Carriço', 'Sevilla FC', 80],
#  ['M. Schmelzer', 'Borussia Dortmund', 80],
#  ['J. McCarthy', 'Everton', 80],
#  ['A. Dzagoev', 'CSKA Moscow', 80],
#  ['Ganso', 'Sevilla FC', 80],
#  ['F. Smolov', 'FC Krasnodar', 80],
#  ['D. Welbeck', 'Arsenal', 80],
#  ['Luiz Gustavo', 'Olympique de Marseille', 80],
#  ['Mikel San José', 'Athletic Club de Bilbao', 80],
#  ['M. Darmian', 'Manchester United', 80],
#  ['R. Thomas', 'Angers SCO', 80],
#  ['I. Traoré', 'Borussia Mönchengladbach', 80],
#  ['Sidnei', 'RC Deportivo de La Coruña', 80],
#  ['J. Lens', 'Beşiktaş JK', 80],
#  ['Eder', 'Inter', 80],
#  ['Nacho Monreal', 'Arsenal', 80],
#  ['S. Bender', 'Bayer 04 Leverkusen', 80],
#  ['M. Díaz', 'U.N.A.M.', 80],
#  ['A. Fernández', 'Atlético Madrid', 80],
#  ['I. Piatti', 'Montreal Impact', 80],
#  ['V. Birsa', 'Chievo Verona', 80],
#  ['Pedro León', 'SD Eibar', 80],
#  ['K. Boateng', 'Eintracht Frankfurt', 80],
#  ['Marcano', 'FC Porto', 80],
#  ['H. Moreno', 'Roma', 80],
#  ['A. Candreva', 'Inter', 80],
#  ['D. Criscito', 'Zenit St. Petersburg', 80],
#  ['D. Wass', 'RC Celta de Vigo', 80],
#  ['Coke', 'FC Schalke 04', 80],
#  ['A. Guardado', 'Real Betis Balompié', 80],
#  ['J. dos Santos', 'LA Galaxy', 80],
#  ['E. Lamela', 'Tottenham Hotspur', 80],
#  ['R. Bertrand', 'Southampton', 80],
#  ['Jardel', 'SL Benfica', 80],
#  ['V. Denisov', 'Lokomotiv Moscow', 80],
#  ['D. Basta', 'Lazio', 80],
#  ['G. Cabral', 'RC Celta de Vigo', 80],
#  ['G. Paletta', 'Milan', 80],
#  ['T. Walcott', 'Arsenal', 80],
#  ['V. Ibišević', 'Hertha BSC Berlin', 80],
#  ['K. El Ahmadi', 'Feyenoord', 80],
#  ['S. Kalou', 'Hertha BSC Berlin', 80],
#  ['Manuel Fernandes', 'Lokomotiv Moscow', 80],
#  ['A. Granqvist', 'FC Krasnodar', 80],
#  ['L. Podolski', 'Vissel Kobe', 80],
#  ['Javi Fuego', 'RCD Espanyol', 80],
#  ['F. Belluschi', 'San Lorenzo de Almagro', 80],
#  ['Kaká', 'Orlando City Soccer Club', 80],
#  ['J. Milner', 'Liverpool', 80],
#  ['A. Hutchinson', 'Beşiktaş JK', 80],
#  ['M. Topal', 'Fenerbahçe SK', 80],
#  ['J. Mathieu', 'Sporting CP', 80],
#  ['P. Jagielka', 'Everton', 80],
#  ['P. Evra', 'Olympique de Marseille', 80],
#  ['J. Defoe', 'Bournemouth', 80],
#  ['M. Carrick', 'Manchester United', 80],
#  ['M. Almirón', 'Atlanta United FC', 79],
#  ['Oyarzabal', 'Real Sociedad', 79],
#  ['Soares', 'FC Porto', 79],
#  ['F. Andone', 'RC Deportivo de La Coruña', 79],
#  ['M. Acuña', 'Sporting CP', 79],
#  ['V. Lindelöf', 'Manchester United', 79],
#  ['C. Lenglet', 'Sevilla FC', 79],
#  ['M. Dahoud', 'Borussia Dortmund', 79],
#  ['D. Zappacosta', 'Chelsea', 79],
#  ['N. Maksimović', 'Napoli', 79],
#  ['E. Rigoni', 'Zenit St. Petersburg', 79],
#  ['I. Marcone', 'Club Atlético Lanús', 79],
#  ['L. López', 'SL Benfica', 79],
#  ['A. Correa', 'Atlético Madrid', 79],
#  ['K. Coman', 'FC Bayern Munich', 79],
#  ['W. Cyprien', 'OGC Nice', 79],
#  ['Diego Llorente', 'Real Sociedad', 79],
#  ['Anderson Talisca', 'Beşiktaş JK', 79],
#  ['L. Dendoncker', 'RSC Anderlecht', 79],
#  ['M. Meyer', 'FC Schalke 04', 79],
#  ['Gayà', 'Valencia CF', 79],
#  ['S. Boufal', 'Southampton', 79],
#  ['M. Benassi', 'Fiorentina', 79],
#  ['N. Tagliafico', 'Independiente', 79],
#  ['E. Hysaj', 'Napoli', 79],
#  ['João Cancelo', 'Inter', 79],
#  ['A. Romagnoli', 'Milan', 79],
#  ['Óliver Torres', 'FC Porto', 79],
#  ['H. Çalhanoğlu', 'Milan', 79],
#  ['Gerard Moreno', 'RCD Espanyol', 79],
#  ['B. Traoré', 'Olympique Lyonnais', 79],
#  ['L. Vietto', 'Atlético Madrid', 79],
#  ['L. Paredes', 'Zenit St. Petersburg', 79],
#  ['M. Arnold', 'VfL Wolfsburg', 79],
#  ['S. Gnabry', 'TSG 1899 Hoffenheim', 79],
#  ['L. Shaw', 'Manchester United', 79],
#  ['E. Višća', 'İstanbul Başakşehir FK', 79],
#  ['Bernard', 'Shakhtar Donetsk', 79],
#  ['D. Baselli', 'Torino', 79],
#  ['A. Milik', 'Napoli', 79],
#  ['Bernat', 'FC Bayern Munich', 79],
#  ['W. Orban', 'RB Leipzig', 79],
#  ['Rubén Pardo', 'Real Sociedad', 79],
#  ['K. Zouma', 'Stoke City', 79],
#  ['C. Kramer', 'Borussia Mönchengladbach', 79],
#  ['S. Vrsaljko', 'Atlético Madrid', 79],
#  ['Zé Luís', 'Spartak Moscow', 79],
#  ['J. Stones', 'Manchester City', 79],
#  ['J. Vestergaard', 'Borussia Mönchengladbach', 79],
#  ['Fernando', 'Spartak Moscow', 79],
#  ['M. Depay', 'Olympique Lyonnais', 79],
#  ['F. Fernández', 'Swansea City', 79],
#  ['S. Sané', 'Hannover 96', 79],
#  ['N. Sansone', 'Villarreal CF', 79],
#  ['P. Ntep', 'VfL Wolfsburg', 79],
#  ['F. Ghoulam', 'Napoli', 79],
#  ['J. Murillo', 'Valencia CF', 79],
#  ['Gabriel Paulista', 'Valencia CF', 79],
#  ['V. Darida', 'Hertha BSC Berlin', 79],
#  ['Cédric', 'Southampton', 79],
#  ['L. Tonelli', 'Napoli', 79],
#  ['R. Saponara', 'Fiorentina', 79],
#  ['D. Sidibé', 'AS Monaco', 79],
#  ['Y. Konoplyanka', 'FC Schalke 04', 79],
#  ['L. Digne', 'FC Barcelona', 79],
#  ['Paco Alcácer', 'FC Barcelona', 79],
#  ['Vicente Gómez', 'UD Las Palmas', 79],
#  ['E. Çolak', 'RC Deportivo de La Coruña', 79],
#  ['N. Jørgensen', 'Feyenoord', 79],
#  ['Oriol Romeu', 'Southampton', 79],
#  ['Nolito', 'Sevilla FC', 79],
#  ['B. Martins Indi', 'Stoke City', 79],
#  ['M. Gabbiadini', 'Southampton', 79],
#  ['P. Herrmann', 'Borussia Mönchengladbach', 79],
#  ['F. Lejeune', 'Newcastle United', 79],
#  ['J. Bruma', 'VfL Wolfsburg', 79],
#  ['P. Jones', 'Manchester United', 79],
#  ['Keko', 'Málaga CF', 79],
#  ['H. Pérez', 'RCD Espanyol', 79],
#  ['Jaume Costa', 'Villarreal CF', 79],
#  ['Escudero', 'Sevilla FC', 79],
#  ['Y. Mallı', 'VfL Wolfsburg', 79],
#  ['A. Kokorin', 'Zenit St. Petersburg', 79],
#  ['S. Corchia', 'Sevilla FC', 79],
#  ['J. Kucka', 'Trabzonspor', 79],
#  ['A. Ljajić', 'Torino', 79],
#  ['Canales', 'Real Sociedad', 79],
#  ['Balenziaga', 'Athletic Club de Bilbao', 79],
#  ['W. Bony', 'Swansea City', 79],
#  ['B. Hübner', 'TSG 1899 Hoffenheim', 79],
#  ['F. Coquelin', 'Arsenal', 79],
#  ['Jonathas', 'Hannover 96', 79],
#  ['G. Bou', 'Club Tijuana', 79],
#  ['S. Doumbia', 'Sporting CP', 79],
#  ['C. Noboa', 'Zenit St. Petersburg', 79],
#  ['I. Smolnikov', 'Zenit St. Petersburg', 79],
#  ['Maurício', 'Lazio', 79],
#  ['M. Fabián', 'Eintracht Frankfurt', 79],
#  ['D. Drinkwater', 'Chelsea', 79],
#  ['A. Kolarov', 'Roma', 79],
#  ['Mariano', 'Galatasaray SK', 79],
#  ['S. Feghouli', 'Galatasaray SK', 79],
#  ['K. Papadopoulos', 'Hamburger SV', 79],
#  ['S. Wagner', 'TSG 1899 Hoffenheim', 79],
#  ['P. Piatti', 'RCD Espanyol', 79],
#  ['C. Yacob', 'West Bromwich Albion', 79],
#  ['A. Ogbonna', 'West Ham United', 79],
#  ['N. Amrabat', 'CD Leganés', 79],
#  ['W. Vainqueur', 'Antalyaspor', 79],
#  ['Marcelo', 'Olympique Lyonnais', 79],
#  ['Antunes', 'Getafe CF', 79],
#  ['S. Prödl', 'Watford', 79],
#  ['S. Tasci', 'Spartak Moscow', 79],
#  ['F. Johnson', 'Borussia Mönchengladbach', 79],
#  ['Bojan', 'Deportivo Alavés', 79],
#  ['M. Fellaini', 'Manchester United', 79],
#  ['P. Wernbloom', 'CSKA Moscow', 79],
#  ['A. Ayew', 'West Ham United', 79],
#  ['W. Reid', 'West Ham United', 79],
#  ['Lucas Leiva', 'Lazio', 79],
#  ['Z. Junuzović', 'SV Werder Bremen', 79],
#  ['C. Ansaldi', 'Torino', 79],
#  ['V. Moses', 'Chelsea', 79],
#  ['D. Zurutuza', 'Real Sociedad', 79],
#  ['D. Valeri', 'Portland Timbers', 79],
#  ['José Fonte', 'West Ham United', 79],
#  ['N. Şahin', 'Borussia Dortmund', 79],
#  ['G. dos Santos', 'LA Galaxy', 79],
#  ['R. Shawcross', 'Stoke City', 79],
#  ['J. Evans', 'West Bromwich Albion', 79],
#  ['A. Gyan', 'Kayserispor', 79],
#  ['Y. Cabaye', 'Crystal Palace', 79],
#  ['Danilo', 'Udinese', 79],
#  ['N. Pareja', 'Sevilla FC', 79],
#  ['S. Radu', 'Lazio', 79],
#  ['D. Abraham', 'Eintracht Frankfurt', 79],
#  ['M. Krohn-Dehli', 'Sevilla FC', 79],
#  ['Jurado', 'RCD Espanyol', 79],
#  ['B. Gomis', 'Galatasaray SK', 79],
#  ['H. Herrera', 'FC Porto', 79],
#  ['Luisão', 'SL Benfica', 79],
#  ['V. Berezutskiy', 'CSKA Moscow', 79],
#  ['I. Denisov', 'Lokomotiv Moscow', 79],
#  ['A. Samedov', 'Spartak Moscow', 79],
#  ['Xabi Prieto', 'Real Sociedad', 79],
#  ['Negredo', 'Beşiktaş JK', 79],
#  ['P. Zabaleta', 'West Ham United', 79],
#  ['Vágner Love', 'Alanyaspor', 79],
#  ['D. Baier', 'FC Augsburg', 79],
#  ['T. Rosický', 'Sparta Praha', 79],
#  ['A. Pirlo', 'New York City Football Club', 79],
#  ['G. Barry', 'West Bromwich Albion', 79],
#  ['E. Belözoğlu', 'İstanbul Başakşehir FK', 79],
#  ['André Silva', 'Milan', 78],
#  ['K. Dolberg', 'Ajax', 78],
#  ['Yeray', 'Athletic Club de Bilbao', 78],
#  ['C. Pulisic', 'Borussia Dortmund', 78],
#  ['L. Tousart', 'Olympique Lyonnais', 78],
#  ['V. Koziello', 'OGC Nice', 78],
#  ['N. Radoja', 'RC Celta de Vigo', 78],
#  ['V. Rongier', 'FC Nantes', 78],
#  ['O. Al Soma', 'Al Ahli', 78],
#  ['F. Cervi', 'SL Benfica', 78],
#  ['Jorge Meré', '1. FC Köln', 78],
#  ['Jony', 'Málaga CF', 78],
#  ['R. Karsdorp', 'Roma', 78],
#  ['Dani Ceballos', 'Real Madrid CF', 78],
#  ['H. Lozano', 'PSV', 78],
#  ['Raúl', 'SC Braga', 78],
#  ['M. Vecino', 'Inter', 78],
#  ['A. Sanabria', 'Real Betis Balompié', 78],
#  ['R. Battaglia', 'Sporting CP', 78],
#  ['J. Izquierdo', 'Brighton & Hove Albion', 78],
#  ['T. Bongonda', 'Trabzonspor', 78],
#  ['Rúben Semedo', 'Villarreal CF', 78],
#  ['Rafa', 'SL Benfica', 78],
#  ['Morales', 'Levante UD', 78],
#  ['Capa', 'SD Eibar', 78],
#  ['D. Zapata', 'Sampdoria', 78],
#  ['D. Benedetto', 'Boca Juniors', 78],
#  ['A. Ruiz', 'Sporting CP', 78],
#  ['D. Laxalt', 'Genoa', 78],
#  ['D. Origi', 'VfL Wolfsburg', 78],
#  ['N. Stark', 'Hertha BSC Berlin', 78],
#  ['Hernâni', 'FC Porto', 78],
#  ['Iuri Medeiros', 'Sporting CP', 78],
#  ['Bruno Fernandes', 'Sporting CP', 78],
#  ['R. Gagliardini', 'Inter', 78],
#  ['Pedro Santos', 'Columbus Crew SC', 78],
#  ['Carles Gil', 'RC Deportivo de La Coruña', 78],
#  ['Paulo Oliveira', 'SD Eibar', 78],
#  ['A. Szymanowski', 'CD Leganés', 78],
#  ['Bruno Peres', 'Roma', 78],
#  ['K. Wimmer', 'Stoke City', 78],
#  ['F. Kostić', 'Hamburger SV', 78],
#  ['A. Samaris', 'SL Benfica', 78],
#  ['A. Doucouré', 'Watford', 78],
#  ['G. Pizarro', 'Sevilla FC', 78],
#  ['J. Martínez', 'Atlanta United FC', 78],
#  ['M. Ginter', 'Borussia Mönchengladbach', 78],
#  ['J. Lingard', 'Manchester United', 78],
#  ['M. Weiser', 'Hertha BSC Berlin', 78],
#  ['D. Cheryshev', 'Villarreal CF', 78],
#  ['Bigas', 'UD Las Palmas', 78],
#  ['D. Heintz', '1. FC Köln', 78],
#  ['B. Davies', 'Tottenham Hotspur', 78],
#  ['L. Castro', 'Chievo Verona', 78],
#  ['J. Ward-Prowse', 'Southampton', 78],
#  ['T. Inui', 'SD Eibar', 78],
#  ['M. Sabitzer', 'RB Leipzig', 78],
#  ['B. Mendy', 'Manchester City', 78],
#  ['R. Jiménez', 'SL Benfica', 78],
#  ['E. Sala', 'FC Nantes', 78],
#  ['M. Niang', 'Torino', 78],
#  ['K. Fortounis', 'Olympiakos CFP', 78],
#  ['Pozuelo', 'KRC Genk', 78],
#  ['Joãozinho', 'FC Krasnodar', 78],
#  ['P. Kadeřábek', 'TSG 1899 Hoffenheim', 78],
#  ['T. Vilhena', 'Feyenoord', 78],
#  ['M. Elyounoussi', 'FC Basel', 78],
#  ['L. Bittencourt', '1. FC Köln', 78],
#  ['Sergi Darder', 'RCD Espanyol', 78],
#  ['D. Demme', 'RB Leipzig', 78],
#  ['V. Eysseric', 'Fiorentina', 78],
#  ['G. Ramírez', 'Sampdoria', 78],
#  ['David López', 'RCD Espanyol', 78],
#  ['M. Badelj', 'Fiorentina', 78],
#  ['A. Mandi', 'Real Betis Balompié', 78],
#  ['Ismaily', 'Shakhtar Donetsk', 78],
#  ['L. Teodorczyk', 'RSC Anderlecht', 78],
#  ['N. Chadli', 'West Bromwich Albion', 78],
#  ['S. Rode', 'Borussia Dortmund', 78],
#  ['M. van Ginkel', 'PSV', 78],
#  ['André André', 'FC Porto', 78],
#  ['J. Guidetti', 'RC Celta de Vigo', 78],
#  ['Danilo', 'Manchester City', 78],
#  ['V. Aboubakar', 'FC Porto', 78],
#  ['C. Aránguiz', 'Bayer 04 Leverkusen', 78],
#  ['Raúl Navas', 'Real Sociedad', 78],
#  ['K. Mbodj', 'RSC Anderlecht', 78],
#  ['Rodrigo', 'Valencia CF', 78],
#  ['R. Funes Mori', 'Monterrey', 78],
#  ['M. Höger', '1. FC Köln', 78],
#  ['N. Lodeiro', 'Seattle Sounders FC', 78],
#  ['D. Caligiuri', 'FC Schalke 04', 78],
#  ['S. Verdi', 'Bologna', 78],
#  ['E. Pérez', 'River Plate', 78],
#  ['T. Gutiérrez', 'CPD Junior Barranquilla', 78],
#  ['C. Austin', 'Southampton', 78],
#  ['G. Gillet', 'Olympiakos CFP', 78],
#  ['L. López', 'Racing Club de Avellaneda', 78],
#  ['A. Townsend', 'Crystal Palace', 78],
#  ['D. Heintz', '1. FC Köln', 78],
#  ['Pozuelo', 'KRC Genk', 78],
#  ['T. Vermaelen', 'FC Barcelona', 78],
#  ['I. Abate', 'Milan', 78],
#  ['J. Briand', 'En Avant de Guingamp', 78],
#  ['M. Sabitzer', 'RB Leipzig', 78],
#  ['Capa', 'SD Eibar', 78],
#  ['J. Toulalan', 'Girondins de Bordeaux', 78],
#  ['Bruno Alves', 'Rangers', 78],
#  ['C. Aránguiz', 'Bayer 04 Leverkusen', 78],
#  ['V. Rongier', 'FC Nantes', 78],
#  ['Joaquín', 'Real Betis Balompié', 78],
#  ['J. Lingard', 'Manchester United', 78],
#  ['S. Bocchetti', 'Spartak Moscow', 78],
#  ['Muniain', 'Athletic Club de Bilbao', 78],
#  ['Danilo', 'Manchester City', 78],
#  ['C. Gentner', 'VfB Stuttgart', 78],
#  ['O. Al Soma', 'Al Ahli', 78],
#  ['F. Gago', 'Boca Juniors', 78],
#  ['Bigas', 'UD Las Palmas', 78],
#  ['D. Origi', 'VfL Wolfsburg', 78],
#  ['D. Cheryshev', 'Villarreal CF', 78],
#  ['R. van Persie', 'Fenerbahçe SK', 78],
#  ['M. Layún', 'FC Porto', 78],
#  ['V. Eysseric', 'Fiorentina', 78],
#  ['Sergi Darder', 'RCD Espanyol', 78],
#  ['D. Laxalt', 'Genoa', 78],
#  ['Morales', 'Levante UD', 78],
#  ['V. Aboubakar', 'FC Porto', 78],
#  ['A. Szymanowski', 'CD Leganés', 78],
#  ['N. Nkoulou', 'Torino', 78],
#  ['S. Ignashevich', 'CSKA Moscow', 78],
#  ['Ismaily', 'Shakhtar Donetsk', 78],
#  ['Rafinha', 'FC Bayern Munich', 78],
#  ['L. Tousart', 'Olympique Lyonnais', 78],
#  ['J. Terry', 'Aston Villa', 78],
#  ['P. Skjelbred', 'Hertha BSC Berlin', 78],
#  ['I. Afellay', 'Stoke City', 78],
#  ['N. Lombaerts', 'KV Oostende', 78],
#  ['Granero', 'RCD Espanyol', 78],
#  ['J. Baumgartlinger', 'Bayer 04 Leverkusen', 78],
#  ['R. Palacio', 'Bologna', 78],
#  ['Miguel Lopes', 'Akhisar Belediyespor', 78],
#  ['Susaeta', 'Athletic Club de Bilbao', 78],
#  ['Hilton', 'Montpellier Hérault SC', 78],
#  ["Y. M'Vila", 'Rubin Kazan', 78],
#  ['Pedro Santos', 'Columbus Crew SC', 78],
#  ['Hernâni', 'FC Porto', 78],
#  ['V. Koziello', 'OGC Nice', 78],
#  ['J. Guidetti', 'RC Celta de Vigo', 78],
#  ['Borja Bastón', 'Málaga CF', 78],
#  ['J. Farfán', 'Lokomotiv Moscow', 78],
#  ['J. Montero', 'Getafe CF', 78],
#  ['A. Mandi', 'Real Betis Balompié', 78],
#  ['K. Mbodj', 'RSC Anderlecht', 78],
#  ['M. Badelj', 'Fiorentina', 78],
#  ['R. Battaglia', 'Sporting CP', 78],
#  ['M. Ruben', 'Rosario Central', 78],
#  ['M. Borriello', 'Ferrara (SPAL)', 78],
#  ['Rodrigo', 'Valencia CF', 78],
#  ['R. Gagliardini', 'Inter', 78],
#  ['Eliseu', 'SL Benfica', 78],
#  ['F. Kostić', 'Hamburger SV', 78],
#  ['Mosquera', 'RC Deportivo de La Coruña', 78],
#  ['Rochina', 'Rubin Kazan', 78],
#  ['André André', 'FC Porto', 78],
#  ['Rúben Semedo', 'Villarreal CF', 78],
#  ['B. Džemaili', 'Montreal Impact', 78],
#  ['K. Fortounis', 'Olympiakos CFP', 78],
#  ["A. N'Diaye", 'Wolverhampton Wanderers', 78],
#  ['Y. Gourcuff', 'Stade Rennais FC', 78],
#  ['K. Asamoah', 'Juventus', 78],
#  ['R. Bobadilla', 'Borussia Mönchengladbach', 78],
#  ['R. Hamouma', 'AS Saint-Étienne', 78],
#  ['C. Pulisic', 'Borussia Dortmund', 78],
#  ['M. Fernández', 'Necaxa', 78],
#  ['K. Honda', 'Pachuca', 78],
#  ['Raúl Navas', 'Real Sociedad', 78],
#  ['A. Dzyuba', 'Zenit St. Petersburg', 78],
#  ['B. Yılmaz', 'Trabzonspor', 78],
#  ['J. Holebas', 'Watford', 78],
#  ['Javi García', 'Real Betis Balompié', 78],
#  ['D. Caligiuri', 'FC Schalke 04', 78],
#  ['Fontàs', 'RC Celta de Vigo', 78],
#  ['Jony', 'Málaga CF', 78],
#  ['C. Tosun', 'Beşiktaş JK', 78],
#  ['M. Höger', '1. FC Köln', 78],
#  ['S. Dann', 'Crystal Palace', 78],
#  ['Rafa', 'SL Benfica', 78],
#  ['Y. Bolasie', 'Everton', 78],
#  ['Bruno Fernandes', 'Sporting CP', 78],
#  ['D. Glushakov', 'Spartak Moscow', 78],
#  ['Juanfran', 'RC Deportivo de La Coruña', 78],
#  ['K. Trippier', 'Tottenham Hotspur', 78],
#  ['J. Cork', 'Burnley', 78],
#  ['A. Ramos', 'Granada CF', 78],
#  ['M. Bradley', 'Toronto FC', 78],
#  ['Souza', 'Fenerbahçe SK', 78],
#  ['T. Mangani', 'Angers SCO', 78],
#  ['N. Stark', 'Hertha BSC Berlin', 78],
#  ['Rafael', 'Olympique Lyonnais', 78],
#  ['Carles Gil', 'RC Deportivo de La Coruña', 78],
#  ['Adriano', 'Beşiktaş JK', 78],
#  ['B. Mee', 'Burnley', 78],
#  ['M. Ginter', 'Borussia Mönchengladbach', 78],
#  ['Paulo Oliveira', 'SD Eibar', 78],
#  ['C. Dempsey', 'Seattle Sounders FC', 78],
#  ['R. Funes Mori', 'Monterrey', 78],
#  ['M. Weiser', 'Hertha BSC Berlin', 78],
#  ['H. Briceldo', 'Colo-Colo', 77],
#  ['Juanmi', 'Real Sociedad', 77],
#  ['N. Subotić', 'Borussia Dortmund', 77],
#  ['N. Blandi', 'San Lorenzo de Almagro', 77],
#  ['P. De Blasis', '1. FSV Mainz 05', 77],
#  ['M. Phillips', 'West Bromwich Albion', 77],
#  ['M. Braithwaite', 'Middlesbrough', 77],
#  ['D. Reyes', 'FC Porto', 77],
#  ['Iván Ramis', 'SD Eibar', 77],
#  ['V. Behrami', 'Udinese', 77],
#  ['G. Hoarau', 'BSC Young Boys', 77],
#  ['T. Barnetta', 'FC St. Gallen', 77],
#  ['E. Choupo-Moting', 'Stoke City', 77],
#  ['Jesé', 'Stoke City', 77],
#  ['J. Pinola', 'River Plate', 77],
#  ['Luís Hernández', 'Málaga CF', 77],
#  ['Jonny', 'RC Celta de Vigo', 77],
#  ['M. Carcela-González', 'Olympiakos CFP', 77],
#  ['L. Pavoletti', 'Cagliari', 77],
#  ['D. Bonera', 'Villarreal CF', 77],
#  ['Marcelo', 'Rio Ave FC', 77],
#  ['Dalbert', 'Inter', 77],
#  ['G. McAuley', 'West Bromwich Albion', 77],
#  ['A. Halilović', 'UD Las Palmas', 77],
#  ['N. Amiri', 'TSG 1899 Hoffenheim', 77],
#  ['I. Popov', 'Spartak Moscow', 77],
#  ['N. Burdisso', 'Torino', 77],
#  ['W. Hoolahan', 'Norwich City', 77],
#  ['Sidney Pessinho', 'Grêmio Foot-Ball Porto Alegrense', 77],
#  ['A. Potuk', 'Fenerbahçe SK', 77],
#  ['F. Pogba', 'AS Saint-Étienne', 77],
#  ['A. Carrillo', 'Watford', 77],
#  ['M. Andreolli', 'Cagliari', 77],
#  ['Bruno', 'Getafe CF', 77],
#  ['O. Duarte', 'RCD Espanyol', 77],
#  ['Rúben Neves', 'Wolverhampton Wanderers', 77],
#  ['Jozabed', 'RC Celta de Vigo', 77],
#  ['P. Pérez', 'Boca Juniors', 77],
#  ['Gazzolisco', 'Cruzeiro', 77],
#  ['M. Gamonales', 'Universidad de Chile', 77],
#  ['Ronaldo Esler', 'Santos Futebol Clube', 77],
#  ['Vitor Hugo', 'Fiorentina', 77],
#  ['T. Arslan', 'Beşiktaş JK', 77],
#  ['J. Veretout', 'Fiorentina', 77],
#  ['D. Pabón', 'Monterrey', 77],
#  ['Juan Jesus', 'Roma', 77],
#  ['E. Durm', 'Borussia Dortmund', 77],
#  ['G. Imbula', 'Toulouse FC', 77],
#  ['Luis Alberto', 'Lazio', 77],
#  ['M. Risse', '1. FC Köln', 77],
#  ['Luís Neto', 'Fenerbahçe SK', 77],
#  ['B. Ruíz', 'Sporting CP', 77],
#  ['Jordi Amat', 'Real Betis Balompié', 77],
#  ['J. Ďurica', 'Trabzonspor', 77],
#  ['B. Stambouli', 'FC Schalke 04', 77],
#  ['C. Kaboré', 'FC Krasnodar', 77],
#  ['A. Rukavina', 'Villarreal CF', 77],
#  ['P. Kimpembe', 'Paris Saint-Germain', 77],
#  ['Sergio León', 'Real Betis Balompié', 77],
#  ['M. Elneny', 'Arsenal', 77],
#  ['D. Torres', 'Deportivo Alavés', 77],
#  ['S. Okazaki', 'Leicester City', 77],
#  ['C. Jallet', 'OGC Nice', 77],
#  ['Y. Salibur', 'En Avant de Guingamp', 77],
#  ['N. Redmond', 'Southampton', 77],
#  ['A. Song', 'Rubin Kazan', 77],
#  ['Andreas Pereira', 'Valencia CF', 77],
#  ['Castán', 'Roma', 77],
#  ['K. Huntelaar', 'Ajax', 77],
#  ['T. Partey', 'Atlético Madrid', 77],
#  ['Mário Rui', 'Napoli', 77],
#  ['André Pinto', 'Sporting CP', 77],
#  ['L. Rémy', 'UD Las Palmas', 77],
#  ['Badou Ndiaye', 'Galatasaray SK', 77],
#  ['A. Bertolacci', 'Genoa', 77],
#  ['A. Živković', 'SL Benfica', 77],
#  ['M. Lemina', 'Southampton', 77],
#  ['D. Da Silva', 'SM Caen', 77],
#  ['T. Rincón', 'Torino', 77],
#  ['Y. Ōsako', '1. FC Köln', 77],
#  ['L. Sané', 'SV Werder Bremen', 77],
#  ['J. King', 'Bournemouth', 77],
#  ['Bastos', 'Lazio', 77],
#  ['J. Quintero', 'Independiente Medellín', 77],
#  ['A. Meier', 'Eintracht Frankfurt', 77],
#  ['G. Nkoudou', 'Tottenham Hotspur', 77],
#  ['Montoya', 'Valencia CF', 77],
#  ['L. Dalsaro', 'Colo-Colo', 77],
#  ['K. Källström', 'Djurgårdens IF', 77],
#  ['M. Politano', 'Sassuolo', 77],
#  ['M. Zárate', 'Watford', 77],
#  ['G. İnler', 'İstanbul Başakşehir FK', 77],
#  ['M. Albrighton', 'Leicester City', 77],
#  ['A. Gray', 'Watford', 77],
#  ['Marçal', 'Olympique Lyonnais', 77],
#  ['A. Gamberini', 'Chievo Verona', 77],
#  ['S. Widmer', 'Udinese', 77],
#  ['J. Aquino', 'Tigres U.A.N.L.', 77],
#  ['S. Gentiletti', 'Genoa', 77],
#  ['C. Sánchez', 'Fiorentina', 77],
#  ['M. Sissoko', 'Tottenham Hotspur', 77],
#  ['G. Defrel', 'Roma', 77],
#  ['R. Martínez', 'Club Atlético Lanús', 77],
#  ['J. Geis', 'Sevilla FC', 77],
#  ['P. Verhaegh', 'VfL Wolfsburg', 77],
#  ['H. Nordtveit', 'TSG 1899 Hoffenheim', 77],
#  ['R. Steffen', 'FC Basel', 77],
#  ['M. Hasebe', 'Eintracht Frankfurt', 77],
#  ['J. Córdoba', '1. FC Köln', 77],
#  ['L. Schøne', 'Ajax', 77],
#  ['R. Rosales', 'Málaga CF', 77],
#  ['N. De Préville', 'Girondins de Bordeaux', 77],
#  ['Marcos Llorente', 'Real Madrid CF', 77],
#  ['Y. Chará', 'CPD Junior Barranquilla', 77],
#  ['Wallace', 'Lazio', 77],
#  ['J. Toornstra', 'Feyenoord', 77],
#  ['Pedro Obiang', 'West Ham United', 77],
#  ['V. Chiricheş', 'Napoli', 77],
#  ['S. Hanni', 'RSC Anderlecht', 77],
#  ['C. Théréau', 'Fiorentina', 77],
#  ['D. Rolán', 'Málaga CF', 77],
#  ['Pedro Henrique', 'Vitória Guimarães', 77],
#  ['Bruno Gaspar', 'Fiorentina', 77],
#  ['Cristian Tello', 'Real Betis Balompié', 77],
#  ['Formosandrinho', 'São Paulo Futebol Clube', 77],
#  ['S. Haller', 'Eintracht Frankfurt', 77],
#  ['Claudio Coíntra', 'Grêmio Foot-Ball Porto Alegrense', 77],
#  ['M. Uth', 'TSG 1899 Hoffenheim', 77],
#  ['F. Sørensen', '1. FC Köln', 77],
#  ['J. Van Damme', 'Royal Antwerp FC', 77],
#  ['L. Britton', 'Swansea City', 77],
#  ['V. Grifo', 'Borussia Mönchengladbach', 77],
#  ['T. Cairney', 'Fulham', 77],
#  ['Sandro', 'Everton', 77],
#  ['F. Delph', 'Manchester City', 77],
#  ['J. Veltman', 'Ajax', 77],
#  ['A. Dragović', 'Leicester City', 77],
#  ['D. Pröpper', 'Brighton & Hove Albion', 77],
#  ['L. Cattermole', 'Sunderland', 77],
#  ['Luisinho', 'RC Deportivo de La Coruña', 77],
#  ['Vitinho', 'CSKA Moscow', 77],
#  ['Z. Feddal', 'Real Betis Balompié', 77],
#  ['Vallejo', 'Real Madrid CF', 77],
#  ['Rafael Carioca', 'Tigres U.A.N.L.', 77],
#  ['David García', 'UD Las Palmas', 77],
#  ['J. Allen', 'Stoke City', 77],
#  ['A. Younes', 'Ajax', 77],
#  ['L. Hernández', 'Atlético Madrid', 77],
#  ['A. Mooy', 'Huddersfield Town', 77],
#  ['Campaña', 'Levante UD', 77],
#  ['Vieirinha', 'PAOK Thessaloniki', 77],
#  ['Wendell', 'Bayer 04 Leverkusen', 77],
#  ['Y. Sabaly', 'Girondins de Bordeaux', 77],
#  ['J. Hofmann', 'Borussia Mönchengladbach', 77],
#  ['Timor', 'Girona CF', 77],
#  ['H. Arter', 'Bournemouth', 77],
#  ['M. Lemos', 'UD Las Palmas', 77],
#  ['Louri Beretta', 'Fluminense Football Club', 77],
#  ['F. Caicedo', 'Lazio', 77],
#  ['S. Sturaro', 'Juventus', 77],
#  ['Pablo Fornals', 'Villarreal CF', 77],
#  ['Sergi Gómez', 'RC Celta de Vigo', 77],
#  ['P. Jansson', 'Leeds United', 77],
#  ['A. Berezutskiy', 'CSKA Moscow', 77],
#  ['L. Pellegrini', 'Roma', 77],
#  ['A. Masiello', 'Atalanta', 77],
#  ['M. Ekici', 'Fenerbahçe SK', 77],
#  ['A. Nyom', 'West Bromwich Albion', 77],
#  ['F. Roncaglia', 'RC Celta de Vigo', 77],
#  ['P. Hidalgado', 'Colo-Colo', 77],
#  ['J. De Guzmán', 'Eintracht Frankfurt', 77],
#  ['M. Gradel', 'Toulouse FC', 77],
#  ['M. Debuchy', 'Arsenal', 77],
#  ['S. Terodde', 'VfB Stuttgart', 77],
#  ['Recio', 'Málaga CF', 77],
#  ['R. Zobnin', 'Spartak Moscow', 77],
#  ['Fábio Coentrão', 'Sporting CP', 77],
#  ['J. Campbell', 'Real Betis Balompié', 77],
#  ['C. Stuani', 'Girona CF', 77],
#  ['A. Veznera', 'Colo-Colo', 77],
#  ['J. Willems', 'Eintracht Frankfurt', 77],
#  ['A. Lennon', 'Everton', 77],
#  ['T. Lagardo', 'Universidad de Chile', 77],
#  ['S. Okaka', 'Watford', 77],
#  ['Aritz Elustondo', 'Real Sociedad', 77],
#  ['Ricardo Ferreira', 'SC Braga', 77],
#  ['W. Morgan', 'Leicester City', 77],
#  ['J. Lukaku', 'Lazio', 77],
#  ...]

# %%
B1.add_weighted_edges_from(weighted_edges1.T.values.tolist())

# %%
# the biggest connected graph and test
B1 = max((B1.subgraph(c) for c in nx.connected_components(B1)), key=len)
nx.is_connected(B1)
# Out:
# True

# %%
player_nodes1 = set(n for n,d in B1.nodes(data=True) if d['bipartite']==0)
club_nodes1 = set(B1) - player_nodes1

# %%
cc1 = sorted((B1.subgraph(c) for c in nx.connected_components(B1)), key = len, reverse=True)[0]
#    sorted(nx.connected_component_subgraphs(team_win), key = len, reverse=True)[0]
islands1 = island_method(cc1)
 
for i in islands1:
    # print the threshold level, size of the graph, and number of connected components
    print (i[0], len(i[1]), len(sorted((i[1].subgraph(c) for c in nx.connected_components(i[1])), key = len, reverse=True)))
# Out:
# 46 11334 1
# 54 10773 16
# 62 8312 129
# 70 3512 274
# 78 592 87
# 86 50 13

# %%
plt.rcParams['figure.figsize'] = [16, 12]
node_colors = []

for n in islands1[4][1].nodes(data=True):
    if n[0] in player_nodes:
        node_colors.append('#FFCCCB')
    else:
        node_colors.append('#ffd700')
pos = nx.spring_layout(islands1[4][1], k=2) # k=2 values helps spread the nodes

# Degree calculations to denote the size of nodes
degree1 = dict(nx.degree(islands1[4][1]))


degree_graph1 = nx.draw_networkx(islands1[4][1], 
                                pos=pos,
                                node_color=node_colors,
                                node_size=np.multiply(list(degree1.values()), 400), # multiply degree by 400 for better resolution
                                with_labels=True, 
                                width=0.2)

# Remove axis
limits=plt.axis('off')

# %%
plt.rcParams['figure.figsize'] = [16, 12]
node_colors = []

for n in islands1[5][1].nodes(data=True):
    if n[0] in player_nodes:
        node_colors.append('#FFCCCB')
    else:
        node_colors.append('#ffd700')
pos = nx.spring_layout(islands1[5][1], k=2) # k=2 values helps spread the nodes

# Degree calculations to denote the size of nodes
degree1 = dict(nx.degree(islands1[5][1]))


degree_graph1 = nx.draw_networkx(islands1[5][1], 
                                pos=pos,
                                node_color=node_colors,
                                node_size=np.multiply(list(degree1.values()), 400), # multiply degree by 400 for better resolution
                                with_labels=True, 
                                width=0.2)

# Remove axis
limits=plt.axis('off')

# %% [markdown]
# # Indepth analysis of the best players, their clubs and nationalities

# %%
best_players = fifa[fifa.Name.isin(list(islands[5][1].nodes()))]
best_players[best_players.Name == 'L. Suárez']
# Out:
#        Unnamed: 0       Name  Age  \
# 3               3  L. Suárez   30
# 4510         4510  L. Suárez   21
# 10320       10320  L. Suárez   22
#
#                                                  Photo Nationality  \
# 3      https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4510   https://cdn.sofifa.org/48/18/players/225591.png   Argentina
# 10320  https://cdn.sofifa.org/48/18/players/222378.png   Argentina
#
#                                       Flag  Overall  Potential  \
# 3      https://cdn.sofifa.org/flags/60.png       92         92
# 4510   https://cdn.sofifa.org/flags/52.png       70         81
# 10320  https://cdn.sofifa.org/flags/52.png       64         73
#
#                      Club                                      Club Logo  ...  \
# 3            FC Barcelona     https://cdn.sofifa.org/24/18/teams/241.png  ...
# 4510        Villarreal CF     https://cdn.sofifa.org/24/18/teams/483.png  ...
# 10320  Defensa y Justicia  https://cdn.sofifa.org/24/18/teams/111710.png  ...
#
#        RB  RCB  RCM  RDM  RF  RM  RS  RW  RWB  ST
# 3      64   58   80   65  88  85  88  87   68  88
# 4510   43   34   63   44  69  69  64  71   47  64
# 10320  63   65   49   59  45  50  46  47   62  46
#
# [3 rows x 75 columns]

# %% [markdown]
# Notice there are some players showing up multiple times. That's because we extracted the players from the original dataset and FIFA tracked their career with multiple clubs.
#
# We will keep only the entry at their **peak** overall performance.

# %%
best_players = best_players.groupby('Name', group_keys=False).apply(lambda x: x.loc[x.Overall.idxmax()])
best_players[best_players.Name == 'L. Suárez']
# Out:
#            Unnamed: 0       Name  Age  \
# Name
# L. Suárez           3  L. Suárez   30
#
#                                                      Photo Nationality  \
# Name
# L. Suárez  https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
#
#                                           Flag  Overall  Potential  \
# Name
# L. Suárez  https://cdn.sofifa.org/flags/60.png       92         92
#
#                    Club                                   Club Logo  ...  RB  \
# Name                                                                 ...
# L. Suárez  FC Barcelona  https://cdn.sofifa.org/24/18/teams/241.png  ...  64
#
#            RCB  RCM  RDM  RF  RM  RS  RW  RWB  ST
# Name
# L. Suárez   58   80   65  88  85  88  87   68  88
#
# [1 rows x 75 columns]

# %% [markdown]
# ## Count of High Quality Players by Nationality
#
# It is no surprise that the teams that are usually top contenders in the World Cup 'produce' the most players with exceptional skill and talent.
#
# Since we are approaching the 2018 World Cup Final, the finalists are marked in orange for an easy comparison.

# %%
plt.rcParams['figure.figsize'] = [10, 8]
best_players.groupby('Nationality')\
    .count().Overall\
    .sort_values(ascending=True)\
    .plot(kind='barh', color='orange')

plt.xlabel('Count of High Quality Players')
# Out:
# Text(0.5, 0, 'Count of High Quality Players')

# %% [markdown]
# ## Average Age of Best Players by Nationality
#
# For many players, their professional career starts as early as the age of 16. Even though we are studying only the best 45 players, and the chart below may not be statistically significant to reflect a national trend, it is important to note that a difference of 10 years between best players of Sweden and Slovenia is remarkable because ** the average duration of playing career is 8 years.**

# %%
plt.rcParams['figure.figsize'] = [10, 8]

best_players.groupby('Nationality')\
    .mean()\
    .Age.round()\
    .sort_values(ascending=True)\
    .plot(kind='barh', color='#40bf80')
    
plt.xlabel('Average Age')
# Out:
# Text(0.5, 0, 'Average Age')

# %% [markdown]
# ## Players'  monetary Value and Wage
#
# Before we get to the charting, we first need to convert the value and wage into numerical type. They are initially represented with M for Millions and K for Thousands.
#
# All values are in Euro.

# %%
best_players.iloc[:,11] == best_players["Wage"]
# Out:
# Name
# A. Griezmann         True
# A. Robben            True
# A. Sánchez           True
# A. Vidal             True
# C. Eriksen           True
# Cristiano Ronaldo    True
# D. Godín             True
# David Silva          True
# E. Cavani            True
# E. Hazard            True
# G. Bale              True
# G. Chiellini         True
# G. Higuaín           True
# I. Rakitić           True
# Iniesta              True
# J. Boateng           True
# K. De Bruyne         True
# L. Bonucci           True
# L. Messi             True
# L. Modrić            True
# L. Suárez            True
# M. Hummels           True
# M. Verratti          True
# M. Özil              True
# N. Kanté             True
# Neymar               True
# P. Dybala            True
# P. Pogba             True
# Piqué                True
# S. Agüero            True
# Sergio Ramos         True
# T. Kroos             True
# Thiago               True
# Thiago Silva         True
# Z. Ibrahimović       True
# Name: Wage, dtype: bool

# %% [markdown]
# ## Average Wage (in Thousands of Euros) by Club
#
# There seems to be a correlation between clubs that pay their players the most and the clubs' rank and achievements.
# Spanish, English, German, French and Italian clubs pay the highest salaries.

# %%
best_players.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control',
#        'Composure', 'Crossing', 'Curve', 'Dribbling', 'Finishing',
#        'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking',
#        'GK positioning', 'GK reflexes', 'Heading accuracy', 'Interceptions',
#        'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties',
#        'Positioning', 'Reactions', 'Short passing', 'Shot power',
#        'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle',
#        'Strength', 'Vision', 'Volleys', 'CAM', 'CB', 'CDM', 'CF', 'CM', 'ID',
#        'LAM', 'LB', 'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB',
#        'Preferred Positions', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF', 'RM',
#        'RS', 'RW', 'RWB', 'ST'],
#       dtype='object')

# %%
best_players.iloc[:,[8,11]].groupby("Club").mean().apply(lambda x: x/1000).round().sort_values(ascending=True,by=['Wage'])\
    .plot(kind='barh', colormap='Accent')
# Out:
# <AxesSubplot:ylabel='Club'>

# %% [markdown]
# ## Clubs with the Most Valuable ($) players
#
# Paris Sait-Germain is the team with 4 high quality players and they are valued the most on average. Chealsea is right behind with 3 players and Real Madrit has 6.

# %%
best_players.groupby('Club').count()
# Out:
#                      Unnamed: 0  Name  Age  Photo  Nationality  Flag  Overall  \
# Club
# Arsenal                       2     2    2      2            2     2        2
# Atlético Madrid               2     2    2      2            2     2        2
# Chelsea                       2     2    2      2            2     2        2
# FC Barcelona                  5     5    5      5            5     5        5
# FC Bayern Munich              5     5    5      5            5     5        5
# Juventus                      3     3    3      3            3     3        3
# Manchester City               3     3    3      3            3     3        3
# Manchester United             2     2    2      2            2     2        2
# Milan                         1     1    1      1            1     1        1
# Paris Saint-Germain           4     4    4      4            4     4        4
# Real Madrid CF                5     5    5      5            5     5        5
# Tottenham Hotspur             1     1    1      1            1     1        1
#
#                      Potential  Club Logo  Value  ...  RB  RCB  RCM  RDM  RF  \
# Club                                              ...
# Arsenal                      2          2      2  ...   2    2    2    2   2
# Atlético Madrid              2          2      2  ...   2    2    2    2   2
# Chelsea                      2          2      2  ...   2    2    2    2   2
# FC Barcelona                 5          5      5  ...   5    5    5    5   5
# FC Bayern Munich             5          5      5  ...   5    5    5    5   5
# Juventus                     3          3      3  ...   3    3    3    3   3
# Manchester City              3          3      3  ...   3    3    3    3   3
# Manchester United            2          2      2  ...   2    2    2    2   2
# Milan                        1          1      1  ...   1    1    1    1   1
# Paris Saint-Germain          4          4      4  ...   4    4    4    4   4
# Real Madrid CF               5          5      5  ...   5    5    5    5   5
# Tottenham Hotspur            1          1      1  ...   1    1    1    1   1
#
#                      RM  RS  RW  RWB  ST
# Club
# Arsenal               2   2   2    2   2
# Atlético Madrid       2   2   2    2   2
# Chelsea               2   2   2    2   2
# FC Barcelona          5   5   5    5   5
# FC Bayern Munich      5   5   5    5   5
# Juventus              3   3   3    3   3
# Manchester City       3   3   3    3   3
# Manchester United     2   2   2    2   2
# Milan                 1   1   1    1   1
# Paris Saint-Germain   4   4   4    4   4
# Real Madrid CF        5   5   5    5   5
# Tottenham Hotspur     1   1   1    1   1
#
# [12 rows x 74 columns]

# %%
plt.rcParams['figure.figsize'] = [10, 8]

best_players.iloc[:,[8,10]].groupby('Club').mean()\
    .apply(lambda x: x/1000000).round()\
    .sort_values(ascending=True,by=['Value'])\
    .plot(kind='barh', colormap='Accent')

plt.xlabel('Average Club Value (in Millions of Euros)')
# Out:
# Text(0.5, 0, 'Average Club Value (in Millions of Euros)')

# %% [markdown]
# Since the above chart shows the average value for all players, it may be more informative to check the total (sum) value of all the best players.
#
# As suspected, Real Madrit moves above PSG and Chealsea but Bayern Munich shoots up with their 7 top players and their total value of **393,000,000 Euro!**

# %%
plt.rcParams['figure.figsize'] = [10, 8]

best_players.iloc[:,[8,10]].groupby('Club').sum()\
    .apply(lambda x: x/1000000).round()\
    .sort_values(ascending=True,by=['Value'])\
    .plot(kind='barh', colormap='Accent')

plt.xlabel('Total Club Value (in Millions of Euros)')
# Out:
# Text(0.5, 0, 'Total Club Value (in Millions of Euros)')

# %% [markdown]
# ### Market Value of countries

# %%
plt.rcParams['figure.figsize'] = [10, 8]

best_players.iloc[:,[4,10]].groupby('Nationality').mean()\
    .apply(lambda x: x/1000000).round()\
    .sort_values(ascending=True,by=['Value'])\
    .plot(kind='barh', colormap='Accent')

plt.xlabel('Average Nationality Value (in Millions of Euros)')
# Out:
# Text(0.5, 0, 'Average Nationality Value (in Millions of Euros)')

# %%
plt.rcParams['figure.figsize'] = [10, 8]

best_players.iloc[:,[4,10]].groupby('Nationality').sum()\
    .apply(lambda x: x/1000000).round()\
    .sort_values(ascending=True,by=['Value'])\
    .plot(kind='barh', colormap='Accent')

plt.xlabel('Total Nationality Value (in Millions of Euros)')
# Out:
# Text(0.5, 0, 'Total Nationality Value (in Millions of Euros)')

# %% [markdown]
# **FIFA Position acronyms**
#
#     GK: Goalkeeper
#     CB: Center-back
#     LCB: Left center-back
#     RCB: Right center-back
#     LB: Left-back (Full-back)
#     RB: Right-back (Full-back)
#
#     CM : Centre midfield
#     LDM: Left center midfield
#     LAM: Left attacking midfield
#     RDM: Right center midfield
#     RAM: Right attacking midfield
#     CDM: Centre defensive midfield
#     CAM: Centre attacking midfield
#     LM : Left midfield
#     RM : Right midfield
#
#     ST: Striker
#     CF: Center forward
#     LW: Left winger
#     RW: Right winger

# %% [markdown]
# ## Best paid field positions
#
#
# **It is clear that both forward wings (R,L) and center striker are the best paid field positions.**

# %%
best_players.iloc[:,[63,11]].groupby('Preferred Positions').mean().Wage\
    .apply(lambda x: x/1000).round()\
    .sort_values(ascending=True)\
    .plot(kind='barh', colormap='Accent')
    
    
plt.xlabel('Average Wage (in Thousands of Euros)')
# Out:
# Text(0.5, 0, 'Average Wage (in Thousands of Euros)')

# %% [markdown]
# ## Overall Performance vs Potential
#
# We will create a new feature that captures the difference between these two, _Growth_.
#
# The table shows us some upcoming stars (even bigger) from Slovenia, Argentina and France.
# It would be advisable for club managers to continue to watch their development and consider transfers.
# Notice the much lower salary of J.Oblak from other players of similar performance. It looks like he would be open to negotiations.

# %%
best_players['Growth'] = best_players.Potential - best_players.Overall

best_players.nlargest(10, 'Growth')
# Out:
#               Unnamed: 0          Name  Age  \
# Name
# P. Dybala             15     P. Dybala   23
# P. Pogba              29      P. Pogba   24
# C. Eriksen            30    C. Eriksen   25
# M. Verratti           28   M. Verratti   24
# A. Griezmann          16  A. Griezmann   26
# K. De Bruyne           9  K. De Bruyne   26
# N. Kanté              27      N. Kanté   26
# Neymar                 2        Neymar   25
# Thiago                17        Thiago   26
# E. Hazard              5     E. Hazard   26
#
#                                                         Photo Nationality  \
# Name
# P. Dybala     https://cdn.sofifa.org/48/18/players/211110.png   Argentina
# P. Pogba      https://cdn.sofifa.org/48/18/players/195864.png      France
# C. Eriksen    https://cdn.sofifa.org/48/18/players/190460.png     Denmark
# M. Verratti   https://cdn.sofifa.org/48/18/players/199556.png       Italy
# A. Griezmann  https://cdn.sofifa.org/48/18/players/194765.png      France
# K. De Bruyne  https://cdn.sofifa.org/48/18/players/192985.png     Belgium
# N. Kanté      https://cdn.sofifa.org/48/18/players/215914.png      France
# Neymar        https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# Thiago        https://cdn.sofifa.org/48/18/players/189509.png       Spain
# E. Hazard     https://cdn.sofifa.org/48/18/players/183277.png     Belgium
#
#                                              Flag  Overall  Potential  \
# Name
# P. Dybala     https://cdn.sofifa.org/flags/52.png       88         93
# P. Pogba      https://cdn.sofifa.org/flags/18.png       87         92
# C. Eriksen    https://cdn.sofifa.org/flags/13.png       87         91
# M. Verratti   https://cdn.sofifa.org/flags/27.png       87         91
# A. Griezmann  https://cdn.sofifa.org/flags/18.png       88         91
# K. De Bruyne   https://cdn.sofifa.org/flags/7.png       89         92
# N. Kanté      https://cdn.sofifa.org/flags/18.png       87         90
# Neymar        https://cdn.sofifa.org/flags/54.png       92         94
# Thiago        https://cdn.sofifa.org/flags/45.png       88         90
# E. Hazard      https://cdn.sofifa.org/flags/7.png       90         91
#
#                              Club                                   Club Logo  \
# Name
# P. Dybala                Juventus   https://cdn.sofifa.org/24/18/teams/45.png
# P. Pogba        Manchester United   https://cdn.sofifa.org/24/18/teams/11.png
# C. Eriksen      Tottenham Hotspur   https://cdn.sofifa.org/24/18/teams/18.png
# M. Verratti   Paris Saint-Germain   https://cdn.sofifa.org/24/18/teams/73.png
# A. Griezmann      Atlético Madrid  https://cdn.sofifa.org/24/18/teams/240.png
# K. De Bruyne      Manchester City   https://cdn.sofifa.org/24/18/teams/10.png
# N. Kanté                  Chelsea    https://cdn.sofifa.org/24/18/teams/5.png
# Neymar        Paris Saint-Germain   https://cdn.sofifa.org/24/18/teams/73.png
# Thiago           FC Bayern Munich   https://cdn.sofifa.org/24/18/teams/21.png
# E. Hazard                 Chelsea    https://cdn.sofifa.org/24/18/teams/5.png
#
#               ...  RCB  RCM  RDM  RF  RM  RS  RW  RWB  ST  Growth
# Name          ...
# P. Dybala     ...   43   78   55  86  86  83  87   60  83       5
# P. Pogba      ...   74   84   79  83  83  81  82   77  81       5
# C. Eriksen    ...   53   83   68  82  84  77  83   69  77       4
# M. Verratti   ...   77   85   84  77  80  69  78   80  69       4
# A. Griezmann  ...   48   76   57  85  84  85  86   60  85       3
# K. De Bruyne  ...   57   84   70  85  85  81  85   71  81       3
# N. Kanté      ...   81   81   84  76  78  72  76   83  72       3
# Neymar        ...   46   79   59  88  87  84  89   64  84       2
# Thiago        ...   66   85   76  83  83  77  83   75  77       2
# E. Hazard     ...   47   81   61  87  87  82  88   64  82       1
#
# [10 rows x 76 columns]

# %% [markdown]
# ## Countries with the most room for improvements
#
# France takes the first place in terms of potential growth with 11 points total for all their players. Belgium takes the second place with 7 points. Both teams are top contenders in the World Cup.
#
# On Sunday 7/15/2018 France will face the underestimated Croatia. Perhaps after the tournament FIFA will reevaluate Croatian players and their hidden potential.

# %%
best_players.groupby('Nationality').sum().Growth.sort_values(ascending=False)
# Out:
# Nationality
# France         11
# Argentina       5
# Belgium         4
# Denmark         4
# Italy           4
# Brazil          2
# Spain           2
# Chile           0
# Croatia         0
# Germany         0
# Netherlands     0
# Portugal        0
# Sweden          0
# Uruguay         0
# Wales           0
# Name: Growth, dtype: int64

# %% [markdown]
# ### Clubs with the most room for improvements

# %%
best_players.groupby('Club').sum().Growth.sort_values(ascending=False)
# Out:
# Club
# Paris Saint-Germain    6
# Juventus               5
# Manchester United      5
# Chelsea                4
# Tottenham Hotspur      4
# Atlético Madrid        3
# Manchester City        3
# FC Bayern Munich       2
# Arsenal                0
# FC Barcelona           0
# Milan                  0
# Real Madrid CF         0
# Name: Growth, dtype: int64

# %% [markdown]
# # PLAYER SIMILARITY WITH KNN

# %%
field_cols = [ 'Acceleration',
       'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure',
       'Crossing', 'Curve', 'Dribbling', 'Finishing', 'Free kick accuracy',
       'GK diving', 'GK handling', 'GK kicking', 'GK positioning',
       'GK reflexes', 'Heading accuracy', 'Interceptions', 'Jumping',
       'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning',
       'Reactions', 'Short passing', 'Shot power', 'Sliding tackle',
       'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision',
       'Volleys']

# %%
fifa[field_cols].head()
# Out:
#    Acceleration  Aggression  Agility  Balance  Ball control  Composure  \
# 0            89          63       89       63            93         95
# 1            92          48       90       95            95         96
# 2            94          56       96       82            95         92
# 3            88          78       86       60            91         83
# 4            79          80       78       80            89         87
#
#    Crossing  Curve  Dribbling  Finishing  ...  Reactions  Short passing  \
# 0        85     81         91         94  ...         96             83
# 1        77     89         97         95  ...         95             88
# 2        75     81         96         89  ...         88             81
# 3        77     86         86         94  ...         93             83
# 4        62     77         85         91  ...         91             83
#
#    Shot power  Sliding tackle  Sprint speed  Stamina  Standing tackle  \
# 0          94              23            91       92               31
# 1          85              26            87       73               28
# 2          80              33            90       78               24
# 3          87              38            77       89               45
# 4          88              19            83       79               42
#
#    Strength  Vision  Volleys
# 0        80      85       88
# 1        59      90       85
# 2        53      80       83
# 3        80      84       88
# 4        84      78       87
#
# [5 rows x 34 columns]

# %%
tr = fifa[['ID','Name']+field_cols].dropna()
id_name = fifa.set_index('ID')['Name'].to_dict()

# %%
fifa.to_csv("test2.csv")

# %%
fifa
# Out:
#        Unnamed: 0               Name  Age  \
# 0               0  Cristiano Ronaldo   32
# 1               1           L. Messi   30
# 2               2             Neymar   25
# 3               3          L. Suárez   30
# 4               4     R. Lewandowski   28
# ...           ...                ...  ...
# 15741       15741          J. Keeble   18
# 15742       15742       T. Käßemodel   28
# 15743       15743           J. Young   17
# 15744       15744       J. Lundstram   18
# 15745       15745          L. Sackey   18
#
#                                                  Photo Nationality  \
# 0       https://cdn.sofifa.org/48/18/players/20801.png    Portugal
# 1      https://cdn.sofifa.org/48/18/players/158023.png   Argentina
# 2      https://cdn.sofifa.org/48/18/players/190871.png      Brazil
# 3      https://cdn.sofifa.org/48/18/players/176580.png     Uruguay
# 4      https://cdn.sofifa.org/48/18/players/188545.png      Poland
# ...                                                ...         ...
# 15741  https://cdn.sofifa.org/48/18/players/240404.png     England
# 15742  https://cdn.sofifa.org/48/18/players/235352.png     Germany
# 15743  https://cdn.sofifa.org/48/18/players/231381.png    Scotland
# 15744  https://cdn.sofifa.org/48/18/players/238813.png     England
# 15745  https://cdn.sofifa.org/48/18/players/238308.png       Ghana
#
#                                        Flag  Overall  Potential  \
# 0       https://cdn.sofifa.org/flags/38.png       94         94
# 1       https://cdn.sofifa.org/flags/52.png       93         93
# 2       https://cdn.sofifa.org/flags/54.png       92         94
# 3       https://cdn.sofifa.org/flags/60.png       92         92
# 4       https://cdn.sofifa.org/flags/37.png       91         91
# ...                                     ...      ...        ...
# 15741   https://cdn.sofifa.org/flags/14.png       46         56
# 15742   https://cdn.sofifa.org/flags/21.png       46         46
# 15743   https://cdn.sofifa.org/flags/42.png       46         61
# 15744   https://cdn.sofifa.org/flags/14.png       46         64
# 15745  https://cdn.sofifa.org/flags/117.png       46         64
#
#                       Club                                    Club Logo  ...  \
# 0           Real Madrid CF   https://cdn.sofifa.org/24/18/teams/243.png  ...
# 1             FC Barcelona   https://cdn.sofifa.org/24/18/teams/241.png  ...
# 2      Paris Saint-Germain    https://cdn.sofifa.org/24/18/teams/73.png  ...
# 3             FC Barcelona   https://cdn.sofifa.org/24/18/teams/241.png  ...
# 4         FC Bayern Munich    https://cdn.sofifa.org/24/18/teams/21.png  ...
# ...                    ...                                          ...  ...
# 15741         Grimsby Town    https://cdn.sofifa.org/24/18/teams/92.png  ...
# 15742    FC Erzgebirge Aue   https://cdn.sofifa.org/24/18/teams/506.png  ...
# 15743         Swindon Town  https://cdn.sofifa.org/24/18/teams/1934.png  ...
# 15744      Crewe Alexandra   https://cdn.sofifa.org/24/18/teams/121.png  ...
# 15745    Scunthorpe United  https://cdn.sofifa.org/24/18/teams/1949.png  ...
#
#        RB  RCB  RCM  RDM  RF  RM  RS  RW  RWB  ST
# 0      61   53   82   62  91  89  92  91   66  92
# 1      57   45   84   59  92  90  88  91   62  88
# 2      59   46   79   59  88  87  84  89   64  84
# 3      64   58   80   65  88  85  88  87   68  88
# 4      58   57   78   62  87  82  88  84   61  88
# ...    ..  ...  ...  ...  ..  ..  ..  ..  ...  ..
# 15741  46   45   34   41  33  35  33  34   44  33
# 15742  37   38   45   42  42  42  41  41   38  41
# 15743  31   28   38   29  45  42  45  44   32  45
# 15744  47   46   45   47  43  45  41  44   46  41
# 15745  40   45   30   38  29  30  31  29   38  31
#
# [15746 rows x 75 columns]

# %%
from sklearn.neighbors import NearestNeighbors
NUM_RECOM = 10

X = tr[field_cols].dropna().values
nbrs = NearestNeighbors(n_neighbors=NUM_RECOM+1, algorithm='ball_tree').fit(X)
dist, rank = nbrs.kneighbors(X)

similar_df = pd.DataFrame(columns=[f'rank_{i}'for i in range(1,NUM_RECOM+1)],
                          index=tr['ID'].values,
                          data=rank[:,1:])
dist_df = pd.DataFrame(columns=[f'rank_{i}'for i in range(1,NUM_RECOM+1)],
                       index=tr['ID'].values,
                       data=dist[:,1:])


for cols in list(similar_df):
    tg_col = similar_df[cols]
    new_value = tr['ID'].iloc[tg_col].tolist()
    similar_df[cols] = new_value

# %%
import plotly.graph_objs as go
def similar_player(similar_df, dist_df, player_id):
    player_id = int(player_id)
    player_name = tr[tr['ID'] == player_id]['Name'].values[0]
    
    ## Bar chart
    Xaxis = 1/(1+dist_df.loc[player_id].values[::-1])
    Yaxis = similar_df.loc[player_id].map(id_name).values[::-1]

    fig = go.Figure(go.Bar(
                x=Xaxis,
                y=Yaxis,
                orientation='h'))
    
    fig.update_layout(title_text='Players similar to  " '+str(player_name)+' "')
    fig.show()

    ## Table display
    sim_ply = similar_df.loc[player_id]
    display_col = ['Name','Age','Nationality','Overall','Potential', 'Club', 'Wage','Value']

    display_df = pd.DataFrame({'ID':similar_df.loc[player_id]})\
    .merge(fifa[['ID']+display_col], how='left', on='ID')[display_col]


    display(display_df.style.highlight_max(color='#BF40BF').highlight_min(color='#cd4f39'))

# %%
similar_player(similar_df, dist_df, 183277)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fa1aa934-08ec-4a76-8514-0a1f8a6eddc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa1aa934-08ec-4a76-8514-0a1f8a6eddc3")) {                    Plotly.newPlot(                        "fa1aa934-08ec-4a76-8514-0a1f8a6eddc3",                        [{"orientation":"h","x":[0.023002507578031392,0.02310282541898822,0.023339972517608772,0.023871990784273937,0.024026799286343117,0.024578316179141586,0.02606672644052961,0.026438306478999217,0.031766703995965886,0.03522847513385621],"y":["Y. Brahimi","F. Rib\u00e9ry","Coutinho","R. Mahrez","A. G\u00f3mez","F. Bernardeschi","P. Dybala","Douglas Costa","Neymar","A. Robben"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"s ...
# <style type="text/css">
# #T_4a227_row0_col2, #T_4a227_row1_col3, #T_4a227_row1_col4, #T_4a227_row1_col5, #T_4a227_row1_col6, #T_4a227_row1_col7, #T_4a227_row8_col1, #T_4a227_row9_col0 {
#   background-color: #BF40BF;
# }
# #T_4a227_row2_col3, #T_4a227_row2_col4, #T_4a227_row3_col1, #T_4a227_row4_col1, #T_4a227_row4_col3, #T_4a227_row5_col0, #T_4a227_row5_col5, #T_4a227_row6_col2, #T_4a227_row8_col7, #T_4a227_row9_col2, #T_4a227_row9_col3, #T_4a227_row9_col4, #T_4a227_row9_col6 {
#   background-color: #cd4f39;
# }
# </style>
# <table id="T_4a227_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Age</th>
#       <th class="col_heading level0 col2" >Nationality</th>
#       <th class="col_heading level0 col3" >Overall</th>
#       <th class="col_heading level0 col4" >Potential</th>
#       <th class="col_heading level0 col5" >Club</th>
#       <th class="col_heading level0 col6" >Wage</th>
#       <th class="col_heading level0 col7" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a227_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a227_row0_col0" class="data row0 col0" >A. Robben</td>
#       <td id="T_4a227_row0_col1" class="data row0 col1" >33</td>
#       <td id="T_4a227_row0_col2" class="data row0 col2" >Netherlands</td>
#       <td id="T_4a227_row0_col3" class="data row0 col3" >88</td>
#       <td id="T_4a227_row0_col4" class="data row0 col4" >88</td>
#       <td id="T_4a227_row0_col5" class="data row0 col5" >FC Bayern Munich</td>
#       <td id="T_4a227_row0_col6" class="data row0 col6" >225000</td>
#       <td id="T_4a227_row0_col7" class="data row0 col7" >36000000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a227_row1_col0" class="data row1 col0" >Neymar</td>
#       <td id="T_4a227_row1_col1" class="data row1 col1" >25</td>
#       <td id="T_4a227_row1_col2" class="data row1 col2" >Brazil</td>
#       <td id="T_4a227_row1_col3" class="data row1 col3" >92</td>
#       <td id="T_4a227_row1_col4" class="data row1 col4" >94</td>
#       <td id="T_4a227_row1_col5" class="data row1 col5" >Paris Saint-Germain</td>
#       <td id="T_4a227_row1_col6" class="data row1 col6" >280000</td>
#       <td id="T_4a227_row1_col7" class="data row1 col7" >123000000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a227_row2_col0" class="data row2 col0" >Douglas Costa</td>
#       <td id="T_4a227_row2_col1" class="data row2 col1" >26</td>
#       <td id="T_4a227_row2_col2" class="data row2 col2" >Brazil</td>
#       <td id="T_4a227_row2_col3" class="data row2 col3" >82</td>
#       <td id="T_4a227_row2_col4" class="data row2 col4" >82</td>
#       <td id="T_4a227_row2_col5" class="data row2 col5" >Juventus</td>
#       <td id="T_4a227_row2_col6" class="data row2 col6" >115000</td>
#       <td id="T_4a227_row2_col7" class="data row2 col7" >24000000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a227_row3_col0" class="data row3 col0" >P. Dybala</td>
#       <td id="T_4a227_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_4a227_row3_col2" class="data row3 col2" >Argentina</td>
#       <td id="T_4a227_row3_col3" class="data row3 col3" >88</td>
#       <td id="T_4a227_row3_col4" class="data row3 col4" >93</td>
#       <td id="T_4a227_row3_col5" class="data row3 col5" >Juventus</td>
#       <td id="T_4a227_row3_col6" class="data row3 col6" >215000</td>
#       <td id="T_4a227_row3_col7" class="data row3 col7" >79000000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a227_row4_col0" class="data row4 col0" >F. Bernardeschi</td>
#       <td id="T_4a227_row4_col1" class="data row4 col1" >23</td>
#       <td id="T_4a227_row4_col2" class="data row4 col2" >Italy</td>
#       <td id="T_4a227_row4_col3" class="data row4 col3" >82</td>
#       <td id="T_4a227_row4_col4" class="data row4 col4" >88</td>
#       <td id="T_4a227_row4_col5" class="data row4 col5" >Juventus</td>
#       <td id="T_4a227_row4_col6" class="data row4 col6" >110000</td>
#       <td id="T_4a227_row4_col7" class="data row4 col7" >30500000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a227_row5_col0" class="data row5 col0" >A. Gómez</td>
#       <td id="T_4a227_row5_col1" class="data row5 col1" >29</td>
#       <td id="T_4a227_row5_col2" class="data row5 col2" >Argentina</td>
#       <td id="T_4a227_row5_col3" class="data row5 col3" >84</td>
#       <td id="T_4a227_row5_col4" class="data row5 col4" >84</td>
#       <td id="T_4a227_row5_col5" class="data row5 col5" >Atalanta</td>
#       <td id="T_4a227_row5_col6" class="data row5 col6" >60000</td>
#       <td id="T_4a227_row5_col7" class="data row5 col7" >31000000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a227_row6_col0" class="data row6 col0" >R. Mahrez</td>
#       <td id="T_4a227_row6_col1" class="data row6 col1" >26</td>
#       <td id="T_4a227_row6_col2" class="data row6 col2" >Algeria</td>
#       <td id="T_4a227_row6_col3" class="data row6 col3" >83</td>
#       <td id="T_4a227_row6_col4" class="data row6 col4" >84</td>
#       <td id="T_4a227_row6_col5" class="data row6 col5" >Leicester City</td>
#       <td id="T_4a227_row6_col6" class="data row6 col6" >88000</td>
#       <td id="T_4a227_row6_col7" class="data row6 col7" >30500000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a227_row7_col0" class="data row7 col0" >Coutinho</td>
#       <td id="T_4a227_row7_col1" class="data row7 col1" >25</td>
#       <td id="T_4a227_row7_col2" class="data row7 col2" >Brazil</td>
#       <td id="T_4a227_row7_col3" class="data row7 col3" >86</td>
#       <td id="T_4a227_row7_col4" class="data row7 col4" >89</td>
#       <td id="T_4a227_row7_col5" class="data row7 col5" >Liverpool</td>
#       <td id="T_4a227_row7_col6" class="data row7 col6" >205000</td>
#       <td id="T_4a227_row7_col7" class="data row7 col7" >56000000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a227_row8_col0" class="data row8 col0" >F. Ribéry</td>
#       <td id="T_4a227_row8_col1" class="data row8 col1" >34</td>
#       <td id="T_4a227_row8_col2" class="data row8 col2" >France</td>
#       <td id="T_4a227_row8_col3" class="data row8 col3" >86</td>
#       <td id="T_4a227_row8_col4" class="data row8 col4" >86</td>
#       <td id="T_4a227_row8_col5" class="data row8 col5" >FC Bayern Munich</td>
#       <td id="T_4a227_row8_col6" class="data row8 col6" >175000</td>
#       <td id="T_4a227_row8_col7" class="data row8 col7" >22500000</td>
#     </tr>
#     <tr>
#       <th id="T_4a227_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a227_row9_col0" class="data row9 col0" >Y. Brahimi</td>
#       <td id="T_4a227_row9_col1" class="data row9 col1" >27</td>
#       <td id="T_4a227_row9_col2" class="data row9 col2" >Algeria</td>
#       <td id="T_4a227_row9_col3" class="data row9 col3" >82</td>
#       <td id="T_4a227_row9_col4" class="data row9 col4" >82</td>
#       <td id="T_4a227_row9_col5" class="data row9 col5" >FC Porto</td>
#       <td id="T_4a227_row9_col6" class="data row9 col6" >21000</td>
#       <td id="T_4a227_row9_col7" class="data row9 col7" >23000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
similar_player(similar_df, dist_df, 190871)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6816fe42-72ee-4ed7-af55-268e22616537" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6816fe42-72ee-4ed7-af55-268e22616537")) {                    Plotly.newPlot(                        "6816fe42-72ee-4ed7-af55-268e22616537",                        [{"orientation":"h","x":[0.021624527909801797,0.021655601957012778,0.02171292326479805,0.02177598160160258,0.021876965871980136,0.02251411183236986,0.023977213088221764,0.024944099915772185,0.026334526423625403,0.031766703995965886],"y":["W. Ben Yedder","H. Son","F. Bernardeschi","D. Mertens","A. G\u00f3mez","Eder","P. Dybala","L. Messi","A. Robben","E. Hazard"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}], ...
# <style type="text/css">
# #T_16b70_row1_col1, #T_16b70_row1_col2, #T_16b70_row2_col3, #T_16b70_row2_col4, #T_16b70_row2_col6, #T_16b70_row2_col7, #T_16b70_row3_col4, #T_16b70_row8_col5, #T_16b70_row9_col0 {
#   background-color: #BF40BF;
# }
# #T_16b70_row2_col2, #T_16b70_row3_col1, #T_16b70_row3_col2, #T_16b70_row4_col3, #T_16b70_row4_col4, #T_16b70_row4_col7, #T_16b70_row5_col0, #T_16b70_row5_col2, #T_16b70_row5_col5, #T_16b70_row7_col1, #T_16b70_row9_col6 {
#   background-color: #cd4f39;
# }
# </style>
# <table id="T_16b70_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Age</th>
#       <th class="col_heading level0 col2" >Nationality</th>
#       <th class="col_heading level0 col3" >Overall</th>
#       <th class="col_heading level0 col4" >Potential</th>
#       <th class="col_heading level0 col5" >Club</th>
#       <th class="col_heading level0 col6" >Wage</th>
#       <th class="col_heading level0 col7" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16b70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16b70_row0_col0" class="data row0 col0" >E. Hazard</td>
#       <td id="T_16b70_row0_col1" class="data row0 col1" >26</td>
#       <td id="T_16b70_row0_col2" class="data row0 col2" >Belgium</td>
#       <td id="T_16b70_row0_col3" class="data row0 col3" >90</td>
#       <td id="T_16b70_row0_col4" class="data row0 col4" >91</td>
#       <td id="T_16b70_row0_col5" class="data row0 col5" >Chelsea</td>
#       <td id="T_16b70_row0_col6" class="data row0 col6" >295000</td>
#       <td id="T_16b70_row0_col7" class="data row0 col7" >90500000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16b70_row1_col0" class="data row1 col0" >A. Robben</td>
#       <td id="T_16b70_row1_col1" class="data row1 col1" >33</td>
#       <td id="T_16b70_row1_col2" class="data row1 col2" >Netherlands</td>
#       <td id="T_16b70_row1_col3" class="data row1 col3" >88</td>
#       <td id="T_16b70_row1_col4" class="data row1 col4" >88</td>
#       <td id="T_16b70_row1_col5" class="data row1 col5" >FC Bayern Munich</td>
#       <td id="T_16b70_row1_col6" class="data row1 col6" >225000</td>
#       <td id="T_16b70_row1_col7" class="data row1 col7" >36000000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16b70_row2_col0" class="data row2 col0" >L. Messi</td>
#       <td id="T_16b70_row2_col1" class="data row2 col1" >30</td>
#       <td id="T_16b70_row2_col2" class="data row2 col2" >Argentina</td>
#       <td id="T_16b70_row2_col3" class="data row2 col3" >93</td>
#       <td id="T_16b70_row2_col4" class="data row2 col4" >93</td>
#       <td id="T_16b70_row2_col5" class="data row2 col5" >FC Barcelona</td>
#       <td id="T_16b70_row2_col6" class="data row2 col6" >565000</td>
#       <td id="T_16b70_row2_col7" class="data row2 col7" >105000000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16b70_row3_col0" class="data row3 col0" >P. Dybala</td>
#       <td id="T_16b70_row3_col1" class="data row3 col1" >23</td>
#       <td id="T_16b70_row3_col2" class="data row3 col2" >Argentina</td>
#       <td id="T_16b70_row3_col3" class="data row3 col3" >88</td>
#       <td id="T_16b70_row3_col4" class="data row3 col4" >93</td>
#       <td id="T_16b70_row3_col5" class="data row3 col5" >Juventus</td>
#       <td id="T_16b70_row3_col6" class="data row3 col6" >215000</td>
#       <td id="T_16b70_row3_col7" class="data row3 col7" >79000000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16b70_row4_col0" class="data row4 col0" >Eder</td>
#       <td id="T_16b70_row4_col1" class="data row4 col1" >30</td>
#       <td id="T_16b70_row4_col2" class="data row4 col2" >Italy</td>
#       <td id="T_16b70_row4_col3" class="data row4 col3" >80</td>
#       <td id="T_16b70_row4_col4" class="data row4 col4" >80</td>
#       <td id="T_16b70_row4_col5" class="data row4 col5" >Inter</td>
#       <td id="T_16b70_row4_col6" class="data row4 col6" >80000</td>
#       <td id="T_16b70_row4_col7" class="data row4 col7" >14500000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_16b70_row5_col0" class="data row5 col0" >A. Gómez</td>
#       <td id="T_16b70_row5_col1" class="data row5 col1" >29</td>
#       <td id="T_16b70_row5_col2" class="data row5 col2" >Argentina</td>
#       <td id="T_16b70_row5_col3" class="data row5 col3" >84</td>
#       <td id="T_16b70_row5_col4" class="data row5 col4" >84</td>
#       <td id="T_16b70_row5_col5" class="data row5 col5" >Atalanta</td>
#       <td id="T_16b70_row5_col6" class="data row5 col6" >60000</td>
#       <td id="T_16b70_row5_col7" class="data row5 col7" >31000000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_16b70_row6_col0" class="data row6 col0" >D. Mertens</td>
#       <td id="T_16b70_row6_col1" class="data row6 col1" >30</td>
#       <td id="T_16b70_row6_col2" class="data row6 col2" >Belgium</td>
#       <td id="T_16b70_row6_col3" class="data row6 col3" >86</td>
#       <td id="T_16b70_row6_col4" class="data row6 col4" >86</td>
#       <td id="T_16b70_row6_col5" class="data row6 col5" >Napoli</td>
#       <td id="T_16b70_row6_col6" class="data row6 col6" >135000</td>
#       <td id="T_16b70_row6_col7" class="data row6 col7" >43000000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_16b70_row7_col0" class="data row7 col0" >F. Bernardeschi</td>
#       <td id="T_16b70_row7_col1" class="data row7 col1" >23</td>
#       <td id="T_16b70_row7_col2" class="data row7 col2" >Italy</td>
#       <td id="T_16b70_row7_col3" class="data row7 col3" >82</td>
#       <td id="T_16b70_row7_col4" class="data row7 col4" >88</td>
#       <td id="T_16b70_row7_col5" class="data row7 col5" >Juventus</td>
#       <td id="T_16b70_row7_col6" class="data row7 col6" >110000</td>
#       <td id="T_16b70_row7_col7" class="data row7 col7" >30500000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_16b70_row8_col0" class="data row8 col0" >H. Son</td>
#       <td id="T_16b70_row8_col1" class="data row8 col1" >24</td>
#       <td id="T_16b70_row8_col2" class="data row8 col2" >Korea Republic</td>
#       <td id="T_16b70_row8_col3" class="data row8 col3" >82</td>
#       <td id="T_16b70_row8_col4" class="data row8 col4" >85</td>
#       <td id="T_16b70_row8_col5" class="data row8 col5" >Tottenham Hotspur</td>
#       <td id="T_16b70_row8_col6" class="data row8 col6" >95000</td>
#       <td id="T_16b70_row8_col7" class="data row8 col7" >28000000</td>
#     </tr>
#     <tr>
#       <th id="T_16b70_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_16b70_row9_col0" class="data row9 col0" >W. Ben Yedder</td>
#       <td id="T_16b70_row9_col1" class="data row9 col1" >26</td>
#       <td id="T_16b70_row9_col2" class="data row9 col2" >France</td>
#       <td id="T_16b70_row9_col3" class="data row9 col3" >81</td>
#       <td id="T_16b70_row9_col4" class="data row9 col4" >82</td>
#       <td id="T_16b70_row9_col5" class="data row9 col5" >Sevilla FC</td>
#       <td id="T_16b70_row9_col6" class="data row9 col6" >26000</td>
#       <td id="T_16b70_row9_col7" class="data row9 col7" >21000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
similar_player(similar_df, dist_df, 179844)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="df321030-6000-421a-b30b-38698480e5f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df321030-6000-421a-b30b-38698480e5f9")) {                    Plotly.newPlot(                        "df321030-6000-421a-b30b-38698480e5f9",                        [{"orientation":"h","x":[0.020718857676840972,0.02108726905930392,0.021232449287412632,0.021360745832135954,0.021952287711638575,0.022757363595858806,0.023083915049719357,0.02319808495646422,0.024206458584663023,0.025815828902478157],"y":["Willian Jos\u00e9","C. Stuani","F. Andone","C. Immobile","I. Slimani","R. Jim\u00e9nez","A. Gignac","H. Kane","R. Lukaku","N. Kalini\u0107"],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"ty ...
# <style type="text/css">
# #T_76274_row1_col3, #T_76274_row1_col4, #T_76274_row1_col6, #T_76274_row1_col7, #T_76274_row2_col3, #T_76274_row2_col4, #T_76274_row2_col5, #T_76274_row2_col7, #T_76274_row3_col1, #T_76274_row8_col2, #T_76274_row9_col0 {
#   background-color: #BF40BF;
# }
# #T_76274_row2_col1, #T_76274_row3_col0, #T_76274_row4_col6, #T_76274_row5_col2, #T_76274_row8_col3, #T_76274_row8_col4, #T_76274_row8_col5, #T_76274_row8_col7 {
#   background-color: #cd4f39;
# }
# </style>
# <table id="T_76274_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Name</th>
#       <th class="col_heading level0 col1" >Age</th>
#       <th class="col_heading level0 col2" >Nationality</th>
#       <th class="col_heading level0 col3" >Overall</th>
#       <th class="col_heading level0 col4" >Potential</th>
#       <th class="col_heading level0 col5" >Club</th>
#       <th class="col_heading level0 col6" >Wage</th>
#       <th class="col_heading level0 col7" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76274_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76274_row0_col0" class="data row0 col0" >N. Kalinić</td>
#       <td id="T_76274_row0_col1" class="data row0 col1" >29</td>
#       <td id="T_76274_row0_col2" class="data row0 col2" >Croatia</td>
#       <td id="T_76274_row0_col3" class="data row0 col3" >81</td>
#       <td id="T_76274_row0_col4" class="data row0 col4" >81</td>
#       <td id="T_76274_row0_col5" class="data row0 col5" >Milan</td>
#       <td id="T_76274_row0_col6" class="data row0 col6" >84000</td>
#       <td id="T_76274_row0_col7" class="data row0 col7" >18000000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76274_row1_col0" class="data row1 col0" >R. Lukaku</td>
#       <td id="T_76274_row1_col1" class="data row1 col1" >24</td>
#       <td id="T_76274_row1_col2" class="data row1 col2" >Belgium</td>
#       <td id="T_76274_row1_col3" class="data row1 col3" >86</td>
#       <td id="T_76274_row1_col4" class="data row1 col4" >90</td>
#       <td id="T_76274_row1_col5" class="data row1 col5" >Manchester United</td>
#       <td id="T_76274_row1_col6" class="data row1 col6" >210000</td>
#       <td id="T_76274_row1_col7" class="data row1 col7" >59000000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76274_row2_col0" class="data row2 col0" >H. Kane</td>
#       <td id="T_76274_row2_col1" class="data row2 col1" >23</td>
#       <td id="T_76274_row2_col2" class="data row2 col2" >England</td>
#       <td id="T_76274_row2_col3" class="data row2 col3" >86</td>
#       <td id="T_76274_row2_col4" class="data row2 col4" >90</td>
#       <td id="T_76274_row2_col5" class="data row2 col5" >Tottenham Hotspur</td>
#       <td id="T_76274_row2_col6" class="data row2 col6" >165000</td>
#       <td id="T_76274_row2_col7" class="data row2 col7" >59000000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76274_row3_col0" class="data row3 col0" >A. Gignac</td>
#       <td id="T_76274_row3_col1" class="data row3 col1" >31</td>
#       <td id="T_76274_row3_col2" class="data row3 col2" >France</td>
#       <td id="T_76274_row3_col3" class="data row3 col3" >81</td>
#       <td id="T_76274_row3_col4" class="data row3 col4" >81</td>
#       <td id="T_76274_row3_col5" class="data row3 col5" >Tigres U.A.N.L.</td>
#       <td id="T_76274_row3_col6" class="data row3 col6" >84000</td>
#       <td id="T_76274_row3_col7" class="data row3 col7" >16000000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76274_row4_col0" class="data row4 col0" >R. Jiménez</td>
#       <td id="T_76274_row4_col1" class="data row4 col1" >26</td>
#       <td id="T_76274_row4_col2" class="data row4 col2" >Mexico</td>
#       <td id="T_76274_row4_col3" class="data row4 col3" >78</td>
#       <td id="T_76274_row4_col4" class="data row4 col4" >80</td>
#       <td id="T_76274_row4_col5" class="data row4 col5" >SL Benfica</td>
#       <td id="T_76274_row4_col6" class="data row4 col6" >16000</td>
#       <td id="T_76274_row4_col7" class="data row4 col7" >12500000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76274_row5_col0" class="data row5 col0" >I. Slimani</td>
#       <td id="T_76274_row5_col1" class="data row5 col1" >29</td>
#       <td id="T_76274_row5_col2" class="data row5 col2" >Algeria</td>
#       <td id="T_76274_row5_col3" class="data row5 col3" >82</td>
#       <td id="T_76274_row5_col4" class="data row5 col4" >82</td>
#       <td id="T_76274_row5_col5" class="data row5 col5" >Leicester City</td>
#       <td id="T_76274_row5_col6" class="data row5 col6" >100000</td>
#       <td id="T_76274_row5_col7" class="data row5 col7" >22000000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76274_row6_col0" class="data row6 col0" >C. Immobile</td>
#       <td id="T_76274_row6_col1" class="data row6 col1" >27</td>
#       <td id="T_76274_row6_col2" class="data row6 col2" >Italy</td>
#       <td id="T_76274_row6_col3" class="data row6 col3" >82</td>
#       <td id="T_76274_row6_col4" class="data row6 col4" >83</td>
#       <td id="T_76274_row6_col5" class="data row6 col5" >Lazio</td>
#       <td id="T_76274_row6_col6" class="data row6 col6" >70000</td>
#       <td id="T_76274_row6_col7" class="data row6 col7" >26000000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76274_row7_col0" class="data row7 col0" >F. Andone</td>
#       <td id="T_76274_row7_col1" class="data row7 col1" >24</td>
#       <td id="T_76274_row7_col2" class="data row7 col2" >Romania</td>
#       <td id="T_76274_row7_col3" class="data row7 col3" >79</td>
#       <td id="T_76274_row7_col4" class="data row7 col4" >84</td>
#       <td id="T_76274_row7_col5" class="data row7 col5" >RC Deportivo de La Coruña</td>
#       <td id="T_76274_row7_col6" class="data row7 col6" >31000</td>
#       <td id="T_76274_row7_col7" class="data row7 col7" >17000000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76274_row8_col0" class="data row8 col0" >C. Stuani</td>
#       <td id="T_76274_row8_col1" class="data row8 col1" >30</td>
#       <td id="T_76274_row8_col2" class="data row8 col2" >Uruguay</td>
#       <td id="T_76274_row8_col3" class="data row8 col3" >77</td>
#       <td id="T_76274_row8_col4" class="data row8 col4" >77</td>
#       <td id="T_76274_row8_col5" class="data row8 col5" >Girona CF</td>
#       <td id="T_76274_row8_col6" class="data row8 col6" >30000</td>
#       <td id="T_76274_row8_col7" class="data row8 col7" >8500000</td>
#     </tr>
#     <tr>
#       <th id="T_76274_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76274_row9_col0" class="data row9 col0" >Willian José</td>
#       <td id="T_76274_row9_col1" class="data row9 col1" >25</td>
#       <td id="T_76274_row9_col2" class="data row9 col2" >Brazil</td>
#       <td id="T_76274_row9_col3" class="data row9 col3" >82</td>
#       <td id="T_76274_row9_col4" class="data row9 col4" >86</td>
#       <td id="T_76274_row9_col5" class="data row9 col5" >Real Sociedad</td>
#       <td id="T_76274_row9_col6" class="data row9 col6" >42000</td>
#       <td id="T_76274_row9_col7" class="data row9 col7" >29000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# players and their ID
fifa[['Name','ID']].head(20)
# Out:
#                  Name      ID
# 0   Cristiano Ronaldo   20801
# 1            L. Messi  158023
# 2              Neymar  190871
# 3           L. Suárez  176580
# 4      R. Lewandowski  188545
# 5           E. Hazard  183277
# 6            T. Kroos  182521
# 7          G. Higuaín  167664
# 8        Sergio Ramos  155862
# 9        K. De Bruyne  192985
# 10         A. Sánchez  184941
# 11          L. Modrić  177003
# 12            G. Bale  173731
# 13          S. Agüero  153079
# 14       G. Chiellini  138956
# 15          P. Dybala  211110
# 16       A. Griezmann  194765
# 17             Thiago  189509
# 18      P. Aubameyang  188567
# 19         L. Bonucci  184344
